# %% [markdown]
# # Cummings OCR

# %%
# Libraries
from pathlib import Path
import pdf2image
from pdf2image import convert_from_path
import os
import sys
import PIL
import pytesseract
from PIL import Image, ImageChops, ImageStat

# %%
# Create Directories
pdfs_folder = Path("./L'Hospital Big 3")

# %%
### Convert multiple pdfs into a set of image files ordered by folder ###

# For each pdf file in the pdf folder, do the following:
for pdf in pdfs_folder.glob('*.pdf'):
    # Announce the current working file
    print(f'Converting {pdf.name}')
    
    # Create a folder for the images
    pdf_images = Path(f'{pdfs_folder.as_posix()}/{os.path.splitext(pdf.name)[0]}/images')
    pdf_images.mkdir(exist_ok=True, parents=True)
    
    # Get the PDF and convert to a group of PIL (Pillow) objects
    document_path = Path(pdf)
    PIL_objects = convert_from_path(document_path, 250)

    # For each PIL image object:
    for page, image in enumerate(PIL_objects):
        # Create a file name that includes the original file name, and
        # a file number, as well as the file extension.
        if page < 10:
            fileName = f'{pdf_images.as_posix()}/{os.path.splitext(pdf.name)[0]}_image_000{str(page)}.jpg'
        elif page < 100:
            fileName = f'{pdf_images.as_posix()}/{os.path.splitext(pdf.name)[0]}_image_00{str(page)}.jpg'
        elif page < 1000:
            fileName = f'{pdf_images.as_posix()}/{os.path.splitext(pdf.name)[0]}_image_0{str(page)}.jpg'
        else:
            fileName = f'{pdf_images.as_posix()}/{os.path.splitext(pdf.name)[0]}_image_{str(page)}.jpg'

        # Save each PIL image object using the file name created above
        # and declare the image's file format. (Try also PNG or TIFF.)
        image.save(fileName, 'JPEG')
        print('converting page', page)

print('All PDFs converted to images.')
# Out:
# Converting Traite Justice VI-2.pdf
# converting page 0
# converting page 1
# converting page 2
# converting page 3
# converting page 4
# converting page 5
# converting page 6
# converting page 7
# converting page 8
# converting page 9
# converting page 10
# converting page 11
# converting page 12
# converting page 13
# converting page 14
# converting page 15
# converting page 16
# converting page 17
# converting page 18
# converting page 19
# converting page 20
# converting page 21
# converting page 22
# converting page 23
# converting page 24
# converting page 25
# converting page 26
# converting page 27
# converting page 28
# converting page 29
# converting page 30
# converting page 31
# converting page 32
# converting page 33
# converting page 34
# converting page 35
# converting page 36
# converting page 37
# converting page 38
# converting page 39
# converting page 40
# converting page 41
# converting page 42
# converting page 43
# converting page 44
# converting page 45
# ...

# %%
### Rename multiple image files ###
imgs_folder = Path("./L'Hospital Big 3/Traite Justice VI-1/images")
img_folder = "./L'Hospital Big 3/Traite Justice VI-1/images"
# For each img file in the img folder, do the following:
page = 0
doc_name = 'Traite Justice VI'
for img in sorted(imgs_folder.rglob('*.jpg')):
    # Announce the current working file
    print(f'Renaming {img.name}')
    
    # For each image object:
    if page < 10:
        old_name = f'{img_folder}/{img.name}'
        new_name = f'{img_folder}/{doc_name}_image_000{str(page)}.jpg'
        os.rename (old_name, new_name)
    elif page < 100:
        old_name = f'{img_folder}/{img.name}'
        new_name = f'{img_folder}/{doc_name}_image_00{str(page)}.jpg'
        os.rename (old_name, new_name)
    elif page < 1000:
        old_name = f'{img_folder}/{img.name}'
        new_name = f'{img_folder}/{doc_name}_image_0{str(page)}.jpg'
        os.rename (old_name, new_name)
    else:
        old_name = f'{img_folder}/{img.name}'
        new_name = f'{img_folder}/{doc_name}_image_{str(page)}.jpg'
        os.rename (old_name, new_name)
    page = page + 1

print('All images renamed')
# Out:
# Renaming Traite Justice VI-1_image_0000.jpg
# Renaming Traite Justice VI-1_image_0001.jpg
# Renaming Traite Justice VI-1_image_0002.jpg
# Renaming Traite Justice VI-1_image_0003.jpg
# Renaming Traite Justice VI-1_image_0004.jpg
# Renaming Traite Justice VI-1_image_0005.jpg
# Renaming Traite Justice VI-1_image_0006.jpg
# Renaming Traite Justice VI-1_image_0007.jpg
# Renaming Traite Justice VI-1_image_0008.jpg
# Renaming Traite Justice VI-1_image_0009.jpg
# Renaming Traite Justice VI-1_image_0010.jpg
# Renaming Traite Justice VI-1_image_0011.jpg
# Renaming Traite Justice VI-1_image_0012.jpg
# Renaming Traite Justice VI-1_image_0013.jpg
# Renaming Traite Justice VI-1_image_0014.jpg
# Renaming Traite Justice VI-1_image_0015.jpg
# Renaming Traite Justice VI-1_image_0016.jpg
# Renaming Traite Justice VI-1_image_0017.jpg
# Renaming Traite Justice VI-1_image_0018.jpg
# Renaming Traite Justice VI-1_image_0019.jpg
# Renaming Traite Justice VI-1_image_0020.jpg
# ...

# %%
### Rename multiple image files ###
imgs_folder = Path("./L'Hospital Big 3/Traite Justice VI-2/images")
img_folder = "./L'Hospital Big 3/Traite Justice VI-2/images"
# For each img file in the img folder, do the following:
page = 50
doc_name = 'Traite Justice VI'
for img in sorted(imgs_folder.rglob('*.jpg')):
    # Announce the current working file
    print(f'Renaming {img.name}')
    
    # For each image object:
    if page < 10:
        old_name = f'{img_folder}/{img.name}'
        new_name = f'{img_folder}/{doc_name}_image_000{str(page)}.jpg'
        os.rename (old_name, new_name)
    elif page < 100:
        old_name = f'{img_folder}/{img.name}'
        new_name = f'{img_folder}/{doc_name}_image_00{str(page)}.jpg'
        os.rename (old_name, new_name)
    elif page < 1000:
        old_name = f'{img_folder}/{img.name}'
        new_name = f'{img_folder}/{doc_name}_image_0{str(page)}.jpg'
        os.rename (old_name, new_name)
    else:
        old_name = f'{img_folder}/{img.name}'
        new_name = f'{img_folder}/{doc_name}_image_{str(page)}.jpg'
        os.rename (old_name, new_name)
    page = page + 1

print('All images renamed')
# Out:
# Renaming Traite Justice VI-2_image_0000.jpg
# Renaming Traite Justice VI-2_image_0001.jpg
# Renaming Traite Justice VI-2_image_0002.jpg
# Renaming Traite Justice VI-2_image_0003.jpg
# Renaming Traite Justice VI-2_image_0004.jpg
# Renaming Traite Justice VI-2_image_0005.jpg
# Renaming Traite Justice VI-2_image_0006.jpg
# Renaming Traite Justice VI-2_image_0007.jpg
# Renaming Traite Justice VI-2_image_0008.jpg
# Renaming Traite Justice VI-2_image_0009.jpg
# Renaming Traite Justice VI-2_image_0010.jpg
# Renaming Traite Justice VI-2_image_0011.jpg
# Renaming Traite Justice VI-2_image_0012.jpg
# Renaming Traite Justice VI-2_image_0013.jpg
# Renaming Traite Justice VI-2_image_0014.jpg
# Renaming Traite Justice VI-2_image_0015.jpg
# Renaming Traite Justice VI-2_image_0016.jpg
# Renaming Traite Justice VI-2_image_0017.jpg
# Renaming Traite Justice VI-2_image_0018.jpg
# Renaming Traite Justice VI-2_image_0019.jpg
# Renaming Traite Justice VI-2_image_0020.jpg
# ...

# %%
### Rename multiple image files ###
imgs_folder = Path("./L'Hospital Big 3/Traite Justice VI-3/images")
img_folder = "./L'Hospital Big 3/Traite Justice VI-3/images"
# For each img file in the img folder, do the following:
page = 100
doc_name = 'Traite Justice VI'
for img in sorted(imgs_folder.rglob('*.jpg')):
    # Announce the current working file
    print(f'Renaming {img.name}')
    
    # For each image object:
    if page < 10:
        old_name = f'{img_folder}/{img.name}'
        new_name = f'{img_folder}/{doc_name}_image_000{str(page)}.jpg'
        os.rename (old_name, new_name)
    elif page < 100:
        old_name = f'{img_folder}/{img.name}'
        new_name = f'{img_folder}/{doc_name}_image_00{str(page)}.jpg'
        os.rename (old_name, new_name)
    elif page < 1000:
        old_name = f'{img_folder}/{img.name}'
        new_name = f'{img_folder}/{doc_name}_image_0{str(page)}.jpg'
        os.rename (old_name, new_name)
    else:
        old_name = f'{img_folder}/{img.name}'
        new_name = f'{img_folder}/{doc_name}_image_{str(page)}.jpg'
        os.rename (old_name, new_name)
    page = page + 1

print('All images renamed')
# Out:
# Renaming Traite Justice VI-3_image_0000.jpg
# Renaming Traite Justice VI-3_image_0001.jpg
# Renaming Traite Justice VI-3_image_0002.jpg
# Renaming Traite Justice VI-3_image_0003.jpg
# Renaming Traite Justice VI-3_image_0004.jpg
# Renaming Traite Justice VI-3_image_0005.jpg
# Renaming Traite Justice VI-3_image_0006.jpg
# Renaming Traite Justice VI-3_image_0007.jpg
# Renaming Traite Justice VI-3_image_0008.jpg
# Renaming Traite Justice VI-3_image_0009.jpg
# Renaming Traite Justice VI-3_image_0010.jpg
# Renaming Traite Justice VI-3_image_0011.jpg
# Renaming Traite Justice VI-3_image_0012.jpg
# Renaming Traite Justice VI-3_image_0013.jpg
# Renaming Traite Justice VI-3_image_0014.jpg
# Renaming Traite Justice VI-3_image_0015.jpg
# Renaming Traite Justice VI-3_image_0016.jpg
# Renaming Traite Justice VI-3_image_0017.jpg
# Renaming Traite Justice VI-3_image_0018.jpg
# Renaming Traite Justice VI-3_image_0019.jpg
# Renaming Traite Justice VI-3_image_0020.jpg
# ...
