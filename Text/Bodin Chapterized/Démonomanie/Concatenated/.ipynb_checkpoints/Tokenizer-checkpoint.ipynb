# %%
from pathlib import Path
import glob
import os
import sys
import csv
import nltk
from collections import Counter
from nltk.tokenize import word_tokenize,wordpunct_tokenize
from nltk.collocations import BigramCollocationFinder, BigramAssocMeasures, TrigramCollocationFinder, TrigramAssocMeasures

import locale
# Set the locale to your desired setting (e.g., 'fr_FR.UTF-8' for French)
locale.setlocale(locale.LC_ALL, 'fr_FR.UTF-8')
# Out:
# 'fr_FR.UTF-8'

# %%
sys.path.append("/home/lucas-jerusalimiec/Documents/OCR Text/Notebooks")
from tokenizer_func  import (wordcleaner, write_words_to_file, dictionary_to_file, convert_tuple_bigrams,
convert_tuple_trigrams)

from extra_token_func import print_first_n_items, remove_keys_from_nested_dict

from additional_token_func import convert_strings_to_counts

from dict_write import write_dict_to_files_with_suffix

# %%
text_loc = Path("./final")
text_files = sorted(glob.glob(f"{text_loc}/*.txt"), key=locale.strxfrm)
output_folder = './tokenized/'
tokenized_folder = Path(output_folder)
tokenized_folder.mkdir(exist_ok=True)

output_unigram = f'{output_folder}unigram_counts'
unigram_folder = Path(output_unigram)
unigram_folder.mkdir(exist_ok=True)

output_bigram = f'{output_folder}bigram_counts'
bigram_folder = Path(output_bigram)
bigram_folder.mkdir(exist_ok=True)

output_trigram = f'{output_folder}trigram_counts'
trigram_folder = Path(output_trigram)
trigram_folder.mkdir(exist_ok=True)

output_collocation = f'{output_folder}collocation_counts'
collocation_folder = Path(output_collocation)
collocation_folder.mkdir(exist_ok=True)

output_trigram_collocation = f'{output_folder}trigram_collocation_counts'
trigram_collocation_folder = Path(output_trigram_collocation)
trigram_collocation_folder.mkdir(exist_ok=True)

output_underscore = f'{output_folder}underscore_bigrams'
underscore_folder = Path(output_underscore)
underscore_folder.mkdir(exist_ok=True)

output_trigram_underscore = f'{output_folder}underscore_trigrams'
trigram_underscore_folder = Path(output_trigram_underscore)
trigram_underscore_folder.mkdir(exist_ok=True)

print("Text files in the spellchecked directory:", text_files)
# Out:
# Text files in the spellchecked directory: ['final/Démonomanie I_corrected.txt', 'final/Démonomanie II_corrected.txt', 'final/Démonomanie III_corrected.txt', 'final/Démonomanie IV_corrected.txt', 'final/Démonomanie preface Repair_corrected.txt']

# %%
# Open stopwords CSV file and list the contents
with open('./stop_words.csv', 'r') as f:
    stopwords = f.read().strip().split(",")
stopwords[-10:]
# Out:
# ['ue', 'ung', 'v', 'vingt', 'vn', 'vne', 'vnes', 'w', 'x', 'ya']

# %%
tokenized_texts = {}
for txt in text_files:
    with open(txt, 'r') as f:
        content = f.read()
        file_name = txt.split('\\')[-1]
        #key = file_name.split('.')[0]
        key = os.path.splitext(os.path.basename(file_name))[0]
        tokenized_texts[key] = content
print("Raw texts:", list(tokenized_texts.keys()))
# Out:
# Raw texts: ['Démonomanie I_corrected', 'Démonomanie II_corrected', 'Démonomanie III_corrected', 'Démonomanie IV_corrected', 'Démonomanie preface Repair_corrected']

# %%
unigrams = {}

for key, value in tokenized_texts.items():
    unigram_list = wordpunct_tokenize(value)
    cleanwords = [wordcleaner(w) for w in unigram_list]
    unigrams[key] = cleanwords

for key, value in unigrams.items():
    filename = f"./tokenized/{key}.txt"
    write_words_to_file(value, filename, words_per_line=20)
    print(f"Saved content for '{key}' to {filename}")
# Out:
# Saved content for 'Démonomanie I_corrected' to ./tokenized/Démonomanie I_corrected.txt
# Saved content for 'Démonomanie II_corrected' to ./tokenized/Démonomanie II_corrected.txt
# Saved content for 'Démonomanie III_corrected' to ./tokenized/Démonomanie III_corrected.txt
# Saved content for 'Démonomanie IV_corrected' to ./tokenized/Démonomanie IV_corrected.txt
# Saved content for 'Démonomanie preface Repair_corrected' to ./tokenized/Démonomanie preface Repair_corrected.txt

# %%
print("Unigram texts:")
for key in unigrams:
    print(key)
# Out:
# Unigram texts:
# Démonomanie I_corrected
# Démonomanie II_corrected
# Démonomanie III_corrected
# Démonomanie IV_corrected
# Démonomanie preface Repair_corrected

# %%
# Count up the tokens using a Counter() object
unigram_counts = {}
for key, value in unigrams.items():
    unigram_counts_dict = Counter(value)
    unigram_counts[key] = unigram_counts_dict

print("Unigram Counts:")
for key in unigram_counts:
    print(key)

print_first_n_items(unigram_counts, 25)
# Out:
# Unigram Counts:
# Démonomanie I_corrected
# Démonomanie II_corrected
# Démonomanie III_corrected
# Démonomanie IV_corrected
# Démonomanie preface Repair_corrected
# First 25 items in Démonomanie I_corrected:
# : 8961
# de: 693
# que: 442
# les: 423
# il: 380
# qui: 358
# la: 339
# en: 330
# des: 328
# qu: 321
# l: 311
# le: 271
# à: 264
# dieu: 263
# eft: 245
# d: 211
# pour: 174
# par: 171
# a: 160
# ce: 156
# comme: 150
# n: 145
# du: 145
# c: 138
# ne: 133
#
# First 25 items in Démonomanie II_corrected:
# : 13497
# de: 877
# que: 543
# en: 494
# qu: 490
# à: 451
# les: 420
# qui: 419
# la: 415
# d: 413
# il: 410
# l: 361
# le: 340
# des: 286
# a: 252
# eft: 206
# vn: 201
# c: 197
# n: 186
# par: 186
# pour: 182
# on: 169
# ce: 167
# e: 165
# dieu: 161
#
# First 25 items in Démonomanie III_corrected:
# : 6797
# de: 655
# que: 391
# qu: 384
# en: 370
# il: 354
# les: 335
# la: 327
# qui: 306
# d: 267
# le: 266
# à: 263
# l: 225
# des: 199
# ne: 183
# vn: 163
# eft: 158
# on: 147
# pour: 144
# par: 134
# ce: 131
# n: 130
# a: 126
# dieu: 125
# c: 114
#
# First 25 items in Démonomanie IV_corrected:
# : 11060
# de: 881
# la: 412
# que: 398
# d: 349
# qui: 338
# qu: 335
# il: 300
# les: 291
# l: 286
# en: 276
# eft: 271
# le: 266
# à: 265
# c: 219
# des: 203
# a: 186
# ne: 184
# n: 176
# ou: 169
# pour: 165
# s: 160
# ce: 154
# par: 144
# on: 143
#
# First 25 items in Démonomanie preface Repair_corrected:
# : 2359
# de: 225
# les: 159
# qu: 143
# en: 130
# que: 129
# la: 113
# des: 112
# qui: 112
# il: 104
# à: 98
# d: 95
# l: 82
# le: 76
# a: 65
# ne: 55
# pour: 55
# on: 55
# au: 50
# eft: 50
# par: 49
# sorciers: 48
# ce: 48
# n: 45
# elle: 44

# %%
# Remove specified keys from the dictionary
stripped_unigrams = remove_keys_from_nested_dict(unigram_counts, stopwords)

print_first_n_items(stripped_unigrams, 30)
# Out:
# First 30 items in Démonomanie I_corrected:
# : 8961
# dieu: 263
# bien: 83
# quand: 55
# premier: 54
# choses: 50
# chose: 49
# sorciers: 49
# dire: 47
# faire: 47
# fort: 46
# hommes: 44
# esprits: 42
# monde: 37
# anges: 35
# entre: 35
# mot: 34
# nature: 34
# esprit: 33
# faut: 32
# non: 29
# hebrieux: 29
# void: 27
# homme: 26
# grand: 26
# pourquoy: 25
# moyens: 24
# foit: 24
# efcripture: 23
# bons: 23
#
# First 30 items in Démonomanie II_corrected:
# : 13497
# dieu: 161
# sorciers: 101
# diable: 94
# bien: 82
# faire: 62
# hommes: 52
# corps: 51
# quand: 44
# sathan: 42
# plusieurs: 40
# dire: 37
# chose: 34
# homme: 34
# grand: 31
# non: 30
# faut: 30
# veu: 30
# mort: 30
# fort: 29
# esprit: 28
# cela: 28
# quil: 27
# paroles: 27
# choses: 26
# sorciere: 26
# sorcier: 25
# an: 25
# toute: 25
# lieu: 25
#
# First 30 items in Démonomanie III_corrected:
# : 6797
# dieu: 125
# sorciers: 93
# sathan: 74
# bien: 59
# diable: 57
# faire: 50
# sorcier: 39
# mal: 34
# veu: 30
# contre: 29
# dire: 29
# plusieurs: 28
# an: 27
# fin: 27
# quand: 26
# sorciere: 26
# esprit: 26
# esprits: 25
# faut: 25
# quelques: 25
# hommes: 24
# vie: 23
# cela: 22
# mort: 21
# malings: 21
# grand: 21
# moyen: 20
# void: 19
# non: 19
#
# First 30 items in Démonomanie IV_corrected:
# : 11060
# dieu: 99
# sorciers: 91
# bien: 71
# mort: 70
# faut: 62
# faire: 55
# doit: 49
# preuve: 45
# peine: 45
# loy: 44
# crime: 44
# foit: 39
# cas: 37
# contre: 37
# quand: 36
# diable: 34
# sorcier: 33
# non: 32
# crimes: 31
# con: 30
# verité: 29
# mourir: 29
# sathan: 28
# dire: 27
# cy: 26
# ff: 25
# ad: 24
# plusieurs: 24
# deuant: 23
#
# First 30 items in Démonomanie preface Repair_corrected:
# : 2359
# sorciers: 48
# dieu: 30
# choses: 25
# corps: 22
# faire: 20
# bien: 18
# aristote: 18
# lieu: 17
# veu: 17
# esprits: 17
# contre: 15
# diable: 14
# homme: 13
# sorcieres: 13
# cens: 12
# nature: 12
# faut: 12
# plusieurs: 11
# grand: 11
# monde: 11
# forme: 10
# mort: 10
# toute: 10
# caufe: 10
# cieux: 10
# voit: 10
# dire: 10
# mil: 9
# hommes: 9

# %%
dictionary_to_file(stripped_unigrams, unigram_folder, 'unigram_counts')
# Out:
# Saved Démonomanie I_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved Démonomanie II_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved Démonomanie III_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved Démonomanie IV_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved Démonomanie preface Repair_corrected_unigram_counts.csv in tokenized/unigram_counts

# %%
bigrams = {}

for key, value in unigrams.items():
    unigram_list = [word for word in value if word.lower() not in stopwords]
    #unigram_list = [word for word in value]
    bigrams_list = list(nltk.bigrams(unigram_list))
    bigrams[key] = bigrams_list

print("Bigrams:")
for key in bigrams:
    print(key)
# Out:
# Bigrams:
# Démonomanie I_corrected
# Démonomanie II_corrected
# Démonomanie III_corrected
# Démonomanie IV_corrected
# Démonomanie preface Repair_corrected

# %%
bigram_counts = {}

for key, value in bigrams.items():
    string_bigrams = convert_tuple_bigrams(value)
    bigramCount = convert_strings_to_counts(string_bigrams)
    bigram_counts[key] = bigramCount

print("Bigram Counts:")
for key in bigram_counts:
    print(key)

print_first_n_items(bigram_counts, 30)
# Out:
# Bigram Counts:
# Démonomanie I_corrected
# Démonomanie II_corrected
# Démonomanie III_corrected
# Démonomanie IV_corrected
# Démonomanie preface Repair_corrected
# First 30 items in Démonomanie I_corrected:
# malins esprits: 15
# eftà dire: 7
# telles choses: 7
# moyens diaboliques: 6
# œuures dieu: 6
# loy dieu: 6
# corps celeftes: 5
# conseil dieu: 5
# ange dieu: 5
# faut donc: 5
# dieu parle: 4
# faire chose: 4
# mot hebrieu: 4
# bien mal: 4
# paruenir chose: 4
# cas pareil: 4
# parle moyen: 4
# face face: 4
# moyens naturels: 4
# cours nature: 4
# moyens illicites: 4
# malings esprits: 3
# maiftre sorcier: 3
# grand leuiathan: 3
# monde elementaire: 3
# efcripture faincte: 3
# moyés diaboliques: 3
# laloy dieu: 3
# fix cens: 3
# homme bien: 3
#
# First 30 items in Démonomanie II_corrected:
# cas pareil: 11
# malins esprits: 10
# bien fort: 6
# quelques paroles: 5
# loy dieu: 5
# faire mourir: 5
# figure humaine: 5
# bien voulu: 4
# corps celeftes: 4
# eten cas: 4
# parce moyen: 4
# genre humain: 4
# long temps: 4
# parties honteufes: 4
# dieu permet: 4
# grand nombre: 4
# cité dieu: 4
# pendu paris: 3
# beaucoup moins: 3
# eftà dire: 3
# ieune enfant: 3
# laloy dieu: 3
# petits enfans: 3
# difant quelques: 3
# bien noter: 3
# vertu paroles: 3
# non feulement: 3
# nom dieu: 3
# enlaloy dieu: 3
# parole dieu: 3
#
# First 30 items in Démonomanie III_corrected:
# malings esprits: 13
# an mil: 9
# malins esprits: 6
# mil cinq: 6
# maling esprit: 6
# loy dieu: 5
# cinq cens: 5
# prier dieu: 5
# sorciers peuuent: 5
# cy dessus: 5
# mal caduc: 5
# gens bien: 4
# premiere heure: 4
# dieu donne: 4
# faire mourir: 4
# malin esprit: 4
# esprit dieu: 4
# cy deffus: 3
# vray dire: 3
# bien fort: 3
# quelques vns: 3
# cens cinquante: 3
# faire mal: 3
# soleil couché: 3
# mieux dire: 3
# peuuent faire: 3
# cas pareil: 3
# quelques fois: 3
# quelques parolles: 3
# faifant quelques: 3
#
# First 30 items in Démonomanie IV_corrected:
# loy dieu: 12
# auons monftré: 6
# faut donc: 6
# cy deffus: 6
# dire verité: 5
# cy dessus: 5
# ville laon: 4
# quelques vns: 4
# cas pareil: 4
# faire mourir: 4
# faut faire: 4
# mis mort: 4
# és crimes: 4
# crime lefe: 4
# premiere fois: 4
# bien fouuent: 3
# ire dieu: 3
# princes sorciers: 3
# faiét mourir: 3
# bien fort: 3
# prendre garde: 3
# enla loy: 3
# doit proceder: 3
# foit mis: 3
# cas ciuil: 3
# non feulement: 3
# tué pere: 3
# peine capitale: 3
# contre nature: 3
# presomption droit: 3
#
# First 30 items in Démonomanie preface Repair_corrected:
# contre sorciers: 5
# malings esprits: 5
# auoient veu: 4
# choses naturelles: 4
# mil cinq: 3
# cinq cens: 3
# prince mirande: 3
# rendre raifon: 3
# choses fupernaturelles: 3
# images cire: 3
# cens quarante: 3
# cens feptante: 2
# plusieurs fois: 2
# homme noir: 2
# peines eftablies: 2
# faire entédre: 2
# fois forme: 2
# brufler sorciers: 2
# diét loy: 2
# mort contre: 2
# grand nombre: 2
# decerne peines: 2
# peines contre: 2
# meuuentles cieux: 2
# malins esprits: 2
# non toutesfois: 2
# esprit humain: 2
# cas pareil: 2
# merueilles dieu: 2
# voudroit nyer: 2

# %%
dictionary_to_file(bigram_counts, bigram_folder, 'bigram_counts')
# Out:
# Saved Démonomanie I_corrected_bigram_counts.csv in tokenized/bigram_counts
# Saved Démonomanie II_corrected_bigram_counts.csv in tokenized/bigram_counts
# Saved Démonomanie III_corrected_bigram_counts.csv in tokenized/bigram_counts
# Saved Démonomanie IV_corrected_bigram_counts.csv in tokenized/bigram_counts
# Saved Démonomanie preface Repair_corrected_bigram_counts.csv in tokenized/bigram_counts

# %%
trigrams = {}

for key, value in unigrams.items():
    unigram_list = [word for word in value if word.lower() not in stopwords]
    #unigram_list = [word for word in value]
    trigrams_list = list(nltk.trigrams(unigram_list))
    trigrams[key] = trigrams_list

print("Trigrams:")
for key in bigrams:
    print(key)
# Out:
# Trigrams:
# Démonomanie I_corrected
# Démonomanie II_corrected
# Démonomanie III_corrected
# Démonomanie IV_corrected
# Démonomanie preface Repair_corrected

# %%
trigram_counts = {}

for key, value in trigrams.items():
    string_trigrams = convert_tuple_trigrams(value)
    trigramCount = convert_strings_to_counts(string_trigrams)
    trigram_counts[key] = trigramCount

print("Trigram Counts:")
for key in trigram_counts:
    print(key)
    
print_first_n_items(trigram_counts, 30)
# Out:
# Trigram Counts:
# Démonomanie I_corrected
# Démonomanie II_corrected
# Démonomanie III_corrected
# Démonomanie IV_corrected
# Démonomanie preface Repair_corrected
# First 30 items in Démonomanie I_corrected:
# eren cas pareil: 2
# pana non attraxerit: 2
# dieu face face: 2
# come voyoit yeux: 2
# demandoient conseil dieu: 2
# difpofition naturelle corps: 2
# demandé conseil dieu: 2
# defendu parlaloy dieu: 2
# parla loy dieu: 2
# outre cours nature: 2
# és orrcer eftceluy: 1
# orrcer eftceluy moyens: 1
# eftceluy moyens tns: 1
# su parucnir chose: 1
# pofe ye definition: 1
# ye definition neceflaire: 1
# definition neceflaire feu: 1
# neceflaire feu rd: 1
# nonfeulémentpour entédre trai: 1
# ainsauffi pourles iugemensque: 1
# pourles iugemensque fault: 1
# iugemensque fault rendre: 1
# fault rendre contre: 1
# rendre contre sorciers: 1
# quia cl é: 1
# cl é ob: 1
# lesicy detous cfcript: 1
# detous cfcript sorciers: 1
# fondement lequel faut: 1
# lequel faut baftirce: 1
#
# First 30 items in Démonomanie II_corrected:
# eten cas pareil: 3
# lay bien voulu: 2
# difant quelques paroles: 2
# bruflée toute vifue: 2
# bruflee toute viue: 2
# disons donc impofturesdiaboliques: 1
# á pé ot: 1
# pé ot magie: 1
# ot magie perfique: 1
# science choses diuines: 1
# fophiea eftéadulteree lessophiftes: 1
# sageffe don dieu: 1
# aufft magie efté: 1
# magie efté tournee: 1
# efté tournee sorcelerie: 1
# tournee sorcelerie diabolique: 1
# premier miniftre sathan: 1
# miniftre sathan publier: 1
# sathan publier cesteimpieté: 1
# publier cesteimpieté perle: 1
# neantmoins couuerte voile: 1
# couuerte voile pieté: 1
# commele diable couftumier: 1
# diable couftumier faire: 1
# bien nez toufiours: 1
# nez toufiours horreur: 1
# toufiours horreur mefchance: 1
# sorciers ximam fuiffe: 1
# ximam fuiffe nemo: 1
# fuiffe nemo miretur: 1
#
# First 30 items in Démonomanie III_corrected:
# an mil cinq: 6
# mil cinq cens: 4
# faire amende honorable: 2
# cinq cens cinquante: 2
# chafler malins esprits: 2
# ét ooly bon: 1
# ooly bon nsp: 1
# ib ve pie: 1
# ve pie nes: 1
# pie nes hiftoiresnous: 1
# nes hiftoiresnous apprennent: 1
# hiftoiresnous apprennent ec: 1
# apprennent ec sorcelleries: 1
# ec sorcelleries nouucle: 1
# ge sk maladies: 1
# an no anciennement: 1
# no anciennement cent: 1
# anciennement cent tir: 1
# cent tir ex: 1
# tir ex vi: 1
# vs iab loy: 1
# iab loy dedieu: 1
# quieft publiecjil enuiron: 1
# publiecjil enuiron trois: 1
# enuiron trois mil: 1
# nb hiftoiresion void: 1
# hiftoiresion void hays: 1
# eftoient ja remplis: 1
# ja remplis vermine: 1
# peines rigoureufes ordon: 1
#
# First 30 items in Démonomanie IV_corrected:
# contre majefté dieu: 3
# an mil cinq: 3
# foit mis mort: 2
# crime lefe maicfté: 2
# deuant plusieurs perfonnes: 2
# crime lefe majefté: 2
# diminuer nombre mefchans: 2
# età propos difoit: 2
# mil cinq cens: 2
# peine léfe majefté: 2
# sil cust fouffert: 1
# cust fouffert grand: 1
# fouffert grand doüleur: 1
# onfift dire grand: 1
# dire grand nobre: 1
# grand nobre meffes: 1
# reuclant bcaucoup choses: 1
# bcaucoup choses occul: 1
# maisonluy dif fitu: 1
# dif fitu veus: 1
# miferere mei deus: 1
# mei deus fecundàm: 1
# deus fecundàm magnam: 1
# fecundàm magnam mifericor: 1
# magnam mifericor diam: 1
# mifericor diam tuam: 1
# niqyisition id oe: 1
# id oe oor: 1
# oe oor cie: 1
# oor cie rs: 1
#
# First 30 items in Démonomanie preface Repair_corrected:
# mil cinq cens: 3
# decerne peines contre: 2
# peines contre sorciers: 2
# cent cens lieues: 2
# dr oaj oe: 1
# oaj oe io: 1
# oe io per: 1
# io per tn: 1
# per tn bodin: 1
# ere br tref: 1
# vgementquiaefte conclud contre: 1
# conclud contre td: 1
# contre td sorciere: 1
# td sorciere auquel: 1
# sorciere auquel appellé: 1
# auquel appellé dernier: 1
# appellé dernier jour: 1
# auril mil cinq: 1
# cinq cens feptante: 1
# donné occafion mettre: 1
# occafion mettre main: 1
# mettre main plume: 1
# main plume mla: 1
# plume mla elclarcir: 1
# mla elclarcir fubie: 1
# vue ble routes: 1
# ble routes perfonnes: 1
# routes perfonnes eftrangeà: 1
# perfonnes eftrangeà merueilles: 1
# sek plufreurs incroyable: 1

# %%
dictionary_to_file(trigram_counts, trigram_folder, 'trigram_counts')
# Out:
# Saved Démonomanie I_corrected_trigram_counts.csv in tokenized/trigram_counts
# Saved Démonomanie II_corrected_trigram_counts.csv in tokenized/trigram_counts
# Saved Démonomanie III_corrected_trigram_counts.csv in tokenized/trigram_counts
# Saved Démonomanie IV_corrected_trigram_counts.csv in tokenized/trigram_counts
# Saved Démonomanie preface Repair_corrected_trigram_counts.csv in tokenized/trigram_counts

# %%
colloc_dict = {}
colloc_counts = {}

for key, value in unigrams.items():
    unigram_list = [word for word in value if word.lower() not in stopwords]
    bigram_finder = BigramCollocationFinder.from_words(unigram_list)
    bigram_finder.apply_freq_filter(3)  # Make sure all collocations have occurred at least 5 times
    collocations = bigram_finder.nbest(BigramAssocMeasures.pmi, 500)
    filtered_collocations = [bigram for bigram in collocations if '' not in bigram]
    colloc_dict[key] = filtered_collocations
    
    # Initialize Counter for colloc_counts
    bigram_count_dict = Counter()

    # Count the occurrences of each bigram in the text
    bigram_finder = BigramCollocationFinder.from_words(unigram_list)
    bigram_freqs = bigram_finder.ngram_fd.items()
    
    # Filter bigram counts based on collocations
    for bigram, count in bigram_freqs:
        if bigram in filtered_collocations:
            bigram_count_dict[bigram] = count

    colloc_counts[key] = bigram_count_dict

print("Collocations:")
for key, value in colloc_dict.items():
    print(key)
    # for w1, w2 in value:
    #     print(' ', w1, w2)

print("Collocation Counts:")
for key in colloc_counts:
    print(key)
    # Print first n items, assuming print_first_n_items function is defined elsewhere
    for item, count in colloc_counts[key].most_common(30):
        bigram = " ".join(item)
        print(f"{bigram} {count}")
    print()

dictionary_to_file(colloc_counts, collocation_folder, 'collocation_counts')
# Out:
# Collocations:
# Démonomanie I_corrected
# Démonomanie II_corrected
# Démonomanie III_corrected
# Démonomanie IV_corrected
# Démonomanie preface Repair_corrected
# Collocation Counts:
# Démonomanie I_corrected
# malins esprits 15
# eftà dire 7
# telles choses 7
# moyens diaboliques 6
# œuures dieu 6
# loy dieu 6
# corps celeftes 5
# conseil dieu 5
# ange dieu 5
# faut donc 5
# dieu parle 4
# faire chose 4
# mot hebrieu 4
# bien mal 4
# paruenir chose 4
# cas pareil 4
# parle moyen 4
# face face 4
# moyens naturels 4
# cours nature 4
# moyens illicites 4
# malings esprits 3
# maiftre sorcier 3
# grand leuiathan 3
# monde elementaire 3
# efcripture faincte 3
# moyés diaboliques 3
# laloy dieu 3
# fix cens 3
# homme bien 3
#
# Démonomanie II_corrected
# cas pareil 11
# malins esprits 10
# bien fort 6
# quelques paroles 5
# loy dieu 5
# faire mourir 5
# figure humaine 5
# bien voulu 4
# corps celeftes 4
# eten cas 4
# parce moyen 4
# genre humain 4
# long temps 4
# parties honteufes 4
# dieu permet 4
# grand nombre 4
# cité dieu 4
# pendu paris 3
# beaucoup moins 3
# eftà dire 3
# ieune enfant 3
# laloy dieu 3
# petits enfans 3
# difant quelques 3
# bien noter 3
# vertu paroles 3
# non feulement 3
# nom dieu 3
# enlaloy dieu 3
# parole dieu 3
#
# Démonomanie III_corrected
# malings esprits 13
# an mil 9
# malins esprits 6
# mil cinq 6
# maling esprit 6
# loy dieu 5
# cinq cens 5
# prier dieu 5
# sorciers peuuent 5
# cy dessus 5
# mal caduc 5
# gens bien 4
# premiere heure 4
# dieu donne 4
# faire mourir 4
# malin esprit 4
# esprit dieu 4
# cy deffus 3
# vray dire 3
# bien fort 3
# quelques vns 3
# cens cinquante 3
# faire mal 3
# soleil couché 3
# mieux dire 3
# peuuent faire 3
# cas pareil 3
# quelques fois 3
# quelques parolles 3
# faifant quelques 3
#
# Démonomanie IV_corrected
# loy dieu 12
# auons monftré 6
# faut donc 6
# cy deffus 6
# dire verité 5
# cy dessus 5
# ville laon 4
# quelques vns 4
# cas pareil 4
# faire mourir 4
# faut faire 4
# mis mort 4
# és crimes 4
# crime lefe 4
# premiere fois 4
# bien fouuent 3
# ire dieu 3
# princes sorciers 3
# faiét mourir 3
# bien fort 3
# prendre garde 3
# enla loy 3
# doit proceder 3
# foit mis 3
# cas ciuil 3
# non feulement 3
# tué pere 3
# peine capitale 3
# contre nature 3
# presomption droit 3
#
# Démonomanie preface Repair_corrected
# contre sorciers 5
# malings esprits 5
# auoient veu 4
# choses naturelles 4
# mil cinq 3
# cinq cens 3
# prince mirande 3
# rendre raifon 3
# choses fupernaturelles 3
# images cire 3
# cens quarante 3
#
# Saved Démonomanie I_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved Démonomanie II_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved Démonomanie III_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved Démonomanie IV_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved Démonomanie preface Repair_corrected_collocation_counts.csv in tokenized/collocation_counts

# %%
trigram_colloc_dict = {}
trigram_colloc_counts = {}

for key, value in unigrams.items():
    unigram_list = [word for word in value if word.lower() not in stopwords]
    trigram_finder = TrigramCollocationFinder.from_words(unigram_list)
    trigram_finder.apply_freq_filter(3)  # Ensure all collocations have occurred at least 5 times
    collocations = trigram_finder.nbest(TrigramAssocMeasures.pmi, 500)
    filtered_collocations = [trigram for trigram in collocations if '' not in trigram]
    trigram_colloc_dict[key] = filtered_collocations
    
    # Initialize Counter for trigram_colloc_counts
    trigram_count_dict = Counter()

    # Count the occurrences of each trigram in the text
    trigram_freqs = trigram_finder.ngram_fd.items()
    
    # Filter trigram counts based on collocations
    for trigram, count in trigram_freqs:
        if trigram in filtered_collocations:
            trigram_count_dict[trigram] = count

    trigram_colloc_counts[key] = trigram_count_dict

print("Trigram Collocations:")
for key, value in trigram_colloc_dict.items():
    print(key)
    #for w1, w2, w3 in value:
    #    print(' ', w1, w2, w3)

print("Trigram Collocation Counts:")
for key in trigram_colloc_counts:
    print(key)
    # Print first n items, assuming print_first_n_items function is defined elsewhere
    for item, count in trigram_colloc_counts[key].most_common(30):
        trigram = " ".join(item)
        print(f"{trigram} {count}")
    print()

dictionary_to_file(trigram_colloc_counts, trigram_collocation_folder, 'trigram_collocation_counts')
# Out:
# Trigram Collocations:
# Démonomanie I_corrected
# Démonomanie II_corrected
# Démonomanie III_corrected
# Démonomanie IV_corrected
# Démonomanie preface Repair_corrected
# Trigram Collocation Counts:
# Démonomanie I_corrected
#
# Démonomanie II_corrected
# eten cas pareil 3
#
# Démonomanie III_corrected
# an mil cinq 6
# mil cinq cens 4
#
# Démonomanie IV_corrected
# contre majefté dieu 3
# an mil cinq 3
#
# Démonomanie preface Repair_corrected
# mil cinq cens 3
#
# Saved Démonomanie I_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved Démonomanie II_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved Démonomanie III_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved Démonomanie IV_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved Démonomanie preface Repair_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts

# %%
underscore_dict = {}
for key, value in unigrams.items():

    tokenized_words = unigrams.get(key)
    collocations = colloc_dict.get(key)
    
    colloc_words = []
    
    # Iterate through the words making new versions combining collocations
    i = 0
    while i < len(tokenized_words) - 1:
        # If we find a collocation, add and advance by two words
        if (tokenized_words[i], tokenized_words[i + 1]) in collocations:
            colloc_words.append('_'.join((tokenized_words[i], tokenized_words[i + 1])))
            i += 2
        # Otherwise, advance by one word
        else:
            colloc_words.append(tokenized_words[i])
            i += 1

    # Add the last word (if any)
    if i == len(tokenized_words) - 1:
        colloc_words.append(tokenized_words[i])
    underscore_dict[key] = colloc_words

print("Underscore Dictionary:")
for key in underscore_dict:
    print(key)

write_dict_to_files_with_suffix(underscore_dict, underscore_folder, 'underscore_bigrams')
# Out:
# Underscore Dictionary:
# Démonomanie I_corrected
# Démonomanie II_corrected
# Démonomanie III_corrected
# Démonomanie IV_corrected
# Démonomanie preface Repair_corrected
# Démonomanie I_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# Démonomanie II_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# Démonomanie III_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# Démonomanie IV_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# Démonomanie preface Repair_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams

# %%
trigram_underscore_dict = {}

for key, tokenized_words in unigrams.items():
    collocations = trigram_colloc_dict.get(key, [])
    colloc_words = []
    i = 0
    while i < len(tokenized_words) - 2:
        # If we find a trigram collocation, add and advance by three words
        trigram = (tokenized_words[i], tokenized_words[i + 1], tokenized_words[i + 2])
        if trigram in collocations:
            colloc_words.append('_'.join(trigram))
            i += 3
        else:
            colloc_words.append(tokenized_words[i])
            i += 1
    # Add the last words (if any)
    while i < len(tokenized_words):
        colloc_words.append(tokenized_words[i])
        i += 1
    trigram_underscore_dict[key] = colloc_words

print("Trigram underscore Dictionary:")
for key in trigram_underscore_dict:
    print(key)

write_dict_to_files_with_suffix(trigram_underscore_dict, trigram_underscore_folder, 'underscore_trigrams')
# Out:
# Trigram underscore Dictionary:
# Démonomanie I_corrected
# Démonomanie II_corrected
# Démonomanie III_corrected
# Démonomanie IV_corrected
# Démonomanie preface Repair_corrected
# Démonomanie I_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# Démonomanie II_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# Démonomanie III_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# Démonomanie IV_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# Démonomanie preface Repair_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
