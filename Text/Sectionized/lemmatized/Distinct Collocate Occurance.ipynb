# %%
import os
import csv
import nltk
from scipy.stats import fisher_exact
from openpyxl import Workbook, load_workbook
from itertools import combinations
from collections import Counter

# Function to prompt the user to select text files based on patterns
def prompt_pattern_files(text_files, pattern):
    selected_files = [file for file in text_files if file.startswith(pattern)]
    return selected_files

def generate_keyword_pairs(predefined_words):
    """
    Generate all possible combinations of keyword pairs from the predefined word list.
    """
    return list(combinations(predefined_words, 2))

def prompt_files(text_files, purpose):
    text_files = sorted(text_files, key=custom_file_sort_key)  # Custom sort for files
    print(f"Select the files for {purpose}:")
    for i, file in enumerate(text_files, start=1):
        print(f"{i}. {file}")
    
    selection = input("Enter the number of the file, a range (e.g., 1-3), multiple ranges (e.g., 1-3,5-7), a text pattern to select files, or type 'all' to select all files: ").strip()
    selected_files = []
    
    if selection.lower() == 'all':
        selected_files = text_files
    else:
        # Split the input by commas to handle multiple ranges or numbers
        parts = selection.split(',')
        for part in parts:
            part = part.strip()
            if '-' in part:  # If the part is a range
                try:
                    start, end = map(int, part.split('-'))
                    selected_files.extend(text_files[start-1:end])
                except ValueError:
                    print(f"Invalid range: {part}. Please provide ranges like '1-3'.")
            elif part.isdigit():  # If the part is a single number
                try:
                    selected_files.append(text_files[int(part) - 1])
                except IndexError:
                    print(f"Invalid number: {part}. Please select numbers from the list.")
            else:  # If the part is treated as a pattern
                selected_files.extend(prompt_pattern_files(text_files, part))
    
    # Remove duplicates and sort the selected files
    selected_files = sorted(set(selected_files), key=custom_file_sort_key)
    
    print("Selected files:")
    for file in selected_files:
        print(file)
    
    return selected_files

# Custom sort key for file names
def custom_file_sort_key(filename):
    # Prioritize 'preface' higher than patterns like 'I.1'
    if 'preface' in filename.lower():
        return ('', filename.lower())  # Sort 'preface' first
    return (filename.lower(),)

# Function to process text files
def process_text_files(file_paths):
    combined_text = ""
    for file_path in file_paths:
        with open(file_path, 'r', encoding='utf-8') as file:
            combined_text += file.read().lower() + " "
    tokens = nltk.wordpunct_tokenize(combined_text)
    return nltk.Text(tokens)

# Function to find .txt files in a directory
def find_text_files(directory):
    return sorted([f for f in os.listdir(directory) if f.endswith('.txt')], key=custom_file_sort_key)  # Custom sort

# Function to list subfolders in the current directory
def list_subfolders():
    return sorted([f.name for f in os.scandir() if f.is_dir()])  # Sort folders alphabetically

# Function to prompt the user to select a subfolder or the current directory
def prompt_subfolder(subfolders):
    print("Select a subfolder or the current working directory:")
    print("0. Current Working Directory")
    for i, subfolder in enumerate(subfolders, start=1):
        print(f"{i}. {subfolder}")
    selected_index = int(input("Enter the number of the subfolder: "))
    return None if selected_index == 0 else subfolders[selected_index - 1]

# Function to get predefined target words
def get_predefined_target_words():
    return [
        ['citoyen', 'cour', 'domain', 'ressort'],  # List 1
        ['guerr', 'paix', 'police', 'religion'],  # List 2
        ['confess', 'demon', 'demoniaqu', 'diabl',
         'diabol', 'dieu', 'divin', 
        'hebrieu', 'impiet', 'preuv', 'question',   'sathan', 
        'sorceller', 'sorci',  'statut', 'sujet'],  # List 3
        ['arrest',  'conseil', 'conseiller', 'consul', 
         'couron', 'édict', 'iurisdict', 'jug', 'magistrat',
         'offic', 'offici', 'ordon', 'parlement',
        'seigneur', 'seigneurial', 'statut'],  # List 4
        ['absolu', 'bien', 'chos', 'civil', 'droit', 'estat', 'just', 'justic',
         'loi', 'maiest', 'princ', 'puissanc',
        'republ', 'roy', 'royal', 'royaum', 'souverain', 'souverainet', 'sujet']  # List 5
    ]

# Function to choose subdirectory for stopwords csv file
def choose_subdirectory(subdirectories):
    print("Select a subdirectory:")
    print("0. Current Working Directory")
    for i, subdir in enumerate(subdirectories, start=1):
        print(f"{i}. {subdir}")
    while True:
        try:
            choice = int(input("Enter your choice: "))
            if 0 <= choice <= len(subdirectories):
                return None if choice == 0 else subdirectories[choice - 1]
            else:
                print("Invalid selection. Please try again.")
        except ValueError:
            print("Please enter a number.")

# Function to read stopwords from a csv file
def read_stopwords(filepath):
    with open(filepath, 'r', encoding='utf-8') as file:
        reader = csv.reader(file)
        stopwords = []
        for row in reader:
            for word in row:
                stopwords.extend(word.split(','))
        return [word.strip() for word in stopwords]

# Function to find .csv files in a directory
def find_csv_files(directory):
    return sorted([f for f in os.listdir(directory) if f.endswith('.csv')])  # Sort files alphabetically

# Function to select files for the stopwords
def select_stopwords_file():
    print('Stopwords file selection')
    stopwords_subfolders = list_subfolders()
    selected_stopwords_subfolder = choose_subdirectory(stopwords_subfolders)
    
    # Check if the user selected a subfolder or the current directory
    stopwords_subfolder_path = os.getcwd() if selected_stopwords_subfolder is None else os.path.join(os.getcwd(), selected_stopwords_subfolder)
    
    # Find .csv files in the selected directory
    stopwords_files = find_csv_files(stopwords_subfolder_path)
    if stopwords_files:
        print('Select a stopwords file from the following list:')
        # Prompt the user to select a single .csv file
        selected_file = prompt_files(stopwords_files, "stopwords file")
        if selected_file:
            return selected_file[0], stopwords_subfolder_path  # Return the first selected file and its path
        else:
            print("No stopwords file selected.")
            return None, None
    else:
        print(f"No .csv stopwords files found in '{selected_stopwords_subfolder}'.")
        return None, None

# Function to select files for the rate dictionary
def select_rate_dictionary_files():
    print('Rate dictionary file selection')
    rate_dictionary_subfolders = list_subfolders()
    selected_rate_dictionary_subfolder = choose_subdirectory(rate_dictionary_subfolders)
    
    # Check if the user selected a subfolder or the current directory
    rate_dictionary_subfolder_path = os.getcwd() if selected_rate_dictionary_subfolder is None else os.path.join(os.getcwd(), selected_rate_dictionary_subfolder)
    
    # Find .txt files in the selected directory
    rate_dictionary_files = find_text_files(rate_dictionary_subfolder_path)
    if rate_dictionary_files:
        print('Select one or more rate dictionary files from the following list:')
        selected_files = prompt_files(rate_dictionary_files, "rate dictionary")
        if selected_files:
            return selected_files, rate_dictionary_subfolder_path  # Return the selected files and their path
        else:
            print("No rate dictionary files selected.")
            return [], None
    else:
        print(f"No .txt rate dictionary files found in '{selected_rate_dictionary_subfolder}'.")
        return [], None

def select_existing_xlsx_file():
    print("Select a directory to search for .xlsx files:")
    subfolders = list_subfolders()
    selected_subfolder = choose_subdirectory(subfolders)

    # Check if the user selected a subfolder or the current directory
    folder_path = os.getcwd() if selected_subfolder is None else os.path.join(os.getcwd(), selected_subfolder)

    # Find .xlsx files in the selected directory
    xlsx_files = [f for f in os.listdir(folder_path) if f.endswith('.xlsx')]
    if xlsx_files:
        print("Select an existing .xlsx file from the following list:")
        for i, file in enumerate(xlsx_files, start=1):
            print(f"{i}. {file}")
        while True:
            try:
                choice = int(input("Enter the number of the file you want to select or 0 to cancel: "))
                if 0 <= choice <= len(xlsx_files):
                    return None if choice == 0 else os.path.join(folder_path, xlsx_files[choice - 1])
                else:
                    print("Invalid selection. Please try again.")
            except ValueError:
                print("Please enter a number.")
    else:
        print(f"No .xlsx files found in '{folder_path}'.")
        return None

# Utility function to clean file names
def clean_file_name(file_name):
    """
    Clean the file name for display, including replacing specific patterns.
    """
    file_name = file_name.replace('_', '').replace('corrected', '').replace('stemmed', '')
    if 'Démonomanie' in file_name:
        file_name = file_name.replace('Démonomanie', 'Dém')
    if 'République' in file_name:
        file_name = file_name.replace('République', 'Rép')
   
    # Replace '911' with '11' and '910' with '10' (NEW CHANGE)
    file_name = file_name.replace('911', '11').replace('910', '10')  # <--- CHANGE HERE
   
    return os.path.splitext(file_name)[0]

# Function to process the subset of text files for KWIC and counts
def process_subset_files(file_paths):
    combined_text = ""
    for file_path in file_paths:
        with open(file_path, 'r') as f:
            file_contents = f.read().lower()
            combined_text += file_contents + " "
    tokens = nltk.wordpunct_tokenize(combined_text)
    return tokens

def get_kwic(sometargetterm, somelistofwords, window=10, excl_target=True, source_file=None):
    kwics = []
    for n, w in enumerate(somelistofwords):
        if w == sometargetterm:
            start = max(0, n - window)
            end = min(n + window + 1, len(somelistofwords))
            if excl_target:
                # Updated: Exclude keyword itself from the window
                k = [word for word in (somelistofwords[start:n] + somelistofwords[n + 1:end]) if word != sometargetterm]
            else:
                k = somelistofwords[start:end]
            kwics.append((k, source_file))
    return kwics
   

def add_to_count_dict(word, count_dict):
    if word in count_dict:
        count_dict[word] += 1
    else:
        count_dict[word] = 1

def get_fishers(someword, somecountdict, someratedict, alternative='greater'):
    r = someratedict[someword]
    wc = sum(somecountdict.values())
    a = somecountdict[someword]
    b = wc - a
    c = round(r * wc)
    d = wc - c
    p = fisher_exact([[a, b], [c, d]], alternative=alternative)[1]
    return p

def filter_collocates_with_removal(collocates, collocate_counts):
    """
    Allow the user to filter the list of significant collocates and remove any selected collocates in error.

    Parameters:
        collocates (list): A sorted list of significant collocates.
        collocate_counts (dict): A dictionary of collocates and their counts.

    Returns:
        list: A filtered list of collocates selected by the user.
    """

    # Allow the user to refine the minimum‐count threshold repeatedly
    while True:
        try:
            min_count = int(input("Enter the minimum count threshold for collocates to include: ").strip())
        except ValueError:
            print("Invalid input. Please enter a valid number.")
            continue

        filtered_collocates = [c for c in collocates if collocate_counts[c] >= min_count]
        print(f"\nCollocates with counts >= {min_count} ({len(filtered_collocates)} items):")
        for i, collocate in enumerate(filtered_collocates, start=1):
            print(f"{i}. {collocate} (Count: {collocate_counts[collocate]})")
    
        choice = input("\nType 'refine' to try a new threshold, or press Enter to proceed: ").strip().lower()
        if choice == 'refine':
            continue
        break
        

    print("\nYou can select collocates by entering:")
    print("- A single number (e.g., 3) to select one collocate.")
    print("- A range of numbers (e.g., 3-6) to select multiple collocates.")
    print("- Multiple selections separated by commas (e.g., 3,5-7,9).")
    print("- Type 'all' to select all collocates.")
    print("- Type 'done' to finalize your selection.")

    selected_collocates = []

    while True:
        selection = input("Enter your selection: ").strip()
        if selection.lower() == 'done':
            break
        elif selection.lower() == 'all':
            selected_collocates = filtered_collocates
            break

        try:
            parts = selection.split(',')
            for part in parts:
                part = part.strip()
                if '-' in part:  # Handle ranges
                    start, end = map(int, part.split('-'))
                    selected_collocates.extend(filtered_collocates[start-1:end])
                elif part.isdigit():  # Handle single numbers
                    selected_collocates.append(filtered_collocates[int(part) - 1])
                else:
                    print(f"Invalid selection: {part}. Please try again.")
        except (ValueError, IndexError):
            print(f"Invalid input: {selection}. Please try again.")

        # Remove duplicates and sort the selected collocates
        selected_collocates = sorted(set(selected_collocates), key=filtered_collocates.index)

        print("Currently selected collocates:")
        for collocate in selected_collocates:
            print(collocate)

    # Allow users to review and remove collocates selected in error
    while True:
        print("\nFinalized collocates:")
        for i, collocate in enumerate(selected_collocates, start=1):
            print(f"{i}. {collocate}")

        remove_error = input(
            "Would you like to remove any collocates selected in error? (yes/no): "
        ).strip().lower()
        if remove_error == 'yes':
            remove_selection = input(
                "Enter the numbers of the collocates to remove (e.g., 2,4-5): "
            ).strip()
            try:
                parts = remove_selection.split(',')
                to_remove = []
                for part in parts:
                    part = part.strip()
                    if '-' in part:  # Handle ranges
                        start, end = map(int, part.split('-'))
                        to_remove.extend(selected_collocates[start-1:end])
                    elif part.isdigit():  # Handle single numbers
                        to_remove.append(selected_collocates[int(part) - 1])
                    else:
                        print(f"Invalid selection: {part}. Please try again.")
                selected_collocates = [
                    collocate for collocate in selected_collocates
                    if collocate not in to_remove
                ]
            except (ValueError, IndexError):
                print(f"Invalid input: {remove_selection}. Please try again.")
        else:
            break

    return selected_collocates, min_count

def search_concordance(
    reference_files,         # files → build the rate dictionary
    analysis_files,          # files → do KWIC & Fisher tests
    predefined_word_lists,
    stops,
    alpha
):
    # --- A) window prompt & workbook setup (unchanged) ---
    window = int(input("Enter the window size for concordance: ").strip())

    append_to_existing = input("Do you want to append results to an existing .xlsx file? (yes/no): ").strip().lower()
    if append_to_existing == 'yes':
        existing_file = select_existing_xlsx_file()
        if existing_file:
            wb = load_workbook(existing_file)
            print(f"Appending to existing file: {existing_file}")
        else:
            print("No existing workbook selected. Creating a new workbook instead.")
            wb = Workbook()
    else:
        wb = Workbook()
        print("Creating a new workbook.")
    if 'Sheet' in wb.sheetnames:
        del wb['Sheet']

    if append_to_existing == 'yes' and existing_file:
        output_filepath = existing_file
    else:
        output_filename = input("Enter a unique name for the .xlsx file (without extension): ").strip() or "distinct_collocates"
        output_filepath = os.path.join("concordances", f"{output_filename}.xlsx")

    # --- B) Build expected_rates from reference_files ---
    ref_paths  = [os.path.join(os.getcwd(), f) for f in reference_files]
    ref_tokens = process_subset_files(ref_paths)
    ref_counts = {}
    # sum(predefined_word_lists, []) flattens all hypotheses lists
    all_targets = set(sum(predefined_word_lists, []))
    for tok in ref_tokens:
        if tok not in stops and tok not in all_targets:
            add_to_count_dict(tok, ref_counts)

    total_ref = sum(ref_counts.values())
    if total_ref == 0:
        raise ValueError("Reference corpus is empty after filtering!")
    expected_rates = {w: c / total_ref for w, c in ref_counts.items()}

    # --- C) Loop over each hypothesis list ---
    for idx, predefined_words in enumerate(predefined_word_lists, start=1):
        if input(f"Skip Hypothesis {idx}? (yes/no): ").strip().lower() == 'yes':
            print(f"Skipping Hypothesis {idx}.")
            continue

        print(f"Processing Hypothesis {idx}.")
        ws = wb.create_sheet(title=f"Hypothesis {idx}")
        headers = ['Word'] + [clean_file_name(f) for f in analysis_files] + ['Total']
        ws.append(headers)
        predefined_words = sorted(predefined_words)
        keyword_pairs    = generate_keyword_pairs(predefined_words)

        # --- C1) Build counts_by_file_kw (one map only) ---
        counts_by_file_kw = {
            f: { kw: Counter() for kw in predefined_words }
            for f in analysis_files
        }
        
        for f in analysis_files:
            tokens = process_subset_files([os.path.join(os.getcwd(), f)])
            for kw in predefined_words:
                for context, _ in get_kwic(kw, tokens, window):
                    uniq = set(context) - {kw}
                    for c in uniq:
                        if c in stops:
                            continue
                        # count every collocate (including when c is itself one of your keywords)
                        counts_by_file_kw[f][kw][c] += 1
        
     
        # --- C2) Fisher & user‐filter (fixed file_total calculation) ---
        all_significant = set()
        from collections import Counter as _Counter
        collocate_counts = _Counter()
        
        for f, cnts in counts_by_file_kw.items():
            # flatten all kw‐buckets into one counter
            flat = _Counter()
            for kw in predefined_words:
                flat.update(cnts[kw])
            file_total = sum(flat.values())
            if file_total == 0:
                continue
        
            for coll, obs in flat.items():
                exp_cnt = round(expected_rates.get(coll, 0.0) * file_total)
                a, b = obs, file_total - obs
                c, d = exp_cnt, file_total - exp_cnt
                p = fisher_exact([[a, b], [c, d]], alternative='greater')[1]
                if p < alpha:
                    all_significant.add(coll)
                    collocate_counts[coll] += obs

        print(f"\n=== Hypothesis {idx} target words ===")
        print(", ".join(predefined_words))
        print("=======================================\n")

        
        # … just before you call filter_collocates_with_removal() …
        # 1) Identify any hypothesis keywords that are significant collocates
        auto_keywords = [kw for kw in predefined_words if kw in all_significant]
        
        # 2) Build the manual pool by removing auto_keywords
        manual_pool = sorted(set(all_significant) - set(auto_keywords))
        
        # 3) Prompt the user only on the manual pool
        selected, min_count = filter_collocates_with_removal(manual_pool, collocate_counts)
        
        # 4) Merge the hidden auto_keywords back into selected
        for kw in auto_keywords:
            if kw not in selected:
                selected.append(kw)
        if auto_keywords:
            print(f"\nAutomatically included hidden keyword collocates: {auto_keywords}\n")
        
        # --- C3) Write main table and build summary_by_kw ---
        summary_by_kw = { kw: set() for kw in predefined_words }
        for kw in predefined_words:
            row = [kw]
            row_total = 0
        
            for f in analysis_files:
                # restrict to only those you selected as significant
                coll_hits = {
                    c for c, cnt in counts_by_file_kw[f][kw].items()
                    if c in selected
                }
                # accumulate to summary (includes both “normal” collocates and keyword–keyword)
                summary_by_kw[kw].update(coll_hits)
        
                hits = len(coll_hits)
                row.append(hits)          # <- integer only
                row_total += hits
        
            row.append(row_total)        # <- integer only
            ws.append(row)
        
        # --- C4) Totals row (integers only) ---
        column_totals = [0]*len(analysis_files)
        for r in range(len(predefined_words)):
            for c in range(len(analysis_files)):
                val = ws.cell(row=r+2, column=c+2).value or 0
                column_totals[c] += val
        grand_total = sum(column_totals)
        ws.append(['Total'] + column_totals + [grand_total])
        
        # --- C5) Single summary list below the table ---
        ws.append([])
        ws.append(["Keyword", "Significant Collocates"])
        for kw in predefined_words:
            coll_list = ", ".join(sorted(summary_by_kw[kw]))
            ws.append([kw, coll_list])

        # --- C7) Footer info & optional save/exit per‐hypothesis ---
        ws.append([]); ws.append(['p-value threshold:', alpha])
        ws.append(['window size:', window])
        ws.append(['minimum count threshold:', min_count])

        if input(f"Save results for Hypothesis {idx}? (yes/no): ").strip().lower() == 'yes':
            os.makedirs('concordances', exist_ok=True)
            wb.save(output_filepath)
            print(f"Results up to Hypothesis {idx} saved to {output_filepath}.")

        if input("Exit after this hypothesis? (yes/no): ").strip().lower() == 'yes':
            print("Exiting.")
            return

    # --- D) Final save of workbook ---
    os.makedirs('concordances', exist_ok=True)
    wb.save(output_filepath)
    print(f"Concordance has been saved to {output_filepath}.")
    
# Example usage
use_predefined = input("Do you want to use predefined target word lists (yes/no)? ").strip().lower() == 'yes'
if use_predefined:
    predefined_word_lists = get_predefined_target_words()
else:
    predefined_word_lists = [input("Enter words for a group separated by spaces: ").strip().split() for _ in range(5)]

alpha = float(input("Enter the value for alpha: ").strip())

stopwords_file, stopwords_path = select_stopwords_file()
if stopwords_file:
    stops = read_stopwords(os.path.join(stopwords_path, stopwords_file))
    rate_dictionary_files, rate_dictionary_path = select_rate_dictionary_files()
    if rate_dictionary_files:
       #    build full path if needed:
        ref_files = [
            os.path.join(rate_dictionary_path, f)
            for f in rate_dictionary_files
        ]
        # 2) pick analysis files
        anal_files = prompt_files(find_text_files(os.getcwd()), "analysis (KWIC)")
        # 3) call with both lists
        search_concordance(ref_files, anal_files, predefined_word_lists, stops, alpha)
    else:
        print("No rate dictionary files selected.")
else:
    print("No stopwords file selected.")
# Out:
# Do you want to use predefined target word lists (yes/no)?  yes
# Enter the value for alpha:  0.10
# Stopwords file selection
# Select a subdirectory:
# 0. Current Working Directory
# 1. .ipynb_checkpoints
# 2. concordances
# Enter your choice:  0
# Select a stopwords file from the following list:
# Select the files for stopwords file:
# 1. stop_words.csv
# Enter the number of the file, a range (e.g., 1-3), multiple ranges (e.g., 1-3,5-7), a text pattern to select files, or type 'all' to select all files:  1
# Selected files:
# stop_words.csv
# Rate dictionary file selection
# Select a subdirectory:
# 0. Current Working Directory
# 1. .ipynb_checkpoints
# 2. concordances
# Enter your choice:  0
# Select one or more rate dictionary files from the following list:
# Select the files for rate dictionary:
# 1. Démonomanie preface Repair_corrected_stemmed.txt
# 2. République preface_corrected_stemmed.txt
# 3. Discours des raisons_corrected_stemmed.txt
# 4. Démonomanie I.1_corrected_stemmed.txt
# 5. Démonomanie I.2_corrected_stemmed.txt
# 6. Démonomanie I.3_corrected_stemmed.txt
# 7. Démonomanie I.4_corrected_stemmed.txt
# 8. Démonomanie I.5_corrected_stemmed.txt
# 9. Démonomanie I.6_corrected_stemmed.txt
# 10. Démonomanie I.7_corrected_stemmed.txt
# 11. Démonomanie II.1_corrected_stemmed.txt
# 12. Démonomanie II.2_corrected_stemmed.txt
# 13. Démonomanie II.3_corrected_stemmed.txt
# 14. Démonomanie II.4_corrected_stemmed.txt
# 15. Démonomanie II.5_corrected_stemmed.txt
# 16. Démonomanie II.6_corrected_stemmed.txt
# 17. Démonomanie II.7_corrected_stemmed.txt
# 18. Démonomanie II.8_corrected_stemmed.txt
# 19. Démonomanie III.1_corrected_stemmed.txt
# 20. Démonomanie III.2_corrected_stemmed.txt
# 21. Démonomanie III.3_corrected_stemmed.txt
# 22. Démonomanie III.4_corrected_stemmed.txt
# 23. Démonomanie III.5_corrected_stemmed.txt
# 24. Démonomanie III.6_corrected_stemmed.txt
# 25. Démonomanie IV.1_corrected_stemmed.txt
# 26. Démonomanie IV.2_corrected_stemmed.txt
# 27. Démonomanie IV.3_corrected_stemmed.txt
# 28. Démonomanie IV.4_corrected_stemmed.txt
# 29. Démonomanie IV.5_corrected_stemmed.txt
# 30. Harangue - Fontainebleau_corrected_stemmed.txt
# 31. Harangue - lit de justice_corrected_stemmed.txt
# 32. Harangue - Orléans 2_corrected_stemmed.txt
# 33. Harangue - Orléans_corrected_stemmed.txt
# 34. Harangue - ouverture de parlement_corrected_stemmed.txt
# 35. Harangue - parlement 2_corrected_stemmed.txt
# 36. Harangue - parlement 3_corrected_stemmed.txt
# 37. Harangue - parlement_corrected_stemmed.txt
# 38. Harangue - Poissy_corrected_stemmed.txt
# 39. Harangue - religion_corrected_stemmed.txt
# 40. Harangue - Rouen_corrected_stemmed.txt
# 41. Harangue - Saint Germain_corrected_stemmed.txt
# 42. Harangue - septembre_corrected_stemmed.txt
# 43. La réponse_corrected_stemmed.txt
# 44. Le paradoxe_corrected_stemmed.txt
# 45. Lettre_corrected_stemmed.txt
# 46. Lit de justice_corrected_stemmed.txt
# 47. Memoire - le but_corrected_stemmed.txt
# 48. Memoire - Namur_corrected_stemmed.txt
# 49. Memoire au roi_corrected_stemmed.txt
# 50. Memoires d'État Refuge_corrected_stemmed.txt
# 51. Memoires d'état_corrected_stemmed.txt
# 52. Recueil_corrected_stemmed.txt
# 53. Remonstrances - parlement_corrected_stemmed.txt
# 54. Remonstrances - Royaume_corrected_stemmed.txt
# 55. République I.1_corrected_stemmed.txt
# 56. République I.2_corrected_stemmed.txt
# 57. République I.3_corrected_stemmed.txt
# 58. République I.4_corrected_stemmed.txt
# 59. République I.5_corrected_stemmed.txt
# 60. République I.6_corrected_stemmed.txt
# 61. République I.7_corrected_stemmed.txt
# 62. République I.8_corrected_stemmed.txt
# 63. République I.910_corrected_stemmed.txt
# 64. République I.911_corrected_stemmed.txt
# 65. République I.9_corrected_stemmed.txt
# 66. République II.1_corrected_stemmed.txt
# 67. République II.2_corrected_stemmed.txt
# 68. République II.3_corrected_stemmed.txt
# 69. République II.4_corrected_stemmed.txt
# 70. République II.5_corrected_stemmed.txt
# 71. République II.6_corrected_stemmed.txt
# 72. République II.7_corrected_stemmed.txt
# 73. République III.1_corrected_stemmed.txt
# 74. République III.2_corrected_stemmed.txt
# 75. République III.3_corrected_stemmed.txt
# 76. République III.4_corrected_stemmed.txt
# 77. République III.5_corrected_stemmed.txt
# 78. République III.6_corrected_stemmed.txt
# 79. République III.7_corrected_stemmed.txt
# 80. République IV.1_corrected_stemmed.txt
# 81. République IV.2_corrected_stemmed.txt
# 82. République IV.3_corrected_stemmed.txt
# 83. République IV.4_corrected_stemmed.txt
# 84. République IV.5_corrected_stemmed.txt
# 85. République IV.6_corrected_stemmed.txt
# 86. République IV.7_corrected_stemmed.txt
# 87. République V.1_corrected_stemmed.txt
# 88. République V.2_corrected_stemmed.txt
# 89. République V.3_corrected_stemmed.txt
# 90. République V.4_corrected_stemmed.txt
# 91. République V.5_corrected_stemmed.txt
# 92. République VI.1_corrected_stemmed.txt
# 93. République VI.2_corrected_stemmed.txt
# 94. République VI.3_corrected_stemmed.txt
# 95. République VI.4_corrected_stemmed.txt
# 96. République VI.5_corrected_stemmed.txt
# 97. République VI.6_corrected_stemmed.txt
# 98. Théatre I_corrected_stemmed.txt
# 99. Théatre II_corrected_stemmed.txt
# 100. Théatre III_corrected_stemmed.txt
# 101. Théatre IV_corrected_stemmed.txt
# 102. Théatre summary_corrected_stemmed.txt
# 103. Théatre V_corrected_stemmed.txt
# 104. Traite Justice V_corrected_stemmed.txt
# 105. Traite Justice VI_corrected_stemmed.txt
# 106. Traite Justice VII_corrected_stemmed.txt
# 107. Traité Justice I_corrected_stemmed.txt
# 108. Traité Justice II_corrected_stemmed.txt
# 109. Traité Justice III_corrected_stemmed.txt
# 110. Traité Justice IV_corrected_stemmed.txt
# Enter the number of the file, a range (e.g., 1-3), multiple ranges (e.g., 1-3,5-7), a text pattern to select files, or type 'all' to select all files:  all
# Selected files:
# Démonomanie preface Repair_corrected_stemmed.txt
# République preface_corrected_stemmed.txt
# Discours des raisons_corrected_stemmed.txt
# Démonomanie I.1_corrected_stemmed.txt
# Démonomanie I.2_corrected_stemmed.txt
# Démonomanie I.3_corrected_stemmed.txt
# Démonomanie I.4_corrected_stemmed.txt
# Démonomanie I.5_corrected_stemmed.txt
# Démonomanie I.6_corrected_stemmed.txt
# Démonomanie I.7_corrected_stemmed.txt
# Démonomanie II.1_corrected_stemmed.txt
# Démonomanie II.2_corrected_stemmed.txt
# Démonomanie II.3_corrected_stemmed.txt
# Démonomanie II.4_corrected_stemmed.txt
# Démonomanie II.5_corrected_stemmed.txt
# Démonomanie II.6_corrected_stemmed.txt
# Démonomanie II.7_corrected_stemmed.txt
# Démonomanie II.8_corrected_stemmed.txt
# Démonomanie III.1_corrected_stemmed.txt
# Démonomanie III.2_corrected_stemmed.txt
# Démonomanie III.3_corrected_stemmed.txt
# Démonomanie III.4_corrected_stemmed.txt
# Démonomanie III.5_corrected_stemmed.txt
# Démonomanie III.6_corrected_stemmed.txt
# Démonomanie IV.1_corrected_stemmed.txt
# Démonomanie IV.2_corrected_stemmed.txt
# Démonomanie IV.3_corrected_stemmed.txt
# Démonomanie IV.4_corrected_stemmed.txt
# Démonomanie IV.5_corrected_stemmed.txt
# Harangue - Fontainebleau_corrected_stemmed.txt
# Harangue - lit de justice_corrected_stemmed.txt
# Harangue - Orléans 2_corrected_stemmed.txt
# Harangue - Orléans_corrected_stemmed.txt
# Harangue - ouverture de parlement_corrected_stemmed.txt
# Harangue - parlement 2_corrected_stemmed.txt
# Harangue - parlement 3_corrected_stemmed.txt
# Harangue - parlement_corrected_stemmed.txt
# Harangue - Poissy_corrected_stemmed.txt
# Harangue - religion_corrected_stemmed.txt
# Harangue - Rouen_corrected_stemmed.txt
# Harangue - Saint Germain_corrected_stemmed.txt
# Harangue - septembre_corrected_stemmed.txt
# La réponse_corrected_stemmed.txt
# Le paradoxe_corrected_stemmed.txt
# Lettre_corrected_stemmed.txt
# Lit de justice_corrected_stemmed.txt
# Memoire - le but_corrected_stemmed.txt
# Memoire - Namur_corrected_stemmed.txt
# Memoire au roi_corrected_stemmed.txt
# Memoires d'État Refuge_corrected_stemmed.txt
# Memoires d'état_corrected_stemmed.txt
# Recueil_corrected_stemmed.txt
# Remonstrances - parlement_corrected_stemmed.txt
# Remonstrances - Royaume_corrected_stemmed.txt
# République I.1_corrected_stemmed.txt
# République I.2_corrected_stemmed.txt
# République I.3_corrected_stemmed.txt
# République I.4_corrected_stemmed.txt
# République I.5_corrected_stemmed.txt
# République I.6_corrected_stemmed.txt
# République I.7_corrected_stemmed.txt
# République I.8_corrected_stemmed.txt
# République I.910_corrected_stemmed.txt
# République I.911_corrected_stemmed.txt
# République I.9_corrected_stemmed.txt
# République II.1_corrected_stemmed.txt
# République II.2_corrected_stemmed.txt
# République II.3_corrected_stemmed.txt
# République II.4_corrected_stemmed.txt
# République II.5_corrected_stemmed.txt
# République II.6_corrected_stemmed.txt
# République II.7_corrected_stemmed.txt
# République III.1_corrected_stemmed.txt
# République III.2_corrected_stemmed.txt
# République III.3_corrected_stemmed.txt
# République III.4_corrected_stemmed.txt
# République III.5_corrected_stemmed.txt
# République III.6_corrected_stemmed.txt
# République III.7_corrected_stemmed.txt
# République IV.1_corrected_stemmed.txt
# République IV.2_corrected_stemmed.txt
# République IV.3_corrected_stemmed.txt
# République IV.4_corrected_stemmed.txt
# République IV.5_corrected_stemmed.txt
# République IV.6_corrected_stemmed.txt
# République IV.7_corrected_stemmed.txt
# République V.1_corrected_stemmed.txt
# République V.2_corrected_stemmed.txt
# République V.3_corrected_stemmed.txt
# République V.4_corrected_stemmed.txt
# République V.5_corrected_stemmed.txt
# République VI.1_corrected_stemmed.txt
# République VI.2_corrected_stemmed.txt
# République VI.3_corrected_stemmed.txt
# République VI.4_corrected_stemmed.txt
# République VI.5_corrected_stemmed.txt
# République VI.6_corrected_stemmed.txt
# Théatre I_corrected_stemmed.txt
# Théatre II_corrected_stemmed.txt
# Théatre III_corrected_stemmed.txt
# Théatre IV_corrected_stemmed.txt
# Théatre summary_corrected_stemmed.txt
# Théatre V_corrected_stemmed.txt
# Traite Justice V_corrected_stemmed.txt
# Traite Justice VI_corrected_stemmed.txt
# Traite Justice VII_corrected_stemmed.txt
# Traité Justice I_corrected_stemmed.txt
# Traité Justice II_corrected_stemmed.txt
# Traité Justice III_corrected_stemmed.txt
# Traité Justice IV_corrected_stemmed.txt
# Select the files for analysis (KWIC):
# 1. Démonomanie preface Repair_corrected_stemmed.txt
# 2. République preface_corrected_stemmed.txt
# 3. Discours des raisons_corrected_stemmed.txt
# 4. Démonomanie I.1_corrected_stemmed.txt
# 5. Démonomanie I.2_corrected_stemmed.txt
# 6. Démonomanie I.3_corrected_stemmed.txt
# 7. Démonomanie I.4_corrected_stemmed.txt
# 8. Démonomanie I.5_corrected_stemmed.txt
# 9. Démonomanie I.6_corrected_stemmed.txt
# 10. Démonomanie I.7_corrected_stemmed.txt
# 11. Démonomanie II.1_corrected_stemmed.txt
# 12. Démonomanie II.2_corrected_stemmed.txt
# 13. Démonomanie II.3_corrected_stemmed.txt
# 14. Démonomanie II.4_corrected_stemmed.txt
# 15. Démonomanie II.5_corrected_stemmed.txt
# 16. Démonomanie II.6_corrected_stemmed.txt
# 17. Démonomanie II.7_corrected_stemmed.txt
# 18. Démonomanie II.8_corrected_stemmed.txt
# 19. Démonomanie III.1_corrected_stemmed.txt
# 20. Démonomanie III.2_corrected_stemmed.txt
# 21. Démonomanie III.3_corrected_stemmed.txt
# 22. Démonomanie III.4_corrected_stemmed.txt
# 23. Démonomanie III.5_corrected_stemmed.txt
# 24. Démonomanie III.6_corrected_stemmed.txt
# 25. Démonomanie IV.1_corrected_stemmed.txt
# 26. Démonomanie IV.2_corrected_stemmed.txt
# 27. Démonomanie IV.3_corrected_stemmed.txt
# 28. Démonomanie IV.4_corrected_stemmed.txt
# 29. Démonomanie IV.5_corrected_stemmed.txt
# 30. Harangue - Fontainebleau_corrected_stemmed.txt
# 31. Harangue - lit de justice_corrected_stemmed.txt
# 32. Harangue - Orléans 2_corrected_stemmed.txt
# 33. Harangue - Orléans_corrected_stemmed.txt
# 34. Harangue - ouverture de parlement_corrected_stemmed.txt
# 35. Harangue - parlement 2_corrected_stemmed.txt
# 36. Harangue - parlement 3_corrected_stemmed.txt
# 37. Harangue - parlement_corrected_stemmed.txt
# 38. Harangue - Poissy_corrected_stemmed.txt
# 39. Harangue - religion_corrected_stemmed.txt
# 40. Harangue - Rouen_corrected_stemmed.txt
# 41. Harangue - Saint Germain_corrected_stemmed.txt
# 42. Harangue - septembre_corrected_stemmed.txt
# 43. La réponse_corrected_stemmed.txt
# 44. Le paradoxe_corrected_stemmed.txt
# 45. Lettre_corrected_stemmed.txt
# 46. Lit de justice_corrected_stemmed.txt
# 47. Memoire - le but_corrected_stemmed.txt
# 48. Memoire - Namur_corrected_stemmed.txt
# 49. Memoire au roi_corrected_stemmed.txt
# 50. Memoires d'État Refuge_corrected_stemmed.txt
# 51. Memoires d'état_corrected_stemmed.txt
# 52. Recueil_corrected_stemmed.txt
# 53. Remonstrances - parlement_corrected_stemmed.txt
# 54. Remonstrances - Royaume_corrected_stemmed.txt
# 55. République I.1_corrected_stemmed.txt
# 56. République I.2_corrected_stemmed.txt
# 57. République I.3_corrected_stemmed.txt
# 58. République I.4_corrected_stemmed.txt
# 59. République I.5_corrected_stemmed.txt
# 60. République I.6_corrected_stemmed.txt
# 61. République I.7_corrected_stemmed.txt
# 62. République I.8_corrected_stemmed.txt
# 63. République I.910_corrected_stemmed.txt
# 64. République I.911_corrected_stemmed.txt
# 65. République I.9_corrected_stemmed.txt
# 66. République II.1_corrected_stemmed.txt
# 67. République II.2_corrected_stemmed.txt
# 68. République II.3_corrected_stemmed.txt
# 69. République II.4_corrected_stemmed.txt
# 70. République II.5_corrected_stemmed.txt
# 71. République II.6_corrected_stemmed.txt
# 72. République II.7_corrected_stemmed.txt
# 73. République III.1_corrected_stemmed.txt
# 74. République III.2_corrected_stemmed.txt
# 75. République III.3_corrected_stemmed.txt
# 76. République III.4_corrected_stemmed.txt
# 77. République III.5_corrected_stemmed.txt
# 78. République III.6_corrected_stemmed.txt
# 79. République III.7_corrected_stemmed.txt
# 80. République IV.1_corrected_stemmed.txt
# 81. République IV.2_corrected_stemmed.txt
# 82. République IV.3_corrected_stemmed.txt
# 83. République IV.4_corrected_stemmed.txt
# 84. République IV.5_corrected_stemmed.txt
# 85. République IV.6_corrected_stemmed.txt
# 86. République IV.7_corrected_stemmed.txt
# 87. République V.1_corrected_stemmed.txt
# 88. République V.2_corrected_stemmed.txt
# 89. République V.3_corrected_stemmed.txt
# 90. République V.4_corrected_stemmed.txt
# 91. République V.5_corrected_stemmed.txt
# 92. République VI.1_corrected_stemmed.txt
# 93. République VI.2_corrected_stemmed.txt
# 94. République VI.3_corrected_stemmed.txt
# 95. République VI.4_corrected_stemmed.txt
# 96. République VI.5_corrected_stemmed.txt
# 97. République VI.6_corrected_stemmed.txt
# 98. Théatre I_corrected_stemmed.txt
# 99. Théatre II_corrected_stemmed.txt
# 100. Théatre III_corrected_stemmed.txt
# 101. Théatre IV_corrected_stemmed.txt
# 102. Théatre summary_corrected_stemmed.txt
# 103. Théatre V_corrected_stemmed.txt
# 104. Traite Justice V_corrected_stemmed.txt
# 105. Traite Justice VI_corrected_stemmed.txt
# 106. Traite Justice VII_corrected_stemmed.txt
# 107. Traité Justice I_corrected_stemmed.txt
# 108. Traité Justice II_corrected_stemmed.txt
# 109. Traité Justice III_corrected_stemmed.txt
# 110. Traité Justice IV_corrected_stemmed.txt
# Enter the number of the file, a range (e.g., 1-3), multiple ranges (e.g., 1-3,5-7), a text pattern to select files, or type 'all' to select all files:  Dém,Rép
# Selected files:
# Démonomanie preface Repair_corrected_stemmed.txt
# République preface_corrected_stemmed.txt
# Démonomanie I.1_corrected_stemmed.txt
# Démonomanie I.2_corrected_stemmed.txt
# Démonomanie I.3_corrected_stemmed.txt
# Démonomanie I.4_corrected_stemmed.txt
# Démonomanie I.5_corrected_stemmed.txt
# Démonomanie I.6_corrected_stemmed.txt
# Démonomanie I.7_corrected_stemmed.txt
# Démonomanie II.1_corrected_stemmed.txt
# Démonomanie II.2_corrected_stemmed.txt
# Démonomanie II.3_corrected_stemmed.txt
# Démonomanie II.4_corrected_stemmed.txt
# Démonomanie II.5_corrected_stemmed.txt
# Démonomanie II.6_corrected_stemmed.txt
# Démonomanie II.7_corrected_stemmed.txt
# Démonomanie II.8_corrected_stemmed.txt
# Démonomanie III.1_corrected_stemmed.txt
# Démonomanie III.2_corrected_stemmed.txt
# Démonomanie III.3_corrected_stemmed.txt
# Démonomanie III.4_corrected_stemmed.txt
# Démonomanie III.5_corrected_stemmed.txt
# Démonomanie III.6_corrected_stemmed.txt
# Démonomanie IV.1_corrected_stemmed.txt
# Démonomanie IV.2_corrected_stemmed.txt
# Démonomanie IV.3_corrected_stemmed.txt
# Démonomanie IV.4_corrected_stemmed.txt
# Démonomanie IV.5_corrected_stemmed.txt
# République I.1_corrected_stemmed.txt
# République I.2_corrected_stemmed.txt
# République I.3_corrected_stemmed.txt
# République I.4_corrected_stemmed.txt
# République I.5_corrected_stemmed.txt
# République I.6_corrected_stemmed.txt
# République I.7_corrected_stemmed.txt
# République I.8_corrected_stemmed.txt
# République I.910_corrected_stemmed.txt
# République I.911_corrected_stemmed.txt
# République I.9_corrected_stemmed.txt
# République II.1_corrected_stemmed.txt
# République II.2_corrected_stemmed.txt
# République II.3_corrected_stemmed.txt
# République II.4_corrected_stemmed.txt
# République II.5_corrected_stemmed.txt
# République II.6_corrected_stemmed.txt
# République II.7_corrected_stemmed.txt
# République III.1_corrected_stemmed.txt
# République III.2_corrected_stemmed.txt
# République III.3_corrected_stemmed.txt
# République III.4_corrected_stemmed.txt
# République III.5_corrected_stemmed.txt
# République III.6_corrected_stemmed.txt
# République III.7_corrected_stemmed.txt
# République IV.1_corrected_stemmed.txt
# République IV.2_corrected_stemmed.txt
# République IV.3_corrected_stemmed.txt
# République IV.4_corrected_stemmed.txt
# République IV.5_corrected_stemmed.txt
# République IV.6_corrected_stemmed.txt
# République IV.7_corrected_stemmed.txt
# République V.1_corrected_stemmed.txt
# République V.2_corrected_stemmed.txt
# République V.3_corrected_stemmed.txt
# République V.4_corrected_stemmed.txt
# République V.5_corrected_stemmed.txt
# République VI.1_corrected_stemmed.txt
# République VI.2_corrected_stemmed.txt
# République VI.3_corrected_stemmed.txt
# République VI.4_corrected_stemmed.txt
# République VI.5_corrected_stemmed.txt
# République VI.6_corrected_stemmed.txt
# Enter the window size for concordance:  15
# Do you want to append results to an existing .xlsx file? (yes/no):  yes
# Select a directory to search for .xlsx files:
# Select a subdirectory:
# 0. Current Working Directory
# 1. .ipynb_checkpoints
# 2. concordances
# Enter your choice:  2
# Select an existing .xlsx file from the following list:
# 1. 15WindowSummary - Archive.xlsx
# 2. 15winsum.xlsx
# 3. most_distinct_collocates_20_window.xlsx
# Enter the number of the file you want to select or 0 to cancel:  2
# Appending to existing file: /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/concordances/15winsum.xlsx
# Skip Hypothesis 1? (yes/no):  yes
# Skipping Hypothesis 1.
# Skip Hypothesis 2? (yes/no):  yes
# Skipping Hypothesis 2.
# Skip Hypothesis 3? (yes/no):  yes
# Skipping Hypothesis 3.
# Skip Hypothesis 4? (yes/no):  yes
# Skipping Hypothesis 4.
# Skip Hypothesis 5? (yes/no):  no
# Processing Hypothesis 5.
#
# === Hypothesis 5 target words ===
# absolu, bien, chos, civil, droit, estat, just, justic, loi, maiest, princ, puissanc, republ, roy, royal, royaum, souverain, souverainet, sujet
# =======================================
# Enter the minimum count threshold for collocates to include:  10
# Collocates with counts >= 10 (955 items):
# 1. abreg (Count: 10)
# 2. abus (Count: 12)
# 3. abíolu (Count: 21)
# 4. accord (Count: 28)
# 5. achean (Count: 19)
# 6. acquis (Count: 12)
# 7. action (Count: 37)
# 8. adheran (Count: 13)
# 9. adopt (Count: 20)
# 10. aduint (Count: 30)
# 11. advient (Count: 31)
# 12. advis (Count: 62)
# 13. affair (Count: 79)
# 14. affembl (Count: 27)
# 15. affeur (Count: 35)
# 16. affin (Count: 21)
# 17. afi (Count: 35)
# 18. afin (Count: 28)
# 19. afranch (Count: 20)
# 20. afriqu (Count: 23)
# 21. age (Count: 26)
# 22. aif (Count: 34)
# 23. ail (Count: 14)
# 24. ainsauss (Count: 21)
# 25. ainsil (Count: 13)
# 26. aisn (Count: 56)
# 27. aleman (Count: 12)
# 28. alien (Count: 13)
# 29. alli (Count: 44)
# 30. allianc (Count: 95)
# 31. almaign (Count: 60)
# 32. alors (Count: 17)
# 33. alpe (Count: 13)
# 34. alphon (Count: 14)
# 35. alter (Count: 18)
# 36. ambaffadeur (Count: 25)
# 37. ambafladeur (Count: 22)
# 38. ambit (Count: 13)
# 39. ame (Count: 14)
# 40. amend (Count: 22)
# 41. amis (Count: 27)
# 42. amiti (Count: 25)
# 43. amour (Count: 11)
# 44. ancien (Count: 178)
# 45. ange (Count: 12)
# 46. angleterr (Count: 158)
# 47. anne (Count: 11)
# 48. antioqu (Count: 19)
# 49. apparent (Count: 29)
# 50. appel (Count: 76)
# 51. appellent (Count: 10)
# 52. apresl (Count: 15)
# 53. arbitr (Count: 18)
# 54. argent (Count: 47)
# 55. arien (Count: 11)
# 56. ariftocrat (Count: 101)
# 57. aristocrat (Count: 183)
# 58. aristot (Count: 42)
# 59. arithmet (Count: 40)
# 60. arme (Count: 55)
# 61. armec (Count: 14)
# 62. arragon (Count: 50)
# 63. arrest (Count: 117)
# 64. athen (Count: 28)
# 65. attalus (Count: 15)
# 66. attendu (Count: 60)
# 67. attribu (Count: 16)
# 68. auf (Count: 10)
# 69. auff (Count: 36)
# 70. aufs (Count: 20)
# 71. auquel (Count: 28)
# 72. auroit (Count: 22)
# 73. aussil (Count: 20)
# 74. autor (Count: 18)
# 75. autruy (Count: 135)
# 76. auxloix (Count: 10)
# 77. avon (Count: 66)
# 78. ayan (Count: 15)
# 79. baftard (Count: 15)
# 80. baille (Count: 16)
# 81. bann (Count: 26)
# 82. bar (Count: 10)
# 83. baron (Count: 16)
# 84. bataill (Count: 12)
# 85. beau (Count: 28)
# 86. beaucoup (Count: 50)
# 87. befoin (Count: 21)
# 88. bel (Count: 31)
# 89. bencfic (Count: 10)
# 90. benefic (Count: 23)
# 91. billon (Count: 16)
# 92. ble (Count: 29)
# 93. bon (Count: 39)
# 94. bourgeois (Count: 71)
# 95. bretaign (Count: 17)
# 96. but (Count: 12)
# 97. caff (Count: 18)
# 98. caftill (Count: 21)
# 99. canon (Count: 12)
# 100. canton (Count: 23)
# 101. capitain (Count: 88)
# 102. capital (Count: 24)
# 103. captiu (Count: 11)
# 104. caril (Count: 47)
# 105. carl (Count: 48)
# 106. cas (Count: 123)
# 107. casil (Count: 11)
# 108. castill (Count: 19)
# 109. cattill (Count: 11)
# 110. caus (Count: 32)
# 111. cefar (Count: 14)
# 112. ceffion (Count: 11)
# 113. celest (Count: 24)
# 114. cenfeur (Count: 24)
# 115. cenfur (Count: 12)
# 116. censur (Count: 10)
# 117. certain (Count: 94)
# 118. cfleu (Count: 12)
# 119. cftat (Count: 40)
# 120. cftranger (Count: 10)
# 121. cftre (Count: 18)
# 122. chaff (Count: 49)
# 123. chafl (Count: 32)
# 124. chambr (Count: 10)
# 125. chang (Count: 171)
# 126. changemen (Count: 57)
# 127. changemet (Count: 16)
# 128. chapitr (Count: 14)
# 129. charg (Count: 107)
# 130. charl (Count: 154)
# 131. charlemaign (Count: 12)
# 132. chef (Count: 93)
# 133. choif (Count: 20)
# 134. chois (Count: 25)
# 135. chrestien (Count: 20)
# 136. chágem (Count: 10)
# 137. cháger (Count: 11)
# 138. ciceron (Count: 14)
# 139. cit (Count: 52)
# 140. citadel (Count: 10)
# 141. citoi (Count: 12)
# 142. citoyen (Count: 156)
# 143. ciuil (Count: 14)
# 144. clauf (Count: 10)
# 145. cofeil (Count: 12)
# 146. cognoiff (Count: 10)
# 147. cognoifl (Count: 19)
# 148. cognoift (Count: 10)
# 149. cognoiftr (Count: 21)
# 150. coll (Count: 12)
# 151. colleg (Count: 111)
# 152. collegu (Count: 24)
# 153. combien (Count: 44)
# 154. command (Count: 255)
# 155. commc (Count: 10)
# 156. commeil (Count: 24)
# 157. commenc (Count: 12)
# 158. comment (Count: 23)
# 159. commif (Count: 13)
# 160. commiff (Count: 13)
# 161. commiss (Count: 25)
# 162. commissair (Count: 36)
# 163. commission (Count: 32)
# 164. commun (Count: 71)
# 165. communaut (Count: 41)
# 166. communiqu (Count: 19)
# 167. compof (Count: 13)
# 168. compofe (Count: 10)
# 169. comt (Count: 31)
# 170. comunaut (Count: 18)
# 171. con (Count: 26)
# 172. condamn (Count: 42)
# 173. condit (Count: 15)
# 174. conduit (Count: 11)
# 175. confent (Count: 14)
# 176. conferu (Count: 36)
# 177. confess (Count: 24)
# 178. confifc (Count: 11)
# 179. confifqu (Count: 24)
# 180. confirm (Count: 11)
# 181. confrair (Count: 11)
# 182. conionct (Count: 11)
# 183. coniur (Count: 11)
# 184. conquest (Count: 10)
# 185. conseil (Count: 183)
# 186. conseiller (Count: 12)
# 187. consent (Count: 23)
# 188. consul (Count: 23)
# 189. contempl (Count: 11)
# 190. continu (Count: 13)
# 191. contract (Count: 14)
# 192. contraint (Count: 16)
# 193. contrair (Count: 55)
# 194. contrel (Count: 41)
# 195. contreuen (Count: 14)
# 196. conuent (Count: 16)
# 197. corp (Count: 94)
# 198. corrig (Count: 16)
# 199. cot (Count: 10)
# 200. cotr (Count: 22)
# 201. coulpabl (Count: 12)
# 202. cour (Count: 123)
# 203. courag (Count: 11)
# 204. couron (Count: 141)
# 205. courón (Count: 12)
# 206. coustum (Count: 137)
# 207. craignan (Count: 18)
# 208. craindr (Count: 16)
# 209. craint (Count: 18)
# 210. creanci (Count: 15)
# 211. crim (Count: 47)
# 212. cruaut (Count: 30)
# 213. cruel (Count: 18)
# 214. cueur (Count: 11)
# 215. cuiur (Count: 12)
# 216. cé (Count: 16)
# 217. dang (Count: 36)
# 218. danger (Count: 25)
# 219. dannemarc (Count: 30)
# 220. dannemarch (Count: 10)
# 221. darius (Count: 18)
# 222. dauantag (Count: 11)
# 223. debout (Count: 15)
# 224. debvoir (Count: 18)
# 225. decern (Count: 16)
# 226. declair (Count: 13)
# 227. declar (Count: 26)
# 228. decommand (Count: 10)
# 229. decret (Count: 23)
# 230. def (Count: 13)
# 231. defair (Count: 12)
# 232. defcharg (Count: 13)
# 233. defenfiu (Count: 11)
# 234. defens (Count: 36)
# 235. defer (Count: 15)
# 236. defon (Count: 10)
# 237. defpoüill (Count: 10)
# 238. defranc (Count: 16)
# 239. deiustic (Count: 11)
# 240. deleur (Count: 39)
# 241. delez (Count: 14)
# 242. deliber (Count: 18)
# 243. demand (Count: 12)
# 244. demeur (Count: 50)
# 245. democrat (Count: 15)
# 246. deni (Count: 55)
# 247. depend (Count: 10)
# 248. dependent (Count: 12)
# 249. depouill (Count: 12)
# 250. deput (Count: 22)
# 251. deric (Count: 10)
# 252. derni (Count: 43)
# 253. dero (Count: 10)
# 254. derog (Count: 26)
# 255. desan (Count: 10)
# 256. dessus (Count: 98)
# 257. destitu (Count: 17)
# 258. destrois (Count: 10)
# 259. deu (Count: 35)
# 260. dextr (Count: 10)
# 261. diabl (Count: 38)
# 262. dieu (Count: 594)
# 263. differend (Count: 22)
# 264. different (Count: 67)
# 265. difficil (Count: 15)
# 266. difficult (Count: 12)
# 267. difpef (Count: 13)
# 268. difpenf (Count: 12)
# 269. difpof (Count: 42)
# 270. difput (Count: 14)
# 271. diftin (Count: 11)
# 272. diftribu (Count: 35)
# 273. diminu (Count: 16)
# 274. dion (Count: 12)
# 275. dir (Count: 178)
# 276. diron (Count: 27)
# 277. discord (Count: 10)
# 278. disent (Count: 10)
# 279. disoit (Count: 54)
# 280. divin (Count: 99)
# 281. divis (Count: 24)
# 282. doc (Count: 16)
# 283. doibuent (Count: 29)
# 284. doit (Count: 353)
# 285. domain (Count: 62)
# 286. dommag (Count: 20)
# 287. don (Count: 259)
# 288. donc (Count: 24)
# 289. doncl (Count: 14)
# 290. donne (Count: 21)
# 291. donnel (Count: 12)
# 292. donnent (Count: 15)
# 293. doubt (Count: 46)
# 294. douceur (Count: 10)
# 295. doux (Count: 17)
# 296. dre (Count: 13)
# 297. droiet (Count: 21)
# 298. duc (Count: 115)
# 299. duch (Count: 13)
# 300. dur (Count: 11)
# 301. dy (Count: 31)
# 302. edi (Count: 17)
# 303. edouart (Count: 19)
# 304. efcrit (Count: 34)
# 305. efcu (Count: 10)
# 306. efcuyer (Count: 11)
# 307. effect (Count: 20)
# 308. efgal (Count: 32)
# 309. efle (Count: 16)
# 310. efleu (Count: 68)
# 311. eflir (Count: 22)
# 312. egal (Count: 39)
# 313. eglis (Count: 22)
# 314. egypt (Count: 18)
# 315. ele (Count: 22)
# 316. elect (Count: 20)
# 317. eleet (Count: 11)
# 318. elt (Count: 14)
# 319. em (Count: 10)
# 320. empar (Count: 10)
# 321. empereur (Count: 247)
# 322. empiet (Count: 12)
# 323. empir (Count: 241)
# 324. emploi (Count: 14)
# 325. ence (Count: 20)
# 326. enfant (Count: 130)
# 327. enla (Count: 25)
# 328. ennemy (Count: 116)
# 329. ensembl (Count: 28)
# 330. entendr (Count: 17)
# 331. entr (Count: 16)
# 332. entre (Count: 113)
# 333. entrel (Count: 33)
# 334. entremefl (Count: 11)
# 335. entreprif (Count: 14)
# 336. entreten (Count: 24)
# 337. enuersl (Count: 10)
# 338. enui (Count: 15)
# 339. enuoi (Count: 13)
# 340. enver (Count: 60)
# 341. equal (Count: 41)
# 342. equit (Count: 61)
# 343. esclav (Count: 120)
# 344. escus (Count: 25)
# 345. espaigne (Count: 42)
# 346. espargn (Count: 19)
# 347. esprit (Count: 43)
# 348. establ (Count: 57)
# 349. estan (Count: 16)
# 350. estle (Count: 11)
# 351. estrang (Count: 40)
# 352. estranger (Count: 69)
# 353. estráger (Count: 12)
# 354. està (Count: 22)
# 355. estát (Count: 11)
# 356. euefqu (Count: 14)
# 357. eumen (Count: 17)
# 358. eur (Count: 13)
# 359. europ (Count: 17)
# 360. except (Count: 32)
# 361. excommuni (Count: 14)
# 362. execu (Count: 24)
# 363. execut (Count: 21)
# 364. exempl (Count: 41)
# 365. exempt (Count: 48)
# 366. exept (Count: 13)
# 367. expedient (Count: 21)
# 368. expre (Count: 10)
# 369. exprefl (Count: 10)
# 370. extraordinair (Count: 13)
# 371. extrem (Count: 34)
# 372. fac (Count: 42)
# 373. facr (Count: 23)
# 374. facre (Count: 16)
# 375. faction (Count: 16)
# 376. fageff (Count: 13)
# 377. faifoient (Count: 10)
# 378. faill (Count: 14)
# 379. faitl (Count: 12)
# 380. famill (Count: 116)
# 381. fang (Count: 10)
# 382. faueur (Count: 40)
# 383. fecour (Count: 17)
# 384. fecret (Count: 13)
# 385. federic (Count: 10)
# 386. fei (Count: 10)
# 387. feigneu (Count: 12)
# 388. felicit (Count: 11)
# 389. femm (Count: 74)
# 390. feodal (Count: 10)
# 391. fepar (Count: 12)
# 392. fer (Count: 85)
# 393. ferrar (Count: 14)
# 394. feruic (Count: 15)
# 395. feruiteur (Count: 14)
# 396. feudatair (Count: 13)
# 397. feulemet (Count: 12)
# 398. feuret (Count: 26)
# 399. fez (Count: 23)
# 400. fief (Count: 27)
# 401. fieg (Count: 13)
# 402. fien (Count: 37)
# 403. fiest (Count: 15)
# 404. fifqu (Count: 16)
# 405. fiftl (Count: 11)
# 406. fill (Count: 43)
# 407. fin (Count: 40)
# 408. financ (Count: 65)
# 409. fino (Count: 15)
# 410. fion (Count: 21)
# 411. fix (Count: 21)
# 412. flateur (Count: 18)
# 413. fleur (Count: 17)
# 414. florenc (Count: 27)
# 415. fo (Count: 11)
# 416. foient (Count: 25)
# 417. foiten (Count: 13)
# 418. fol (Count: 28)
# 419. fond (Count: 15)
# 420. forc (Count: 132)
# 421. forg (Count: 19)
# 422. form (Count: 50)
# 423. fort (Count: 110)
# 424. fortifi (Count: 14)
# 425. fou (Count: 16)
# 426. foufranc (Count: 13)
# 427. fouftenu (Count: 11)
# 428. fous (Count: 11)
# 429. fouu (Count: 11)
# 430. fouuc (Count: 16)
# 431. foy (Count: 142)
# 432. fpecial (Count: 16)
# 433. fran (Count: 21)
# 434. franc (Count: 298)
# 435. françois (Count: 65)
# 436. frer (Count: 35)
# 437. frideric (Count: 17)
# 438. fráce (Count: 34)
# 439. ftat (Count: 11)
# 440. ftoit (Count: 18)
# 441. ftrer (Count: 11)
# 442. fu (Count: 14)
# 443. fubfid (Count: 18)
# 444. fucceff (Count: 29)
# 445. fucceffion (Count: 11)
# 446. fuccefl (Count: 30)
# 447. fuccefleur (Count: 12)
# 448. fucceflion (Count: 12)
# 449. fuflent (Count: 10)
# 450. fuit (Count: 12)
# 451. fuiu (Count: 12)
# 452. furl (Count: 11)
# 453. fà (Count: 11)
# 454. gard (Count: 108)
# 455. gen (Count: 51)
# 456. general (Count: 117)
# 457. geometr (Count: 38)
# 458. gift (Count: 58)
# 459. gouu (Count: 18)
# 460. gouuernemet (Count: 34)
# 461. gouvern (Count: 118)
# 462. gouverneur (Count: 22)
# 463. grac (Count: 38)
# 464. grain (Count: 18)
# 465. grandeur (Count: 20)
# 466. grec (Count: 31)
# 467. grád (Count: 26)
# 468. gré (Count: 15)
# 469. guerr (Count: 392)
# 470. guerri (Count: 14)
# 471. guid (Count: 16)
# 472. habitan (Count: 21)
# 473. harmon (Count: 83)
# 474. haut (Count: 25)
# 475. hazard (Count: 18)
# 476. hebrieu (Count: 20)
# 477. henr (Count: 27)
# 478. henry (Count: 38)
# 479. her (Count: 21)
# 480. hereditair (Count: 17)
# 481. heriti (Count: 29)
# 482. heritier (Count: 15)
# 483. herod (Count: 10)
# 484. heureuf (Count: 12)
# 485. hom (Count: 11)
# 486. homag (Count: 12)
# 487. homm (Count: 57)
# 488. hommag (Count: 111)
# 489. hon (Count: 10)
# 490. hongr (Count: 41)
# 491. honnest (Count: 15)
# 492. honneur (Count: 124)
# 493. honnor (Count: 20)
# 494. hor (Count: 29)
# 495. horfm (Count: 12)
# 496. humain (Count: 56)
# 497. humbl (Count: 11)
# 498. iacoit (Count: 36)
# 499. iaqu (Count: 11)
# 500. iaçoit (Count: 16)
# 501. icel (Count: 37)
# 502. iean (Count: 13)
# 503. iiij (Count: 31)
# 504. ila (Count: 23)
# 505. ilest (Count: 18)
# 506. ilfe (Count: 12)
# 507. ille (Count: 16)
# 508. illuftr (Count: 10)
# 509. imag (Count: 20)
# 510. imperial (Count: 56)
# 511. impof (Count: 14)
# 512. impoffibl (Count: 11)
# 513. impofit (Count: 15)
# 514. impost (Count: 34)
# 515. incompatibl (Count: 14)
# 516. indiu (Count: 11)
# 517. inegal (Count: 11)
# 518. infin (Count: 11)
# 519. inftitu (Count: 14)
# 520. iniqu (Count: 30)
# 521. iniur (Count: 22)
# 522. iniust (Count: 31)
# 523. innocent (Count: 10)
# 524. interest (Count: 27)
# 525. ioindr (Count: 10)
# 526. iour (Count: 19)
# 527. ital (Count: 32)
# 528. iur (Count: 28)
# 529. iurifd (Count: 11)
# 530. iurisdict (Count: 47)
# 531. jug (Count: 446)
# 532. lacedemonien (Count: 30)
# 533. lafemm (Count: 10)
# 534. lafoy (Count: 21)
# 535. languedoc (Count: 11)
# 536. latin (Count: 17)
# 537. legifl (Count: 20)
# 538. legitim (Count: 21)
# 539. lesan (Count: 10)
# 540. lesautr (Count: 36)
# 541. lettr (Count: 80)
# 542. lez (Count: 26)
# 543. libert (Count: 70)
# 544. libr (Count: 11)
# 545. licit (Count: 24)
# 546. liciteau (Count: 10)
# 547. lieu (Count: 34)
# 548. lieuten (Count: 14)
# 549. lieux (Count: 15)
# 550. lig (Count: 43)
# 551. ligne (Count: 18)
# 552. ligu (Count: 79)
# 553. lison (Count: 19)
# 554. lombar (Count: 10)
# 555. lon (Count: 15)
# 556. lou (Count: 86)
# 557. loyer (Count: 47)
# 558. lug (Count: 21)
# 559. lycurgu (Count: 19)
# 560. lyon (Count: 13)
# 561. là (Count: 13)
# 562. macedoin (Count: 55)
# 563. mag (Count: 17)
# 564. magistrat (Count: 732)
# 565. main (Count: 54)
# 566. mainten (Count: 40)
# 567. maisil (Count: 14)
# 568. maisl (Count: 19)
# 569. maison (Count: 77)
# 570. maistr (Count: 16)
# 571. mal (Count: 15)
# 572. malad (Count: 10)
# 573. mall (Count: 20)
# 574. mand (Count: 58)
# 575. mandemen (Count: 34)
# 576. mar (Count: 98)
# 577. marc (Count: 32)
# 578. mariag (Count: 17)
# 579. marqu (Count: 134)
# 580. matier (Count: 18)
# 581. maxim (Count: 15)
# 582. maximilian (Count: 11)
# 583. medois (Count: 11)
# 584. mefch (Count: 12)
# 585. mefpr (Count: 17)
# 586. meilleur (Count: 13)
# 587. membr (Count: 21)
# 588. menag (Count: 16)
# 589. mention (Count: 13)
# 590. menu (Count: 59)
# 591. mer (Count: 12)
# 592. meridional (Count: 17)
# 593. merit (Count: 48)
# 594. meritent (Count: 10)
# 595. meschan (Count: 16)
# 596. mesmemet (Count: 10)
# 597. met (Count: 29)
# 598. meur (Count: 35)
# 599. mieux (Count: 123)
# 600. milan (Count: 32)
# 601. militair (Count: 18)
# 602. minorqu (Count: 10)
# 603. mis (Count: 10)
# 604. moin (Count: 86)
# 605. moindr (Count: 32)
# 606. mois (Count: 25)
# 607. monar (Count: 15)
# 608. monarch (Count: 279)
# 609. monarqu (Count: 121)
# 610. mond (Count: 38)
# 611. monnoy (Count: 59)
# 612. monstr (Count: 114)
# 613. montr (Count: 14)
# 614. mor (Count: 16)
# 615. mort (Count: 164)
# 616. mot (Count: 57)
# 617. mour (Count: 24)
# 618. moyen (Count: 61)
# 619. mun (Count: 11)
# 620. muraill (Count: 15)
# 621. na (Count: 23)
# 622. napl (Count: 60)
# 623. nat (Count: 16)
# 624. natur (Count: 132)
# 625. naturel (Count: 234)
# 626. nauarr (Count: 14)
# 627. neantmoinsil (Count: 14)
# 628. neceff (Count: 10)
# 629. neceffair (Count: 28)
# 630. neceflair (Count: 29)
# 631. neuf (Count: 11)
# 632. neur (Count: 14)
# 633. neutr (Count: 19)
# 634. neátmoin (Count: 11)
# 635. nicomed (Count: 10)
# 636. nobl (Count: 54)
# 637. nobleff (Count: 36)
# 638. noblefl (Count: 12)
# 639. nom (Count: 13)
# 640. nombr (Count: 65)
# 641. notabl (Count: 26)
# 642. nouucau (Count: 17)
# 643. nouueau (Count: 13)
# 644. noy (Count: 53)
# 645. né (Count: 20)
# 646. obeir (Count: 39)
# 647. obeiss (Count: 96)
# 648. oblig (Count: 110)
# 649. occafion (Count: 72)
# 650. of (Count: 13)
# 651. offenfiu (Count: 12)
# 652. offic (Count: 176)
# 653. offici (Count: 168)
# 654. officier (Count: 12)
# 655. ofter (Count: 19)
# 656. ona (Count: 12)
# 657. onque (Count: 25)
# 658. opinion (Count: 26)
# 659. ordinair (Count: 85)
# 660. ordon (Count: 381)
# 661. ordonne (Count: 22)
# 662. ordre (Count: 21)
# 663. ore (Count: 138)
# 664. otroi (Count: 11)
# 665. ottroi (Count: 12)
# 666. oul (Count: 21)
# 667. outr (Count: 50)
# 668. ouuertur (Count: 11)
# 669. paffion (Count: 10)
# 670. pafl (Count: 15)
# 671. pair (Count: 18)
# 672. pais (Count: 11)
# 673. paix (Count: 132)
# 674. pap (Count: 167)
# 675. parau (Count: 35)
# 676. parcill (Count: 10)
# 677. pareil (Count: 16)
# 678. paren (Count: 12)
# 679. parlemen (Count: 14)
# 680. parlemet (Count: 11)
# 681. parricid (Count: 11)
# 682. part (Count: 102)
# 683. partag (Count: 28)
# 684. particuli (Count: 205)
# 685. particulier (Count: 24)
# 686. pass (Count: 14)
# 687. patent (Count: 20)
# 688. paternel (Count: 27)
# 689. pauur (Count: 53)
# 690. pauvret (Count: 16)
# 691. pay (Count: 218)
# 692. pein (Count: 154)
# 693. penfion (Count: 23)
# 694. per (Count: 89)
# 695. perdr (Count: 22)
# 696. perdu (Count: 12)
# 697. perf (Count: 18)
# 698. perfeus (Count: 19)
# 699. perfid (Count: 10)
# 700. perfonnag (Count: 14)
# 701. pergam (Count: 13)
# 702. perial (Count: 10)
# 703. perl (Count: 28)
# 704. perm (Count: 26)
# 705. pernicieuf (Count: 26)
# 706. perpetu (Count: 10)
# 707. perpetuel (Count: 47)
# 708. person (Count: 84)
# 709. pet (Count: 14)
# 710. peu (Count: 53)
# 711. peupl (Count: 578)
# 712. peuuet (Count: 12)
# 713. peuvent (Count: 71)
# 714. philipp (Count: 50)
# 715. philippel (Count: 11)
# 716. piec (Count: 12)
# 717. pied (Count: 13)
# 718. pierr (Count: 16)
# 719. pirrhus (Count: 10)
# 720. plac (Count: 10)
# 721. plaif (Count: 27)
# 722. plaint (Count: 26)
# 723. planet (Count: 12)
# 724. platon (Count: 25)
# 725. ploi (Count: 12)
# 726. plufpart (Count: 38)
# 727. plusieur (Count: 183)
# 728. plutarqu (Count: 10)
# 729. po (Count: 20)
# 730. poid (Count: 24)
# 731. poinet (Count: 13)
# 732. polemon (Count: 13)
# 733. polyb (Count: 12)
# 734. pontif (Count: 22)
# 735. popu (Count: 10)
# 736. populair (Count: 520)
# 737. port (Count: 47)
# 738. portugal (Count: 10)
# 739. poulongn (Count: 27)
# 740. pourquoy (Count: 19)
# 741. pourr (Count: 12)
# 742. pourroit (Count: 30)
# 743. pourveu (Count: 20)
# 744. pouvoir (Count: 42)
# 745. pratiqu (Count: 14)
# 746. pred (Count: 20)
# 747. prefcript (Count: 20)
# 748. prefenc (Count: 15)
# 749. prefer (Count: 12)
# 750. prefident (Count: 21)
# 751. preiudic (Count: 25)
# 752. pren (Count: 15)
# 753. prend (Count: 11)
# 754. prequ (Count: 37)
# 755. prerogativ (Count: 35)
# 756. present (Count: 59)
# 757. presompt (Count: 10)
# 758. prest (Count: 14)
# 759. pretend (Count: 15)
# 760. pretendr (Count: 19)
# 761. preteur (Count: 19)
# 762. preuoft (Count: 13)
# 763. preuv (Count: 15)
# 764. prifon (Count: 12)
# 765. prin (Count: 42)
# 766. princeff (Count: 11)
# 767. principal (Count: 51)
# 768. print (Count: 21)
# 769. prisonni (Count: 31)
# 770. priv (Count: 36)
# 771. privileg (Count: 106)
# 772. prix (Count: 53)
# 773. proc (Count: 16)
# 774. proch (Count: 24)
# 775. procureur (Count: 18)
# 776. prof (Count: 44)
# 777. prom (Count: 23)
# 778. prophet (Count: 13)
# 779. proport (Count: 45)
# 780. propr (Count: 71)
# 781. propriet (Count: 11)
# 782. prot (Count: 23)
# 783. protect (Count: 63)
# 784. protecteur (Count: 16)
# 785. prouinc (Count: 30)
# 786. public (Count: 103)
# 787. publiqu (Count: 91)
# 788. puif (Count: 17)
# 789. puifn (Count: 30)
# 790. puiss (Count: 16)
# 791. pulair (Count: 12)
# 792. pun (Count: 29)
# 793. pur (Count: 21)
# 794. péfion (Count: 12)
# 795. quaf (Count: 17)
# 796. qualit (Count: 81)
# 797. quandil (Count: 10)
# 798. quant (Count: 79)
# 799. quelconqu (Count: 22)
# 800. question (Count: 77)
# 801. quiest (Count: 25)
# 802. quin (Count: 16)
# 803. quit (Count: 12)
# 804. quitt (Count: 20)
# 805. quoy (Count: 70)
# 806. quád (Count: 30)
# 807. rai (Count: 12)
# 808. raison (Count: 91)
# 809. ran (Count: 10)
# 810. raport (Count: 11)
# 811. ratifi (Count: 12)
# 812. rebel (Count: 22)
# 813. rebellion (Count: 15)
# 814. receuoir (Count: 27)
# 815. reciproqu (Count: 11)
# 816. recognoiftr (Count: 11)
# 817. reduit (Count: 21)
# 818. referu (Count: 32)
# 819. refift (Count: 13)
# 820. reflort (Count: 15)
# 821. refolu (Count: 16)
# 822. refpond (Count: 13)
# 823. refuf (Count: 14)
# 824. regal (Count: 11)
# 825. regent (Count: 16)
# 826. regiftr (Count: 13)
# 827. releu (Count: 13)
# 828. religion (Count: 67)
# 829. remarqu (Count: 16)
# 830. request (Count: 71)
# 831. ressort (Count: 42)
# 832. restitu (Count: 27)
# 833. retranch (Count: 12)
# 834. reuenu (Count: 14)
# 835. reuolt (Count: 23)
# 836. reuoqu (Count: 11)
# 837. rez (Count: 11)
# 838. reçoit (Count: 12)
# 839. rich (Count: 46)
# 840. richeff (Count: 11)
# 841. rom (Count: 57)
# 842. romain (Count: 288)
# 843. roturi (Count: 31)
# 844. rout (Count: 14)
# 845. royau (Count: 12)
# 846. royaut (Count: 12)
# 847. royn (Count: 41)
# 848. ruin (Count: 133)
# 849. ruinal (Count: 10)
# 850. sag (Count: 72)
# 851. sang (Count: 35)
# 852. sathan (Count: 24)
# 853. sauoy (Count: 22)
# 854. savoir (Count: 76)
# 855. sedit (Count: 28)
# 856. seigneur (Count: 564)
# 857. seigneurial (Count: 53)
# 858. sembl (Count: 32)
# 859. semblabl (Count: 24)
# 860. senat (Count: 196)
# 861. senateur (Count: 19)
# 862. septebr (Count: 12)
# 863. septentrion (Count: 17)
# 864. serment (Count: 51)
# 865. servir (Count: 10)
# 866. sicil (Count: 15)
# 867. sigifmond (Count: 10)
# 868. simpl (Count: 17)
# 869. sinon (Count: 23)
# 870. soleil (Count: 17)
# 871. solon (Count: 23)
# 872. sorci (Count: 134)
# 873. sous (Count: 63)
# 874. souvent (Count: 146)
# 875. soyent (Count: 84)
# 876. statut (Count: 15)
# 877. succeed (Count: 30)
# 878. successeur (Count: 56)
# 879. sued (Count: 26)
# 880. suifl (Count: 15)
# 881. superieur (Count: 21)
# 882. tabl (Count: 18)
# 883. taill (Count: 39)
# 884. temp (Count: 30)
# 885. ten (Count: 20)
# 886. tenu (Count: 105)
# 887. tenus (Count: 25)
# 888. term (Count: 29)
# 889. test (Count: 11)
# 890. thrac (Count: 12)
# 891. thun (Count: 10)
# 892. tiennent (Count: 34)
# 893. tient (Count: 34)
# 894. tion (Count: 26)
# 895. titr (Count: 27)
# 896. tomb (Count: 20)
# 897. touch (Count: 29)
# 898. touchent (Count: 15)
# 899. tousl (Count: 22)
# 900. toutesfoisil (Count: 10)
# 901. toutsl (Count: 16)
# 902. trefor (Count: 23)
# 903. tribun (Count: 24)
# 904. tributair (Count: 32)
# 905. tuition (Count: 10)
# 906. turqu (Count: 12)
# 907. tyran (Count: 91)
# 908. tyrann (Count: 55)
# 909. tyrannic (Count: 12)
# 910. té (Count: 21)
# 911. uc (Count: 12)
# 912. uer (Count: 20)
# 913. uerain (Count: 17)
# 914. uget (Count: 11)
# 915. uit (Count: 10)
# 916. uoit (Count: 15)
# 917. va (Count: 26)
# 918. vaincu (Count: 25)
# 919. vainqueur (Count: 19)
# 920. valois (Count: 12)
# 921. vassal (Count: 108)
# 922. ven (Count: 11)
# 923. venitien (Count: 17)
# 924. veniz (Count: 37)
# 925. verifi (Count: 10)
# 926. verit (Count: 39)
# 927. vertu (Count: 73)
# 928. vertueux (Count: 43)
# 929. veu (Count: 125)
# 930. veut (Count: 42)
# 931. veux (Count: 10)
# 932. vfer (Count: 18)
# 933. vfurp (Count: 11)
# 934. vic (Count: 24)
# 935. vicair (Count: 27)
# 936. victoir (Count: 10)
# 937. vient (Count: 18)
# 938. vill (Count: 205)
# 939. viénent (Count: 10)
# 940. vni (Count: 27)
# 941. vnion (Count: 10)
# 942. voi (Count: 11)
# 943. voifin (Count: 11)
# 944. voil (Count: 22)
# 945. voir (Count: 43)
# 946. voit (Count: 97)
# 947. voix (Count: 16)
# 948. voleur (Count: 26)
# 949. voulut (Count: 18)
# 950. voy (Count: 18)
# 951. vray (Count: 104)
# 952. vtil (Count: 26)
# 953. yn (Count: 18)
# 954. àla (Count: 15)
# 955. édict (Count: 154)
# Type 'refine' to try a new threshold, or press Enter to proceed:  refine
# Enter the minimum count threshold for collocates to include:  20
# Collocates with counts >= 20 (479 items):
# 1. abíolu (Count: 21)
# 2. accord (Count: 28)
# 3. action (Count: 37)
# 4. adopt (Count: 20)
# 5. aduint (Count: 30)
# 6. advient (Count: 31)
# 7. advis (Count: 62)
# 8. affair (Count: 79)
# 9. affembl (Count: 27)
# 10. affeur (Count: 35)
# 11. affin (Count: 21)
# 12. afi (Count: 35)
# 13. afin (Count: 28)
# 14. afranch (Count: 20)
# 15. afriqu (Count: 23)
# 16. age (Count: 26)
# 17. aif (Count: 34)
# 18. ainsauss (Count: 21)
# 19. aisn (Count: 56)
# 20. alli (Count: 44)
# 21. allianc (Count: 95)
# 22. almaign (Count: 60)
# 23. ambaffadeur (Count: 25)
# 24. ambafladeur (Count: 22)
# 25. amend (Count: 22)
# 26. amis (Count: 27)
# 27. amiti (Count: 25)
# 28. ancien (Count: 178)
# 29. angleterr (Count: 158)
# 30. apparent (Count: 29)
# 31. appel (Count: 76)
# 32. argent (Count: 47)
# 33. ariftocrat (Count: 101)
# 34. aristocrat (Count: 183)
# 35. aristot (Count: 42)
# 36. arithmet (Count: 40)
# 37. arme (Count: 55)
# 38. arragon (Count: 50)
# 39. arrest (Count: 117)
# 40. athen (Count: 28)
# 41. attendu (Count: 60)
# 42. auff (Count: 36)
# 43. aufs (Count: 20)
# 44. auquel (Count: 28)
# 45. auroit (Count: 22)
# 46. aussil (Count: 20)
# 47. autruy (Count: 135)
# 48. avon (Count: 66)
# 49. bann (Count: 26)
# 50. beau (Count: 28)
# 51. beaucoup (Count: 50)
# 52. befoin (Count: 21)
# 53. bel (Count: 31)
# 54. benefic (Count: 23)
# 55. ble (Count: 29)
# 56. bon (Count: 39)
# 57. bourgeois (Count: 71)
# 58. caftill (Count: 21)
# 59. canton (Count: 23)
# 60. capitain (Count: 88)
# 61. capital (Count: 24)
# 62. caril (Count: 47)
# 63. carl (Count: 48)
# 64. cas (Count: 123)
# 65. caus (Count: 32)
# 66. celest (Count: 24)
# 67. cenfeur (Count: 24)
# 68. certain (Count: 94)
# 69. cftat (Count: 40)
# 70. chaff (Count: 49)
# 71. chafl (Count: 32)
# 72. chang (Count: 171)
# 73. changemen (Count: 57)
# 74. charg (Count: 107)
# 75. charl (Count: 154)
# 76. chef (Count: 93)
# 77. choif (Count: 20)
# 78. chois (Count: 25)
# 79. chrestien (Count: 20)
# 80. cit (Count: 52)
# 81. citoyen (Count: 156)
# 82. cognoiftr (Count: 21)
# 83. colleg (Count: 111)
# 84. collegu (Count: 24)
# 85. combien (Count: 44)
# 86. command (Count: 255)
# 87. commeil (Count: 24)
# 88. comment (Count: 23)
# 89. commiss (Count: 25)
# 90. commissair (Count: 36)
# 91. commission (Count: 32)
# 92. commun (Count: 71)
# 93. communaut (Count: 41)
# 94. comt (Count: 31)
# 95. con (Count: 26)
# 96. condamn (Count: 42)
# 97. conferu (Count: 36)
# 98. confess (Count: 24)
# 99. confifqu (Count: 24)
# 100. conseil (Count: 183)
# 101. consent (Count: 23)
# 102. consul (Count: 23)
# 103. contrair (Count: 55)
# 104. contrel (Count: 41)
# 105. corp (Count: 94)
# 106. cotr (Count: 22)
# 107. cour (Count: 123)
# 108. couron (Count: 141)
# 109. coustum (Count: 137)
# 110. crim (Count: 47)
# 111. cruaut (Count: 30)
# 112. dang (Count: 36)
# 113. danger (Count: 25)
# 114. dannemarc (Count: 30)
# 115. declar (Count: 26)
# 116. decret (Count: 23)
# 117. defens (Count: 36)
# 118. deleur (Count: 39)
# 119. demeur (Count: 50)
# 120. deni (Count: 55)
# 121. deput (Count: 22)
# 122. derni (Count: 43)
# 123. derog (Count: 26)
# 124. dessus (Count: 98)
# 125. deu (Count: 35)
# 126. diabl (Count: 38)
# 127. dieu (Count: 594)
# 128. differend (Count: 22)
# 129. different (Count: 67)
# 130. difpof (Count: 42)
# 131. diftribu (Count: 35)
# 132. dir (Count: 178)
# 133. diron (Count: 27)
# 134. disoit (Count: 54)
# 135. divin (Count: 99)
# 136. divis (Count: 24)
# 137. doibuent (Count: 29)
# 138. doit (Count: 353)
# 139. domain (Count: 62)
# 140. dommag (Count: 20)
# 141. don (Count: 259)
# 142. donc (Count: 24)
# 143. donne (Count: 21)
# 144. doubt (Count: 46)
# 145. droiet (Count: 21)
# 146. duc (Count: 115)
# 147. dy (Count: 31)
# 148. efcrit (Count: 34)
# 149. effect (Count: 20)
# 150. efgal (Count: 32)
# 151. efleu (Count: 68)
# 152. eflir (Count: 22)
# 153. egal (Count: 39)
# 154. eglis (Count: 22)
# 155. ele (Count: 22)
# 156. elect (Count: 20)
# 157. empereur (Count: 247)
# 158. empir (Count: 241)
# 159. ence (Count: 20)
# 160. enfant (Count: 130)
# 161. enla (Count: 25)
# 162. ennemy (Count: 116)
# 163. ensembl (Count: 28)
# 164. entre (Count: 113)
# 165. entrel (Count: 33)
# 166. entreten (Count: 24)
# 167. enver (Count: 60)
# 168. equal (Count: 41)
# 169. equit (Count: 61)
# 170. esclav (Count: 120)
# 171. escus (Count: 25)
# 172. espaigne (Count: 42)
# 173. esprit (Count: 43)
# 174. establ (Count: 57)
# 175. estrang (Count: 40)
# 176. estranger (Count: 69)
# 177. està (Count: 22)
# 178. except (Count: 32)
# 179. execu (Count: 24)
# 180. execut (Count: 21)
# 181. exempl (Count: 41)
# 182. exempt (Count: 48)
# 183. expedient (Count: 21)
# 184. extrem (Count: 34)
# 185. fac (Count: 42)
# 186. facr (Count: 23)
# 187. famill (Count: 116)
# 188. faueur (Count: 40)
# 189. femm (Count: 74)
# 190. fer (Count: 85)
# 191. feuret (Count: 26)
# 192. fez (Count: 23)
# 193. fief (Count: 27)
# 194. fien (Count: 37)
# 195. fill (Count: 43)
# 196. fin (Count: 40)
# 197. financ (Count: 65)
# 198. fion (Count: 21)
# 199. fix (Count: 21)
# 200. florenc (Count: 27)
# 201. foient (Count: 25)
# 202. fol (Count: 28)
# 203. forc (Count: 132)
# 204. form (Count: 50)
# 205. fort (Count: 110)
# 206. foy (Count: 142)
# 207. fran (Count: 21)
# 208. franc (Count: 298)
# 209. françois (Count: 65)
# 210. frer (Count: 35)
# 211. fráce (Count: 34)
# 212. fucceff (Count: 29)
# 213. fuccefl (Count: 30)
# 214. gard (Count: 108)
# 215. gen (Count: 51)
# 216. general (Count: 117)
# 217. geometr (Count: 38)
# 218. gift (Count: 58)
# 219. gouuernemet (Count: 34)
# 220. gouvern (Count: 118)
# 221. gouverneur (Count: 22)
# 222. grac (Count: 38)
# 223. grandeur (Count: 20)
# 224. grec (Count: 31)
# 225. grád (Count: 26)
# 226. guerr (Count: 392)
# 227. habitan (Count: 21)
# 228. harmon (Count: 83)
# 229. haut (Count: 25)
# 230. hebrieu (Count: 20)
# 231. henr (Count: 27)
# 232. henry (Count: 38)
# 233. her (Count: 21)
# 234. heriti (Count: 29)
# 235. homm (Count: 57)
# 236. hommag (Count: 111)
# 237. hongr (Count: 41)
# 238. honneur (Count: 124)
# 239. honnor (Count: 20)
# 240. hor (Count: 29)
# 241. humain (Count: 56)
# 242. iacoit (Count: 36)
# 243. icel (Count: 37)
# 244. iiij (Count: 31)
# 245. ila (Count: 23)
# 246. imag (Count: 20)
# 247. imperial (Count: 56)
# 248. impost (Count: 34)
# 249. iniqu (Count: 30)
# 250. iniur (Count: 22)
# 251. iniust (Count: 31)
# 252. interest (Count: 27)
# 253. ital (Count: 32)
# 254. iur (Count: 28)
# 255. iurisdict (Count: 47)
# 256. jug (Count: 446)
# 257. lacedemonien (Count: 30)
# 258. lafoy (Count: 21)
# 259. legifl (Count: 20)
# 260. legitim (Count: 21)
# 261. lesautr (Count: 36)
# 262. lettr (Count: 80)
# 263. lez (Count: 26)
# 264. libert (Count: 70)
# 265. licit (Count: 24)
# 266. lieu (Count: 34)
# 267. lig (Count: 43)
# 268. ligu (Count: 79)
# 269. lou (Count: 86)
# ...
# 116. femm (Count: 74)
# 117. fer (Count: 85)
# 118. fien (Count: 37)
# 119. fill (Count: 43)
# 120. fin (Count: 40)
# 121. financ (Count: 65)
# 122. forc (Count: 132)
# 123. form (Count: 50)
# 124. fort (Count: 110)
# 125. foy (Count: 142)
# 126. franc (Count: 298)
# 127. françois (Count: 65)
# 128. frer (Count: 35)
# 129. fráce (Count: 34)
# 130. fuccefl (Count: 30)
# 131. gard (Count: 108)
# 132. gen (Count: 51)
# 133. general (Count: 117)
# 134. geometr (Count: 38)
# 135. gift (Count: 58)
# 136. gouuernemet (Count: 34)
# 137. gouvern (Count: 118)
# 138. grac (Count: 38)
# 139. grec (Count: 31)
# 140. guerr (Count: 392)
# 141. harmon (Count: 83)
# 142. henry (Count: 38)
# 143. homm (Count: 57)
# 144. hommag (Count: 111)
# 145. hongr (Count: 41)
# 146. honneur (Count: 124)
# 147. humain (Count: 56)
# 148. iacoit (Count: 36)
# 149. icel (Count: 37)
# 150. iiij (Count: 31)
# 151. imperial (Count: 56)
# 152. impost (Count: 34)
# 153. iniqu (Count: 30)
# 154. iniust (Count: 31)
# 155. ital (Count: 32)
# 156. iurisdict (Count: 47)
# 157. jug (Count: 446)
# 158. lacedemonien (Count: 30)
# 159. lesautr (Count: 36)
# 160. lettr (Count: 80)
# 161. libert (Count: 70)
# 162. lieu (Count: 34)
# 163. lig (Count: 43)
# 164. ligu (Count: 79)
# 165. lou (Count: 86)
# 166. loyer (Count: 47)
# 167. macedoin (Count: 55)
# 168. magistrat (Count: 732)
# 169. main (Count: 54)
# 170. mainten (Count: 40)
# 171. maison (Count: 77)
# 172. mand (Count: 58)
# 173. mandemen (Count: 34)
# 174. mar (Count: 98)
# 175. marc (Count: 32)
# 176. marqu (Count: 134)
# 177. menu (Count: 59)
# 178. merit (Count: 48)
# 179. meur (Count: 35)
# 180. mieux (Count: 123)
# 181. milan (Count: 32)
# 182. moin (Count: 86)
# 183. moindr (Count: 32)
# 184. monarch (Count: 279)
# 185. monarqu (Count: 121)
# 186. mond (Count: 38)
# 187. monnoy (Count: 59)
# 188. monstr (Count: 114)
# 189. mort (Count: 164)
# 190. mot (Count: 57)
# 191. moyen (Count: 61)
# 192. napl (Count: 60)
# 193. natur (Count: 132)
# 194. naturel (Count: 234)
# 195. nobl (Count: 54)
# 196. nobleff (Count: 36)
# 197. nombr (Count: 65)
# 198. noy (Count: 53)
# 199. obeir (Count: 39)
# 200. obeiss (Count: 96)
# 201. oblig (Count: 110)
# 202. occafion (Count: 72)
# 203. offic (Count: 176)
# 204. offici (Count: 168)
# 205. ordinair (Count: 85)
# 206. ordon (Count: 381)
# 207. ore (Count: 138)
# 208. outr (Count: 50)
# 209. paix (Count: 132)
# 210. pap (Count: 167)
# 211. parau (Count: 35)
# 212. part (Count: 102)
# 213. particuli (Count: 205)
# 214. pauur (Count: 53)
# 215. pay (Count: 218)
# 216. pein (Count: 154)
# 217. per (Count: 89)
# 218. perpetuel (Count: 47)
# 219. person (Count: 84)
# 220. peu (Count: 53)
# 221. peupl (Count: 578)
# 222. peuvent (Count: 71)
# 223. philipp (Count: 50)
# 224. plufpart (Count: 38)
# 225. plusieur (Count: 183)
# 226. populair (Count: 520)
# 227. port (Count: 47)
# 228. pourroit (Count: 30)
# 229. pouvoir (Count: 42)
# 230. prequ (Count: 37)
# 231. prerogativ (Count: 35)
# 232. present (Count: 59)
# 233. prin (Count: 42)
# 234. principal (Count: 51)
# 235. prisonni (Count: 31)
# 236. priv (Count: 36)
# 237. privileg (Count: 106)
# 238. prix (Count: 53)
# 239. prof (Count: 44)
# 240. proport (Count: 45)
# 241. propr (Count: 71)
# 242. protect (Count: 63)
# 243. prouinc (Count: 30)
# 244. public (Count: 103)
# 245. publiqu (Count: 91)
# 246. puifn (Count: 30)
# 247. qualit (Count: 81)
# 248. quant (Count: 79)
# 249. question (Count: 77)
# 250. quoy (Count: 70)
# 251. quád (Count: 30)
# 252. raison (Count: 91)
# 253. referu (Count: 32)
# 254. religion (Count: 67)
# 255. request (Count: 71)
# 256. ressort (Count: 42)
# 257. rich (Count: 46)
# 258. rom (Count: 57)
# 259. romain (Count: 288)
# 260. roturi (Count: 31)
# 261. royn (Count: 41)
# 262. ruin (Count: 133)
# 263. sag (Count: 72)
# 264. sang (Count: 35)
# 265. savoir (Count: 76)
# 266. seigneur (Count: 564)
# 267. seigneurial (Count: 53)
# 268. sembl (Count: 32)
# 269. senat (Count: 196)
# 270. serment (Count: 51)
# 271. sorci (Count: 134)
# 272. sous (Count: 63)
# 273. souvent (Count: 146)
# 274. soyent (Count: 84)
# 275. succeed (Count: 30)
# 276. successeur (Count: 56)
# 277. taill (Count: 39)
# 278. temp (Count: 30)
# 279. tenu (Count: 105)
# 280. tiennent (Count: 34)
# 281. tient (Count: 34)
# 282. tributair (Count: 32)
# 283. tyran (Count: 91)
# 284. tyrann (Count: 55)
# 285. vassal (Count: 108)
# 286. veniz (Count: 37)
# 287. verit (Count: 39)
# 288. vertu (Count: 73)
# 289. vertueux (Count: 43)
# 290. veu (Count: 125)
# 291. veut (Count: 42)
# 292. vill (Count: 205)
# 293. voir (Count: 43)
# 294. voit (Count: 97)
# 295. vray (Count: 104)
# 296. édict (Count: 154)
# Type 'refine' to try a new threshold, or press Enter to proceed:  refine
# Enter the minimum count threshold for collocates to include:  40
# Collocates with counts >= 40 (217 items):
# 1. advis (Count: 62)
# 2. affair (Count: 79)
# 3. aisn (Count: 56)
# 4. alli (Count: 44)
# 5. allianc (Count: 95)
# 6. almaign (Count: 60)
# 7. ancien (Count: 178)
# 8. angleterr (Count: 158)
# 9. appel (Count: 76)
# 10. argent (Count: 47)
# 11. ariftocrat (Count: 101)
# 12. aristocrat (Count: 183)
# 13. aristot (Count: 42)
# 14. arithmet (Count: 40)
# 15. arme (Count: 55)
# 16. arragon (Count: 50)
# 17. arrest (Count: 117)
# 18. attendu (Count: 60)
# 19. autruy (Count: 135)
# 20. avon (Count: 66)
# 21. beaucoup (Count: 50)
# 22. bourgeois (Count: 71)
# 23. capitain (Count: 88)
# 24. caril (Count: 47)
# 25. carl (Count: 48)
# 26. cas (Count: 123)
# 27. certain (Count: 94)
# 28. cftat (Count: 40)
# 29. chaff (Count: 49)
# 30. chang (Count: 171)
# 31. changemen (Count: 57)
# 32. charg (Count: 107)
# 33. charl (Count: 154)
# 34. chef (Count: 93)
# 35. cit (Count: 52)
# 36. citoyen (Count: 156)
# 37. colleg (Count: 111)
# 38. combien (Count: 44)
# 39. command (Count: 255)
# 40. commun (Count: 71)
# 41. communaut (Count: 41)
# 42. condamn (Count: 42)
# 43. conseil (Count: 183)
# 44. contrair (Count: 55)
# 45. contrel (Count: 41)
# 46. corp (Count: 94)
# 47. cour (Count: 123)
# 48. couron (Count: 141)
# 49. coustum (Count: 137)
# 50. crim (Count: 47)
# 51. demeur (Count: 50)
# 52. deni (Count: 55)
# 53. derni (Count: 43)
# 54. dessus (Count: 98)
# 55. dieu (Count: 594)
# 56. different (Count: 67)
# 57. difpof (Count: 42)
# 58. dir (Count: 178)
# 59. disoit (Count: 54)
# 60. divin (Count: 99)
# 61. doit (Count: 353)
# 62. domain (Count: 62)
# 63. don (Count: 259)
# 64. doubt (Count: 46)
# 65. duc (Count: 115)
# 66. efleu (Count: 68)
# 67. empereur (Count: 247)
# 68. empir (Count: 241)
# 69. enfant (Count: 130)
# 70. ennemy (Count: 116)
# 71. entre (Count: 113)
# 72. enver (Count: 60)
# 73. equal (Count: 41)
# 74. equit (Count: 61)
# 75. esclav (Count: 120)
# 76. espaigne (Count: 42)
# 77. esprit (Count: 43)
# 78. establ (Count: 57)
# 79. estrang (Count: 40)
# 80. estranger (Count: 69)
# 81. exempl (Count: 41)
# 82. exempt (Count: 48)
# 83. fac (Count: 42)
# 84. famill (Count: 116)
# 85. faueur (Count: 40)
# 86. femm (Count: 74)
# 87. fer (Count: 85)
# 88. fill (Count: 43)
# 89. fin (Count: 40)
# 90. financ (Count: 65)
# 91. forc (Count: 132)
# 92. form (Count: 50)
# 93. fort (Count: 110)
# 94. foy (Count: 142)
# 95. franc (Count: 298)
# 96. françois (Count: 65)
# 97. gard (Count: 108)
# 98. gen (Count: 51)
# 99. general (Count: 117)
# 100. gift (Count: 58)
# 101. gouvern (Count: 118)
# 102. guerr (Count: 392)
# 103. harmon (Count: 83)
# 104. homm (Count: 57)
# 105. hommag (Count: 111)
# 106. hongr (Count: 41)
# 107. honneur (Count: 124)
# 108. humain (Count: 56)
# 109. imperial (Count: 56)
# 110. iurisdict (Count: 47)
# 111. jug (Count: 446)
# 112. lettr (Count: 80)
# 113. libert (Count: 70)
# 114. lig (Count: 43)
# 115. ligu (Count: 79)
# 116. lou (Count: 86)
# 117. loyer (Count: 47)
# 118. macedoin (Count: 55)
# 119. magistrat (Count: 732)
# 120. main (Count: 54)
# 121. mainten (Count: 40)
# 122. maison (Count: 77)
# 123. mand (Count: 58)
# 124. mar (Count: 98)
# 125. marqu (Count: 134)
# 126. menu (Count: 59)
# 127. merit (Count: 48)
# 128. mieux (Count: 123)
# 129. moin (Count: 86)
# 130. monarch (Count: 279)
# 131. monarqu (Count: 121)
# 132. monnoy (Count: 59)
# 133. monstr (Count: 114)
# 134. mort (Count: 164)
# 135. mot (Count: 57)
# 136. moyen (Count: 61)
# 137. napl (Count: 60)
# 138. natur (Count: 132)
# 139. naturel (Count: 234)
# 140. nobl (Count: 54)
# 141. nombr (Count: 65)
# 142. noy (Count: 53)
# 143. obeiss (Count: 96)
# 144. oblig (Count: 110)
# 145. occafion (Count: 72)
# 146. offic (Count: 176)
# 147. offici (Count: 168)
# 148. ordinair (Count: 85)
# 149. ordon (Count: 381)
# 150. ore (Count: 138)
# 151. outr (Count: 50)
# 152. paix (Count: 132)
# 153. pap (Count: 167)
# 154. part (Count: 102)
# 155. particuli (Count: 205)
# 156. pauur (Count: 53)
# 157. pay (Count: 218)
# 158. pein (Count: 154)
# 159. per (Count: 89)
# 160. perpetuel (Count: 47)
# 161. person (Count: 84)
# 162. peu (Count: 53)
# 163. peupl (Count: 578)
# 164. peuvent (Count: 71)
# 165. philipp (Count: 50)
# 166. plusieur (Count: 183)
# 167. populair (Count: 520)
# 168. port (Count: 47)
# 169. pouvoir (Count: 42)
# 170. present (Count: 59)
# 171. prin (Count: 42)
# 172. principal (Count: 51)
# 173. privileg (Count: 106)
# 174. prix (Count: 53)
# 175. prof (Count: 44)
# 176. proport (Count: 45)
# 177. propr (Count: 71)
# 178. protect (Count: 63)
# 179. public (Count: 103)
# 180. publiqu (Count: 91)
# 181. qualit (Count: 81)
# 182. quant (Count: 79)
# 183. question (Count: 77)
# 184. quoy (Count: 70)
# 185. raison (Count: 91)
# 186. religion (Count: 67)
# 187. request (Count: 71)
# 188. ressort (Count: 42)
# 189. rich (Count: 46)
# 190. rom (Count: 57)
# 191. romain (Count: 288)
# 192. royn (Count: 41)
# 193. ruin (Count: 133)
# 194. sag (Count: 72)
# 195. savoir (Count: 76)
# 196. seigneur (Count: 564)
# 197. seigneurial (Count: 53)
# 198. senat (Count: 196)
# 199. serment (Count: 51)
# 200. sorci (Count: 134)
# 201. sous (Count: 63)
# 202. souvent (Count: 146)
# 203. soyent (Count: 84)
# 204. successeur (Count: 56)
# 205. tenu (Count: 105)
# 206. tyran (Count: 91)
# 207. tyrann (Count: 55)
# 208. vassal (Count: 108)
# 209. vertu (Count: 73)
# 210. vertueux (Count: 43)
# 211. veu (Count: 125)
# 212. veut (Count: 42)
# 213. vill (Count: 205)
# 214. voir (Count: 43)
# 215. voit (Count: 97)
# 216. vray (Count: 104)
# 217. édict (Count: 154)
# Type 'refine' to try a new threshold, or press Enter to proceed:  refine
# Enter the minimum count threshold for collocates to include:  45
# Collocates with counts >= 45 (187 items):
# 1. advis (Count: 62)
# 2. affair (Count: 79)
# 3. aisn (Count: 56)
# 4. allianc (Count: 95)
# 5. almaign (Count: 60)
# 6. ancien (Count: 178)
# 7. angleterr (Count: 158)
# 8. appel (Count: 76)
# 9. argent (Count: 47)
# 10. ariftocrat (Count: 101)
# 11. aristocrat (Count: 183)
# 12. arme (Count: 55)
# 13. arragon (Count: 50)
# 14. arrest (Count: 117)
# 15. attendu (Count: 60)
# 16. autruy (Count: 135)
# 17. avon (Count: 66)
# 18. beaucoup (Count: 50)
# 19. bourgeois (Count: 71)
# 20. capitain (Count: 88)
# 21. caril (Count: 47)
# 22. carl (Count: 48)
# 23. cas (Count: 123)
# 24. certain (Count: 94)
# 25. chaff (Count: 49)
# 26. chang (Count: 171)
# 27. changemen (Count: 57)
# 28. charg (Count: 107)
# 29. charl (Count: 154)
# 30. chef (Count: 93)
# 31. cit (Count: 52)
# 32. citoyen (Count: 156)
# 33. colleg (Count: 111)
# 34. command (Count: 255)
# 35. commun (Count: 71)
# 36. conseil (Count: 183)
# 37. contrair (Count: 55)
# 38. corp (Count: 94)
# 39. cour (Count: 123)
# 40. couron (Count: 141)
# 41. coustum (Count: 137)
# 42. crim (Count: 47)
# 43. demeur (Count: 50)
# 44. deni (Count: 55)
# 45. dessus (Count: 98)
# 46. dieu (Count: 594)
# 47. different (Count: 67)
# 48. dir (Count: 178)
# 49. disoit (Count: 54)
# 50. divin (Count: 99)
# 51. doit (Count: 353)
# 52. domain (Count: 62)
# 53. don (Count: 259)
# 54. doubt (Count: 46)
# 55. duc (Count: 115)
# 56. efleu (Count: 68)
# 57. empereur (Count: 247)
# 58. empir (Count: 241)
# 59. enfant (Count: 130)
# 60. ennemy (Count: 116)
# 61. entre (Count: 113)
# 62. enver (Count: 60)
# 63. equit (Count: 61)
# 64. esclav (Count: 120)
# 65. establ (Count: 57)
# 66. estranger (Count: 69)
# 67. exempt (Count: 48)
# 68. famill (Count: 116)
# 69. femm (Count: 74)
# 70. fer (Count: 85)
# 71. financ (Count: 65)
# 72. forc (Count: 132)
# 73. form (Count: 50)
# 74. fort (Count: 110)
# 75. foy (Count: 142)
# 76. franc (Count: 298)
# 77. françois (Count: 65)
# 78. gard (Count: 108)
# 79. gen (Count: 51)
# 80. general (Count: 117)
# 81. gift (Count: 58)
# 82. gouvern (Count: 118)
# 83. guerr (Count: 392)
# 84. harmon (Count: 83)
# 85. homm (Count: 57)
# 86. hommag (Count: 111)
# 87. honneur (Count: 124)
# 88. humain (Count: 56)
# 89. imperial (Count: 56)
# 90. iurisdict (Count: 47)
# 91. jug (Count: 446)
# 92. lettr (Count: 80)
# 93. libert (Count: 70)
# 94. ligu (Count: 79)
# 95. lou (Count: 86)
# 96. loyer (Count: 47)
# 97. macedoin (Count: 55)
# 98. magistrat (Count: 732)
# 99. main (Count: 54)
# 100. maison (Count: 77)
# 101. mand (Count: 58)
# 102. mar (Count: 98)
# 103. marqu (Count: 134)
# 104. menu (Count: 59)
# 105. merit (Count: 48)
# 106. mieux (Count: 123)
# 107. moin (Count: 86)
# 108. monarch (Count: 279)
# 109. monarqu (Count: 121)
# 110. monnoy (Count: 59)
# 111. monstr (Count: 114)
# 112. mort (Count: 164)
# 113. mot (Count: 57)
# 114. moyen (Count: 61)
# 115. napl (Count: 60)
# 116. natur (Count: 132)
# 117. naturel (Count: 234)
# 118. nobl (Count: 54)
# 119. nombr (Count: 65)
# 120. noy (Count: 53)
# 121. obeiss (Count: 96)
# 122. oblig (Count: 110)
# 123. occafion (Count: 72)
# 124. offic (Count: 176)
# 125. offici (Count: 168)
# 126. ordinair (Count: 85)
# 127. ordon (Count: 381)
# 128. ore (Count: 138)
# 129. outr (Count: 50)
# 130. paix (Count: 132)
# 131. pap (Count: 167)
# 132. part (Count: 102)
# 133. particuli (Count: 205)
# 134. pauur (Count: 53)
# 135. pay (Count: 218)
# 136. pein (Count: 154)
# 137. per (Count: 89)
# 138. perpetuel (Count: 47)
# 139. person (Count: 84)
# 140. peu (Count: 53)
# 141. peupl (Count: 578)
# 142. peuvent (Count: 71)
# 143. philipp (Count: 50)
# 144. plusieur (Count: 183)
# 145. populair (Count: 520)
# 146. port (Count: 47)
# 147. present (Count: 59)
# 148. principal (Count: 51)
# 149. privileg (Count: 106)
# 150. prix (Count: 53)
# 151. proport (Count: 45)
# 152. propr (Count: 71)
# 153. protect (Count: 63)
# 154. public (Count: 103)
# 155. publiqu (Count: 91)
# 156. qualit (Count: 81)
# 157. quant (Count: 79)
# 158. question (Count: 77)
# 159. quoy (Count: 70)
# 160. raison (Count: 91)
# 161. religion (Count: 67)
# 162. request (Count: 71)
# 163. rich (Count: 46)
# 164. rom (Count: 57)
# 165. romain (Count: 288)
# 166. ruin (Count: 133)
# 167. sag (Count: 72)
# 168. savoir (Count: 76)
# 169. seigneur (Count: 564)
# 170. seigneurial (Count: 53)
# 171. senat (Count: 196)
# 172. serment (Count: 51)
# 173. sorci (Count: 134)
# 174. sous (Count: 63)
# 175. souvent (Count: 146)
# 176. soyent (Count: 84)
# 177. successeur (Count: 56)
# 178. tenu (Count: 105)
# 179. tyran (Count: 91)
# 180. tyrann (Count: 55)
# 181. vassal (Count: 108)
# 182. vertu (Count: 73)
# 183. veu (Count: 125)
# 184. vill (Count: 205)
# 185. voit (Count: 97)
# 186. vray (Count: 104)
# 187. édict (Count: 154)
# Type 'refine' to try a new threshold, or press Enter to proceed:  32,38,40,52,58,63,68,71,82,84,90,93,100,103,108,109,110,117,121,122,135,138,145,149,154,155,169,170,177,179,180,181,187
# You can select collocates by entering:
# - A single number (e.g., 3) to select one collocate.
# - A range of numbers (e.g., 3-6) to select multiple collocates.
# - Multiple selections separated by commas (e.g., 3,5-7,9).
# - Type 'all' to select all collocates.
# - Type 'done' to finalize your selection.
# Enter your selection:  32,38,40,52,58,63,68,71,82,84,90,93,100,103,108,109,110,117,121,122,135,138,145,149,154,155,169,170,177,179,180,181,187
# Currently selected collocates:
# citoyen
# corp
# couron
# domain
# empir
# equit
# famill
# financ
# gouvern
# harmon
# iurisdict
# libert
# maison
# marqu
# monarch
# monarqu
# monnoy
# naturel
# obeiss
# oblig
# pay
# perpetuel
# populair
# privileg
# public
# publiqu
# seigneur
# seigneurial
# successeur
# tyran
# tyrann
# vassal
# édict
# Enter your selection:  done
# Finalized collocates:
# 1. citoyen
# 2. corp
# 3. couron
# 4. domain
# 5. empir
# 6. equit
# 7. famill
# 8. financ
# 9. gouvern
# 10. harmon
# 11. iurisdict
# 12. libert
# 13. maison
# 14. marqu
# 15. monarch
# 16. monarqu
# 17. monnoy
# 18. naturel
# 19. obeiss
# 20. oblig
# 21. pay
# 22. perpetuel
# 23. populair
# 24. privileg
# 25. public
# 26. publiqu
# 27. seigneur
# 28. seigneurial
# 29. successeur
# 30. tyran
# 31. tyrann
# 32. vassal
# 33. édict
# Would you like to remove any collocates selected in error? (yes/no):  no
# Automatically included hidden keyword collocates: ['absolu', 'bien', 'chos', 'civil', 'droit', 'estat', 'just', 'justic', 'loi', 'maiest', 'princ', 'puissanc', 'republ', 'roy', 'royal', 'royaum', 'souverain', 'souverainet', 'sujet']
# Save results for Hypothesis 5? (yes/no):  yes
# Results up to Hypothesis 5 saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/concordances/15winsum.xlsx.
# Exit after this hypothesis? (yes/no):  yes
# Exiting.
