# %%
import re
import os
from collections import Counter

def select_files():
    # List all text files in the current directory
    txt_files = sorted([f for f in os.listdir() if f.endswith('.txt')])
    if not txt_files:
        print("No text files found in the current directory.")
        return []

    print("Available text files:")
    for i, file in enumerate(txt_files):
        print(f"{i + 1}. {file}")
    print("Enter 'all' to select all files.")

    selected_files = []
    while True:
        user_input = input("Select file numbers (individual, ranges, or 'all'): ")
        if not user_input:
            break

        if user_input.strip().lower() == 'all':
            selected_files = txt_files[:]
            break
        else:
            try:
                parts = user_input.split(',')
                for part in parts:
                    if '-' in part:
                        start, end = map(int, part.split('-'))
                        selected_files.extend(txt_files[start - 1:end])
                    else:
                        selected_files.append(txt_files[int(part) - 1])
                break
            except (ValueError, IndexError):
                print("Invalid input. Please enter valid numbers, ranges, or 'all'.")

    return selected_files

def search_pattern(file_paths, pattern):
    results = {}

    for file_path in file_paths:
        with open(file_path, 'r') as file:
            text = file.read()
            matches = pattern.findall(text)
            counter = Counter(matches)
            results[file_path] = counter

    for file_path, counter in results.items():
        print(f"Results for {file_path}:")
        for word, count in counter.items():
            print(f"'{word}': {count}")
        print()

def main():
    file_paths = select_files()
    if file_paths:
        regex_pattern = input("Enter the regex pattern: ")
        try:
            pattern = re.compile(regex_pattern)
            search_pattern(file_paths, pattern)
        except re.error:
            print("Invalid regex pattern. Please try again.")
            main()

# %%
if __name__ == "__main__":
    main()
# Out:
# Available text files:
# 1. Discours des raisons_corrected_stemmed.txt
# 2. Démonomanie I.1_corrected_stemmed.txt
# 3. Démonomanie I.2_corrected_stemmed.txt
# 4. Démonomanie I.3_corrected_stemmed.txt
# 5. Démonomanie I.4_corrected_stemmed.txt
# 6. Démonomanie I.5_corrected_stemmed.txt
# 7. Démonomanie I.6_corrected_stemmed.txt
# 8. Démonomanie I.7_corrected_stemmed.txt
# 9. Démonomanie II.1_corrected_stemmed.txt
# 10. Démonomanie II.2_corrected_stemmed.txt
# 11. Démonomanie II.3_corrected_stemmed.txt
# 12. Démonomanie II.4_corrected_stemmed.txt
# 13. Démonomanie II.5_corrected_stemmed.txt
# 14. Démonomanie II.6_corrected_stemmed.txt
# 15. Démonomanie II.7_corrected_stemmed.txt
# 16. Démonomanie II.8_corrected_stemmed.txt
# 17. Démonomanie III.1_corrected_stemmed.txt
# 18. Démonomanie III.2_corrected_stemmed.txt
# 19. Démonomanie III.3_corrected_stemmed.txt
# 20. Démonomanie III.4_corrected_stemmed.txt
# 21. Démonomanie III.5_corrected_stemmed.txt
# 22. Démonomanie III.6_corrected_stemmed.txt
# 23. Démonomanie IV.1_corrected_stemmed.txt
# 24. Démonomanie IV.2_corrected_stemmed.txt
# 25. Démonomanie IV.3_corrected_stemmed.txt
# 26. Démonomanie IV.4_corrected_stemmed.txt
# 27. Démonomanie IV.5_corrected_stemmed.txt
# 28. Démonomanie preface Repair_corrected_stemmed.txt
# 29. Harangue - Fontainebleau_corrected_stemmed.txt
# 30. Harangue - Orléans 2_corrected_stemmed.txt
# 31. Harangue - Orléans_corrected_stemmed.txt
# 32. Harangue - Poissy_corrected_stemmed.txt
# 33. Harangue - Rouen_corrected_stemmed.txt
# 34. Harangue - Saint Germain_corrected_stemmed.txt
# 35. Harangue - lit de justice_corrected_stemmed.txt
# 36. Harangue - ouverture de parlement_corrected_stemmed.txt
# 37. Harangue - parlement 2_corrected_stemmed.txt
# 38. Harangue - parlement 3_corrected_stemmed.txt
# 39. Harangue - parlement_corrected_stemmed.txt
# 40. Harangue - religion_corrected_stemmed.txt
# 41. Harangue - septembre_corrected_stemmed.txt
# 42. La réponse_corrected_stemmed.txt
# 43. Le paradoxe_corrected_stemmed.txt
# 44. Lettre_corrected_stemmed.txt
# 45. Lit de justice_corrected_stemmed.txt
# 46. Memoire - Namur_corrected_stemmed.txt
# 47. Memoire - le but_corrected_stemmed.txt
# 48. Memoire au roi_corrected_stemmed.txt
# 49. Memoires d'État Refuge_corrected_stemmed.txt
# 50. Memoires d'état_corrected_stemmed.txt
# 51. Recueil_corrected_stemmed.txt
# 52. Remonstrances - Royaume_corrected_stemmed.txt
# 53. Remonstrances - parlement_corrected_stemmed.txt
# 54. République I.1_corrected_stemmed.txt
# 55. République I.2_corrected_stemmed.txt
# 56. République I.3_corrected_stemmed.txt
# 57. République I.4_corrected_stemmed.txt
# 58. République I.5_corrected_stemmed.txt
# 59. République I.6_corrected_stemmed.txt
# 60. République I.7_corrected_stemmed.txt
# 61. République I.8_corrected_stemmed.txt
# 62. République I.910_corrected_stemmed.txt
# 63. République I.911_corrected_stemmed.txt
# 64. République I.9_corrected_stemmed.txt
# 65. République II.1_corrected_stemmed.txt
# 66. République II.2_corrected_stemmed.txt
# 67. République II.3_corrected_stemmed.txt
# 68. République II.4_corrected_stemmed.txt
# 69. République II.5_corrected_stemmed.txt
# 70. République II.6_corrected_stemmed.txt
# 71. République II.7_corrected_stemmed.txt
# 72. République III.1_corrected_stemmed.txt
# 73. République III.2_corrected_stemmed.txt
# 74. République III.3_corrected_stemmed.txt
# 75. République III.4_corrected_stemmed.txt
# 76. République III.5_corrected_stemmed.txt
# 77. République III.6_corrected_stemmed.txt
# 78. République III.7_corrected_stemmed.txt
# 79. République IV.1_corrected_stemmed.txt
# 80. République IV.2_corrected_stemmed.txt
# 81. République IV.3_corrected_stemmed.txt
# 82. République IV.4_corrected_stemmed.txt
# 83. République IV.5_corrected_stemmed.txt
# 84. République IV.6_corrected_stemmed.txt
# 85. République IV.7_corrected_stemmed.txt
# 86. République V.1_corrected_stemmed.txt
# 87. République V.2_corrected_stemmed.txt
# 88. République V.3_corrected_stemmed.txt
# 89. République V.4_corrected_stemmed.txt
# 90. République V.5_corrected_stemmed.txt
# 91. République VI.1_corrected_stemmed.txt
# 92. République VI.2_corrected_stemmed.txt
# 93. République VI.3_corrected_stemmed.txt
# 94. République VI.4_corrected_stemmed.txt
# 95. République VI.5_corrected_stemmed.txt
# 96. République VI.6_corrected_stemmed.txt
# 97. République preface_corrected_stemmed.txt
# 98. Théatre III_corrected_stemmed.txt
# 99. Théatre II_corrected_stemmed.txt
# 100. Théatre IV_corrected_stemmed.txt
# 101. Théatre I_corrected_stemmed.txt
# 102. Théatre V_corrected_stemmed.txt
# 103. Théatre summary_corrected_stemmed.txt
# 104. Traite Justice VII_corrected_stemmed.txt
# 105. Traite Justice VI_corrected_stemmed.txt
# 106. Traite Justice V_corrected_stemmed.txt
# 107. Traité Justice III_corrected_stemmed.txt
# 108. Traité Justice II_corrected_stemmed.txt
# 109. Traité Justice IV_corrected_stemmed.txt
# 110. Traité Justice I_corrected_stemmed.txt
# Enter 'all' to select all files.
# Results for Discours des raisons_corrected_stemmed.txt:
#
# Results for Démonomanie I.1_corrected_stemmed.txt:
#
# Results for Démonomanie I.2_corrected_stemmed.txt:
#
# Results for Démonomanie I.3_corrected_stemmed.txt:
#
# Results for Démonomanie I.4_corrected_stemmed.txt:
#
# Results for Démonomanie I.5_corrected_stemmed.txt:
#
# Results for Démonomanie I.6_corrected_stemmed.txt:
#
# Results for Démonomanie I.7_corrected_stemmed.txt:
#
# Results for Démonomanie II.1_corrected_stemmed.txt:
# ' eftan ': 1
#
# Results for Démonomanie II.2_corrected_stemmed.txt:
#
# Results for Démonomanie II.3_corrected_stemmed.txt:
#
# Results for Démonomanie II.4_corrected_stemmed.txt:
#
# Results for Démonomanie II.5_corrected_stemmed.txt:
#
# Results for Démonomanie II.6_corrected_stemmed.txt:
#
# Results for Démonomanie II.7_corrected_stemmed.txt:
#
# Results for Démonomanie II.8_corrected_stemmed.txt:
#
# Results for Démonomanie III.1_corrected_stemmed.txt:
# ' eftan ': 3
#
# Results for Démonomanie III.2_corrected_stemmed.txt:
# ' eftan ': 1
#
# Results for Démonomanie III.3_corrected_stemmed.txt:
# ' eftan ': 1
#
# Results for Démonomanie III.4_corrected_stemmed.txt:
#
# Results for Démonomanie III.5_corrected_stemmed.txt:
#
# Results for Démonomanie III.6_corrected_stemmed.txt:
#
# Results for Démonomanie IV.1_corrected_stemmed.txt:
#
# Results for Démonomanie IV.2_corrected_stemmed.txt:
#
# Results for Démonomanie IV.3_corrected_stemmed.txt:
#
# Results for Démonomanie IV.4_corrected_stemmed.txt:
#
# Results for Démonomanie IV.5_corrected_stemmed.txt:
#
# Results for Démonomanie preface Repair_corrected_stemmed.txt:
#
# Results for Harangue - Fontainebleau_corrected_stemmed.txt:
#
# Results for Harangue - Orléans 2_corrected_stemmed.txt:
#
# Results for Harangue - Orléans_corrected_stemmed.txt:
#
# Results for Harangue - Poissy_corrected_stemmed.txt:
#
# Results for Harangue - Rouen_corrected_stemmed.txt:
#
# Results for Harangue - Saint Germain_corrected_stemmed.txt:
#
# Results for Harangue - lit de justice_corrected_stemmed.txt:
#
# Results for Harangue - ouverture de parlement_corrected_stemmed.txt:
#
# Results for Harangue - parlement 2_corrected_stemmed.txt:
#
# Results for Harangue - parlement 3_corrected_stemmed.txt:
#
# Results for Harangue - parlement_corrected_stemmed.txt:
#
# Results for Harangue - religion_corrected_stemmed.txt:
#
# Results for Harangue - septembre_corrected_stemmed.txt:
#
# Results for La réponse_corrected_stemmed.txt:
# ' eftan ': 1
#
# Results for Le paradoxe_corrected_stemmed.txt:
# ' eftan ': 3
#
# Results for Lettre_corrected_stemmed.txt:
# ' eftan ': 1
#
# Results for Lit de justice_corrected_stemmed.txt:
#
# Results for Memoire - Namur_corrected_stemmed.txt:
#
# Results for Memoire - le but_corrected_stemmed.txt:
#
# Results for Memoire au roi_corrected_stemmed.txt:
#
# Results for Memoires d'État Refuge_corrected_stemmed.txt:
#
# Results for Memoires d'état_corrected_stemmed.txt:
#
# Results for Recueil_corrected_stemmed.txt:
# ' eftan ': 5
#
# Results for Remonstrances - Royaume_corrected_stemmed.txt:
#
# Results for Remonstrances - parlement_corrected_stemmed.txt:
#
# Results for République I.1_corrected_stemmed.txt:
#
# Results for République I.2_corrected_stemmed.txt:
#
# Results for République I.3_corrected_stemmed.txt:
#
# Results for République I.4_corrected_stemmed.txt:
#
# Results for République I.5_corrected_stemmed.txt:
#
# Results for République I.6_corrected_stemmed.txt:
#
# Results for République I.7_corrected_stemmed.txt:
#
# Results for République I.8_corrected_stemmed.txt:
#
# Results for République I.910_corrected_stemmed.txt:
#
# Results for République I.911_corrected_stemmed.txt:
#
# Results for République I.9_corrected_stemmed.txt:
#
# Results for République II.1_corrected_stemmed.txt:
#
# Results for République II.2_corrected_stemmed.txt:
#
# Results for République II.3_corrected_stemmed.txt:
#
# Results for République II.4_corrected_stemmed.txt:
#
# Results for République II.5_corrected_stemmed.txt:
#
# Results for République II.6_corrected_stemmed.txt:
#
# Results for République II.7_corrected_stemmed.txt:
#
# Results for République III.1_corrected_stemmed.txt:
#
# Results for République III.2_corrected_stemmed.txt:
#
# Results for République III.3_corrected_stemmed.txt:
#
# Results for République III.4_corrected_stemmed.txt:
#
# Results for République III.5_corrected_stemmed.txt:
#
# Results for République III.6_corrected_stemmed.txt:
#
# Results for République III.7_corrected_stemmed.txt:
#
# Results for République IV.1_corrected_stemmed.txt:
#
# Results for République IV.2_corrected_stemmed.txt:
#
# Results for République IV.3_corrected_stemmed.txt:
#
# Results for République IV.4_corrected_stemmed.txt:
#
# Results for République IV.5_corrected_stemmed.txt:
#
# Results for République IV.6_corrected_stemmed.txt:
#
# Results for République IV.7_corrected_stemmed.txt:
#
# Results for République V.1_corrected_stemmed.txt:
#
# Results for République V.2_corrected_stemmed.txt:
#
# Results for République V.3_corrected_stemmed.txt:
#
# Results for République V.4_corrected_stemmed.txt:
#
# Results for République V.5_corrected_stemmed.txt:
#
# Results for République VI.1_corrected_stemmed.txt:
#
# Results for République VI.2_corrected_stemmed.txt:
#
# Results for République VI.3_corrected_stemmed.txt:
#
# Results for République VI.4_corrected_stemmed.txt:
#
# Results for République VI.5_corrected_stemmed.txt:
#
# Results for République VI.6_corrected_stemmed.txt:
#
# Results for République preface_corrected_stemmed.txt:
#
# Results for Théatre III_corrected_stemmed.txt:
# ' eftan ': 14
#
# Results for Théatre II_corrected_stemmed.txt:
# ' eftan ': 1
#
# Results for Théatre IV_corrected_stemmed.txt:
# ' eftan ': 7
#
# Results for Théatre I_corrected_stemmed.txt:
# ' eftan ': 7
#
# Results for Théatre V_corrected_stemmed.txt:
# ' eftan ': 7
#
# Results for Théatre summary_corrected_stemmed.txt:
# ' eftan ': 2
#
# Results for Traite Justice VII_corrected_stemmed.txt:
#
# Results for Traite Justice VI_corrected_stemmed.txt:
#
# Results for Traite Justice V_corrected_stemmed.txt:
#
# Results for Traité Justice III_corrected_stemmed.txt:
#
# Results for Traité Justice II_corrected_stemmed.txt:
#
# Results for Traité Justice IV_corrected_stemmed.txt:
#
# Results for Traité Justice I_corrected_stemmed.txt:
