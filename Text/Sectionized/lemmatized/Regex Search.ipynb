# %%
import re
import os
from collections import Counter
import csv  # Added for robust comma-aware pattern parsing using CSV quoting

def select_files():
    # List all text files in the current directory
    txt_files = sorted([f for f in os.listdir() if f.endswith('.txt')])
    if not txt_files:
        print("No text files found in the current directory.")
        return []

    print("Available text files:")
    for i, file in enumerate(txt_files):
        print(f"{i + 1}. {file}")
    print("Enter 'all' to select all files.")

    selected_files = []
    while True:
        user_input = input("Select file numbers (individual, ranges, or 'all'): ")
        if not user_input:
            break

        if user_input.strip().lower() == 'all':
            selected_files = txt_files[:]
            break
        else:
            try:
                parts = user_input.split(',')
                for part in parts:
                    if '-' in part:
                        start, end = map(int, part.split('-'))
                        selected_files.extend(txt_files[start - 1:end])
                    else:
                        selected_files.append(txt_files[int(part) - 1])
                break
            except (ValueError, IndexError):
                print("Invalid input. Please enter valid numbers, ranges, or 'all'.")

    return selected_files

def search_pattern(file_paths, pattern, pattern_string):
    results = {}
    print(f"\n--- Results for pattern: '{pattern_string}' ---")

    for file_path in file_paths:
        with open(file_path, 'r', encoding='utf-8') as file:
            text = file.read()
            matches = pattern.findall(text)
            if matches:
                counter = Counter(matches)
                results[file_path] = counter

    # Separate files with hits and without hits
    files_with_hits = {fp: c for fp, c in results.items() if sum(c.values()) > 0}
    all_file_paths = set(file_paths)
    hit_file_paths = set(files_with_hits.keys())
    files_without_hits = all_file_paths - hit_file_paths

    # Sort files with hits by total hit count (descending)
    sorted_with_hits = sorted(files_with_hits.items(), key=lambda x: sum(x[1].values()), reverse=True)

    if sorted_with_hits:
        #print("Files with hits:")
        for file_path, counter in sorted_with_hits:
            print(f"Results for {file_path}:")
            for word, count in counter.items():
                print(f"'{word}': {count}")
            print()
    else:
        print("No hits found for this pattern in any of the selected files.")

    #if files_without_hits:
    #    print("Files without hits:")
    #    for file_path in sorted(list(files_without_hits)):
    #        print(f"{file_path}")
    #    print()

def main():
    file_paths = select_files()
    if file_paths:
        regex_patterns_input = input("Enter regex patterns (comma-separated; wrap any pattern containing a comma in double quotes, e.g. \"foo,bar\"; spaces at start/end are preserved): ")
        # Old simple split approach (retained for reference):
        # pattern_strings = regex_patterns_input.split(',')
        # CSV-based parsing (now preserving leading/trailing spaces by NOT using skipinitialspace and not stripping).
        try:
            # IMPORTANT: skipinitialspace=False so spaces immediately after commas are kept as part of the pattern.
            pattern_strings = next(csv.reader([regex_patterns_input], skipinitialspace=False))
        except Exception as e:
            print(f"Failed to parse input with CSV reader ({e}); falling back to naive split (will not preserve some spaces).")
            pattern_strings = regex_patterns_input.split(',')
        
        for pattern_str in pattern_strings:
            raw = pattern_str  # Preserve original (including any leading/trailing spaces) for display & compilation
            # pattern_str_stripped = pattern_str.strip()  # Previous behavior (would remove leading/trailing spaces)
            # if not pattern_str_stripped:
            #     continue
            if pattern_str == '':  # Skip truly empty entries (e.g., consecutive commas)
                continue
            try:
                pattern = re.compile(pattern_str)  # Compile with spaces intact
                search_pattern(file_paths, pattern, raw)
            except re.error:
                print(f"Invalid regex pattern: '{raw}'. Skipping.")

# %%
if __name__ == "__main__":
    main()
# Out:
# Available text files:
# 1. 0Théatre summary_corrected_stemmed.txt
# 2. Discours des raisons_corrected_stemmed.txt
# 3. Démonomanie I.1_corrected_stemmed.txt
# 4. Démonomanie I.2_corrected_stemmed.txt
# 5. Démonomanie I.3_corrected_stemmed.txt
# 6. Démonomanie I.4_corrected_stemmed.txt
# 7. Démonomanie I.5_corrected_stemmed.txt
# 8. Démonomanie I.6_corrected_stemmed.txt
# 9. Démonomanie I.7_corrected_stemmed.txt
# 10. Démonomanie II.1_corrected_stemmed.txt
# 11. Démonomanie II.2_corrected_stemmed.txt
# 12. Démonomanie II.3_corrected_stemmed.txt
# 13. Démonomanie II.4_corrected_stemmed.txt
# 14. Démonomanie II.5_corrected_stemmed.txt
# 15. Démonomanie II.6_corrected_stemmed.txt
# 16. Démonomanie II.7_corrected_stemmed.txt
# 17. Démonomanie II.8_corrected_stemmed.txt
# 18. Démonomanie III.1_corrected_stemmed.txt
# 19. Démonomanie III.2_corrected_stemmed.txt
# 20. Démonomanie III.3_corrected_stemmed.txt
# 21. Démonomanie III.4_corrected_stemmed.txt
# 22. Démonomanie III.5_corrected_stemmed.txt
# 23. Démonomanie III.6_corrected_stemmed.txt
# 24. Démonomanie IV.1_corrected_stemmed.txt
# 25. Démonomanie IV.2_corrected_stemmed.txt
# 26. Démonomanie IV.3_corrected_stemmed.txt
# 27. Démonomanie IV.4_corrected_stemmed.txt
# 28. Démonomanie IV.5_corrected_stemmed.txt
# 29. Démonomanie preface Repair_corrected_stemmed.txt
# 30. Harangue - Fontainebleau_corrected_stemmed.txt
# 31. Harangue - Orléans 2_corrected_stemmed.txt
# 32. Harangue - Orléans_corrected_stemmed.txt
# 33. Harangue - Poissy_corrected_stemmed.txt
# 34. Harangue - Rouen_corrected_stemmed.txt
# 35. Harangue - Saint Germain_corrected_stemmed.txt
# 36. Harangue - lit de justice_corrected_stemmed.txt
# 37. Harangue - ouverture de parlement_corrected_stemmed.txt
# 38. Harangue - parlement 2_corrected_stemmed.txt
# 39. Harangue - parlement 3_corrected_stemmed.txt
# 40. Harangue - parlement_corrected_stemmed.txt
# 41. Harangue - religion_corrected_stemmed.txt
# 42. Harangue - septembre_corrected_stemmed.txt
# 43. La réponse_corrected_stemmed.txt
# 44. Le paradoxe_corrected_stemmed.txt
# 45. Lettre_corrected_stemmed.txt
# 46. Lit de justice_corrected_stemmed.txt
# 47. Memoire - Namur_corrected_stemmed.txt
# 48. Memoire - le but_corrected_stemmed.txt
# 49. Memoire au roi_corrected_stemmed.txt
# 50. Memoires d'État Refuge_corrected_stemmed.txt
# 51. Memoires d'état_corrected_stemmed.txt
# 52. Recueil_corrected_stemmed.txt
# 53. Remonstrances - Royaume_corrected_stemmed.txt
# 54. Remonstrances - parlement_corrected_stemmed.txt
# 55. République I.1_corrected_stemmed.txt
# 56. République I.2_corrected_stemmed.txt
# 57. République I.3_corrected_stemmed.txt
# 58. République I.4_corrected_stemmed.txt
# 59. République I.5_corrected_stemmed.txt
# 127. Théatre III.7_corrected_stemmed.txt
# 128. Théatre III.8_corrected_stemmed.txt
# 129. Théatre III.910_corrected_stemmed.txt
# 130. Théatre III.911_corrected_stemmed.txt
# 131. Théatre III.912_corrected_stemmed.txt
# 132. Théatre III.913_corrected_stemmed.txt
# 133. Théatre III.914_corrected_stemmed.txt
# 134. Théatre III.915_corrected_stemmed.txt
# 135. Théatre III.916_corrected_stemmed.txt
# 136. Théatre III.9_corrected_stemmed.txt
# 137. Théatre IV.1_corrected_stemmed.txt
# 138. Théatre IV.2_corrected_stemmed.txt
# 139. Théatre IV.3_corrected_stemmed.txt
# 140. Théatre IV.4_corrected_stemmed.txt
# 141. Théatre IV.5_corrected_stemmed.txt
# 142. Théatre IV.6_corrected_stemmed.txt
# 143. Théatre IV.7_corrected_stemmed.txt
# 144. Théatre IV.8_corrected_stemmed.txt
# 145. Théatre IV.910_corrected_stemmed.txt
# 146. Théatre IV.911_corrected_stemmed.txt
# 147. Théatre IV.912_corrected_stemmed.txt
# 148. Théatre IV.913_corrected_stemmed.txt
# 149. Théatre IV.914_corrected_stemmed.txt
# 150. Théatre IV.915_corrected_stemmed.txt
# 151. Théatre IV.9_corrected_stemmed.txt
# 152. Théatre V.1_corrected_stemmed.txt
# 153. Théatre V.2_corrected_stemmed.txt
# 154. Théatre V.3_corrected_stemmed.txt
# 155. Théatre V.4_corrected_stemmed.txt
# 156. Théatre V.5_corrected_stemmed.txt
# 157. Théatre V.6_corrected_stemmed.txt
# 158. Théatre V.7_corrected_stemmed.txt
# 159. Théatre V.8_corrected_stemmed.txt
# 160. Théatre V.910_corrected_stemmed.txt
# 161. Théatre V.911_corrected_stemmed.txt
# 162. Théatre V.912_corrected_stemmed.txt
# 163. Théatre V.9_corrected_stemmed.txt
# 164. Traite Justice VII_corrected_stemmed.txt
# 165. Traite Justice VI_corrected_stemmed.txt
# 166. Traite Justice V_corrected_stemmed.txt
# 167. Traité Justice III_corrected_stemmed.txt
# 168. Traité Justice II_corrected_stemmed.txt
# 169. Traité Justice IV_corrected_stemmed.txt
# 170. Traité Justice I_corrected_stemmed.txt
# Enter 'all' to select all files.
#
# --- Results for pattern: ' vient ' ---
# Results for Théatre III.912_corrected_stemmed.txt:
# ' vient ': 12
#
# Results for République IV.1_corrected_stemmed.txt:
# ' vient ': 10
#
# Results for La réponse_corrected_stemmed.txt:
# ' vient ': 9
#
# Results for Le paradoxe_corrected_stemmed.txt:
# ' vient ': 9
#
# Results for Théatre IV.3_corrected_stemmed.txt:
# ' vient ': 8
#
# Results for Traite Justice VI_corrected_stemmed.txt:
# ' vient ': 8
#
# Results for Théatre III.913_corrected_stemmed.txt:
# ' vient ': 6
#
# Results for Traité Justice IV_corrected_stemmed.txt:
# ' vient ': 6
#
# Results for Traité Justice I_corrected_stemmed.txt:
# ' vient ': 6
#
# Results for Harangue - Orléans_corrected_stemmed.txt:
# ' vient ': 4
#
# Results for République VI.5_corrected_stemmed.txt:
# ' vient ': 4
#
# Results for Théatre III.915_corrected_stemmed.txt:
# ' vient ': 4
#
# Results for Théatre V.5_corrected_stemmed.txt:
# ' vient ': 4
#
# Results for Théatre V.8_corrected_stemmed.txt:
# ' vient ': 4
#
# Results for Harangue - parlement 2_corrected_stemmed.txt:
# ' vient ': 3
#
# Results for Lit de justice_corrected_stemmed.txt:
# ' vient ': 3
#
# Results for République I.5_corrected_stemmed.txt:
# ' vient ': 3
#
# Results for République V.1_corrected_stemmed.txt:
# ' vient ': 3
#
# Results for République VI.6_corrected_stemmed.txt:
# ' vient ': 3
#
# Results for Théatre III.910_corrected_stemmed.txt:
# ' vient ': 3
#
# Results for Théatre IV.4_corrected_stemmed.txt:
# ' vient ': 3
#
# Results for Théatre IV.6_corrected_stemmed.txt:
# ' vient ': 3
#
# Results for Théatre IV.7_corrected_stemmed.txt:
# ' vient ': 3
#
# Results for Théatre V.2_corrected_stemmed.txt:
# ' vient ': 3
#
# Results for Théatre V.9_corrected_stemmed.txt:
# ' vient ': 3
#
# Results for Traite Justice V_corrected_stemmed.txt:
# ' vient ': 3
#
# Results for Traité Justice III_corrected_stemmed.txt:
# ' vient ': 3
#
# Results for Traité Justice II_corrected_stemmed.txt:
# ' vient ': 3
#
# Results for Démonomanie I.4_corrected_stemmed.txt:
# ' vient ': 2
#
# Results for Démonomanie I.5_corrected_stemmed.txt:
# ' vient ': 2
#
# Results for Démonomanie I.6_corrected_stemmed.txt:
# ' vient ': 2
#
# Results for Démonomanie preface Repair_corrected_stemmed.txt:
# ' vient ': 2
#
# Results for Remonstrances - parlement_corrected_stemmed.txt:
# ' vient ': 2
#
# Results for République I.9_corrected_stemmed.txt:
# ' vient ': 2
#
# Results for République III.2_corrected_stemmed.txt:
# ' vient ': 2
#
# Results for République IV.7_corrected_stemmed.txt:
# ' vient ': 2
#
# Results for République VI.2_corrected_stemmed.txt:
# ' vient ': 2
#
# Results for Théatre II.3_corrected_stemmed.txt:
# ' vient ': 2
#
# Results for Théatre II.910_corrected_stemmed.txt:
# ' vient ': 2
#
# Results for Théatre III.5_corrected_stemmed.txt:
# ' vient ': 2
#
# Results for Théatre III.911_corrected_stemmed.txt:
# ' vient ': 2
#
# Results for Théatre III.914_corrected_stemmed.txt:
# ' vient ': 2
#
# Results for Théatre III.916_corrected_stemmed.txt:
# ' vient ': 2
#
# Results for Théatre IV.1_corrected_stemmed.txt:
# ' vient ': 2
#
# Results for Théatre IV.5_corrected_stemmed.txt:
# ' vient ': 2
#
# Results for Théatre IV.913_corrected_stemmed.txt:
# ' vient ': 2
#
# Results for Théatre V.1_corrected_stemmed.txt:
# ' vient ': 2
#
# Results for Traite Justice VII_corrected_stemmed.txt:
# ' vient ': 2
#
# Results for Démonomanie II.3_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for Démonomanie III.5_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for Démonomanie III.6_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for Démonomanie IV.5_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for Harangue - ouverture de parlement_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for Lettre_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for Memoires d'État Refuge_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for République I.1_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for République I.7_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for République I.911_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for République II.3_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for République II.6_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for République III.1_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for République III.4_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for République IV.6_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for République V.3_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for République VI.3_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for République VI.4_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for République preface_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for Théatre I.3_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for Théatre I.4_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for Théatre I.5_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for Théatre I.911_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for Théatre II.4_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for Théatre II.7_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for Théatre II.911_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for Théatre III.1_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for Théatre III.2_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for Théatre IV.2_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for Théatre IV.911_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for Théatre IV.915_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for Théatre V.3_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for Théatre V.7_corrected_stemmed.txt:
# ' vient ': 1
#
# Results for Théatre V.912_corrected_stemmed.txt:
# ' vient ': 1
#
#
# --- Results for pattern: ' resolu ' ---
# Results for Recueil_corrected_stemmed.txt:
# ' resolu ': 21
#
# Results for République III.1_corrected_stemmed.txt:
# ' resolu ': 8
#
# Results for République VI.4_corrected_stemmed.txt:
# ' resolu ': 7
#
# Results for République I.9_corrected_stemmed.txt:
# ' resolu ': 4
#
# Results for Démonomanie I.1_corrected_stemmed.txt:
# ' resolu ': 3
#
# Results for Démonomanie III.5_corrected_stemmed.txt:
# ' resolu ': 3
#
# Results for République I.6_corrected_stemmed.txt:
# ' resolu ': 3
#
# Results for République I.911_corrected_stemmed.txt:
# ' resolu ': 3
#
# Results for République II.5_corrected_stemmed.txt:
# ' resolu ': 3
#
# Results for République III.4_corrected_stemmed.txt:
# ' resolu ': 3
#
# Results for Démonomanie I.2_corrected_stemmed.txt:
# ' resolu ': 2
#
# Results for Démonomanie III.6_corrected_stemmed.txt:
# ' resolu ': 2
#
# Results for République I.4_corrected_stemmed.txt:
# ' resolu ': 2
#
# Results for République I.5_corrected_stemmed.txt:
# ' resolu ': 2
#
# Results for République I.8_corrected_stemmed.txt:
# ' resolu ': 2
#
# Results for République IV.2_corrected_stemmed.txt:
# ' resolu ': 2
#
# Results for République IV.4_corrected_stemmed.txt:
# ' resolu ': 2
#
# Results for République V.1_corrected_stemmed.txt:
# ' resolu ': 2
#
# Results for Théatre I.4_corrected_stemmed.txt:
# ' resolu ': 2
#
# Results for Théatre V.1_corrected_stemmed.txt:
# ' resolu ': 2
#
# Results for Démonomanie II.3_corrected_stemmed.txt:
# ' resolu ': 1
#
# Results for Démonomanie II.8_corrected_stemmed.txt:
# ' resolu ': 1
#
# Results for Démonomanie IV.1_corrected_stemmed.txt:
# ' resolu ': 1
#
# Results for Démonomanie IV.3_corrected_stemmed.txt:
# ' resolu ': 1
#
# Results for Démonomanie IV.5_corrected_stemmed.txt:
# ' resolu ': 1
#
# Results for Le paradoxe_corrected_stemmed.txt:
# ' resolu ': 1
#
# Results for République I.910_corrected_stemmed.txt:
# ' resolu ': 1
#
# Results for République II.2_corrected_stemmed.txt:
# ' resolu ': 1
#
# Results for République II.6_corrected_stemmed.txt:
# ' resolu ': 1
#
# Results for République II.7_corrected_stemmed.txt:
# ' resolu ': 1
#
# Results for République III.2_corrected_stemmed.txt:
# ' resolu ': 1
#
# Results for République III.6_corrected_stemmed.txt:
# ' resolu ': 1
#
# Results for République IV.1_corrected_stemmed.txt:
# ' resolu ': 1
#
# Results for République IV.3_corrected_stemmed.txt:
# ' resolu ': 1
#
# Results for République V.5_corrected_stemmed.txt:
# ' resolu ': 1
#
# Results for République VI.2_corrected_stemmed.txt:
# ' resolu ': 1
#
# Results for République VI.5_corrected_stemmed.txt:
# ' resolu ': 1
#
# Results for Théatre I.3_corrected_stemmed.txt:
# ' resolu ': 1
#
# Results for Théatre I.7_corrected_stemmed.txt:
# ' resolu ': 1
