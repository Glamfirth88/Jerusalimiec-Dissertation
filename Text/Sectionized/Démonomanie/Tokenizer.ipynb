# %%
from pathlib import Path
import glob
import os
import sys
import csv
import nltk
from collections import Counter
from nltk.tokenize import word_tokenize,wordpunct_tokenize
from nltk.collocations import BigramCollocationFinder, BigramAssocMeasures, TrigramCollocationFinder, TrigramAssocMeasures

import locale
# Set the locale to your desired setting (e.g., 'fr_FR.UTF-8' for French)
locale.setlocale(locale.LC_ALL, 'fr_FR.UTF-8')
# Out:
# 'fr_FR.UTF-8'

# %%
sys.path.append("/home/lucas-jerusalimiec/Documents/OCR Text/Notebooks")
from tokenizer_func  import (wordcleaner, write_words_to_file, dictionary_to_file, convert_tuple_bigrams,
convert_tuple_trigrams)

from extra_token_func import print_first_n_items, remove_keys_from_nested_dict

from additional_token_func import convert_strings_to_counts

from dict_write import write_dict_to_files_with_suffix

# %%
text_loc = Path("./final")
text_files = sorted(glob.glob(f"{text_loc}/*.txt"), key=locale.strxfrm)
output_folder = './tokenized/'
tokenized_folder = Path(output_folder)
tokenized_folder.mkdir(exist_ok=True)

output_unigram = f'{output_folder}unigram_counts'
unigram_folder = Path(output_unigram)
unigram_folder.mkdir(exist_ok=True)

output_bigram = f'{output_folder}bigram_counts'
bigram_folder = Path(output_bigram)
bigram_folder.mkdir(exist_ok=True)

output_trigram = f'{output_folder}trigram_counts'
trigram_folder = Path(output_trigram)
trigram_folder.mkdir(exist_ok=True)

output_collocation = f'{output_folder}collocation_counts'
collocation_folder = Path(output_collocation)
collocation_folder.mkdir(exist_ok=True)

output_trigram_collocation = f'{output_folder}trigram_collocation_counts'
trigram_collocation_folder = Path(output_trigram_collocation)
trigram_collocation_folder.mkdir(exist_ok=True)

output_underscore = f'{output_folder}underscore_bigrams'
underscore_folder = Path(output_underscore)
underscore_folder.mkdir(exist_ok=True)

output_trigram_underscore = f'{output_folder}underscore_trigrams'
trigram_underscore_folder = Path(output_trigram_underscore)
trigram_underscore_folder.mkdir(exist_ok=True)

print("Text files in the spellchecked directory:", text_files)
# Out:
# Text files in the spellchecked directory: ['final/Démonomanie I.1_corrected.txt', 'final/Démonomanie I.2_corrected.txt', 'final/Démonomanie I.3_corrected.txt', 'final/Démonomanie I.4_corrected.txt', 'final/Démonomanie I.5_corrected.txt', 'final/Démonomanie I.6_corrected.txt', 'final/Démonomanie I.7_corrected.txt', 'final/Démonomanie II.1_corrected.txt', 'final/Démonomanie II.2_corrected.txt', 'final/Démonomanie II.3_corrected.txt', 'final/Démonomanie II.4_corrected.txt', 'final/Démonomanie II.5_corrected.txt', 'final/Démonomanie II.6_corrected.txt', 'final/Démonomanie II.7_corrected.txt', 'final/Démonomanie II.8_corrected.txt', 'final/Démonomanie III.1_corrected.txt', 'final/Démonomanie III.2_corrected.txt', 'final/Démonomanie III.3_corrected.txt', 'final/Démonomanie III.4_corrected.txt', 'final/Démonomanie III.5_corrected.txt', 'final/Démonomanie III.6_corrected.txt', 'final/Démonomanie IV.1_corrected.txt', 'final/Démonomanie IV.2_corrected.txt', 'final/Démonomanie IV.3_corrected.txt', 'final/Démonomanie IV.4_corrected.txt', 'final/Démonomanie IV.5_corrected.txt', 'final/Démonomanie preface Repair_corrected.txt']

# %%
# Open stopwords CSV file and list the contents
with open('./stop_words.csv', 'r') as f:
    stopwords = f.read().strip().split(",")
stopwords[-10:]
# Out:
# ['votr', 'voz', 'w', 'x', 'xx', 'y', 'ya', 'ycel', 'ure', 'z']

# %%
tokenized_texts = {}
for txt in text_files:
    with open(txt, 'r') as f:
        content = f.read()
        file_name = txt.split('\\')[-1]
        #key = file_name.split('.')[0]
        key = os.path.splitext(os.path.basename(file_name))[0]
        tokenized_texts[key] = content
print("Raw texts:", list(tokenized_texts.keys()))
# Out:
# Raw texts: ['Démonomanie I.1_corrected', 'Démonomanie I.2_corrected', 'Démonomanie I.3_corrected', 'Démonomanie I.4_corrected', 'Démonomanie I.5_corrected', 'Démonomanie I.6_corrected', 'Démonomanie I.7_corrected', 'Démonomanie II.1_corrected', 'Démonomanie II.2_corrected', 'Démonomanie II.3_corrected', 'Démonomanie II.4_corrected', 'Démonomanie II.5_corrected', 'Démonomanie II.6_corrected', 'Démonomanie II.7_corrected', 'Démonomanie II.8_corrected', 'Démonomanie III.1_corrected', 'Démonomanie III.2_corrected', 'Démonomanie III.3_corrected', 'Démonomanie III.4_corrected', 'Démonomanie III.5_corrected', 'Démonomanie III.6_corrected', 'Démonomanie IV.1_corrected', 'Démonomanie IV.2_corrected', 'Démonomanie IV.3_corrected', 'Démonomanie IV.4_corrected', 'Démonomanie IV.5_corrected', 'Démonomanie preface Repair_corrected']

# %%
unigrams = {}

for key, value in tokenized_texts.items():
    unigram_list = wordpunct_tokenize(value)
    cleanwords = [wordcleaner(w) for w in unigram_list]
    unigrams[key] = cleanwords

for key, value in unigrams.items():
    filename = f"./tokenized/{key}.txt"
    write_words_to_file(value, filename, words_per_line=20)
    print(f"Saved content for '{key}' to {filename}")
# Out:
# Saved content for 'Démonomanie I.1_corrected' to ./tokenized/Démonomanie I.1_corrected.txt
# Saved content for 'Démonomanie I.2_corrected' to ./tokenized/Démonomanie I.2_corrected.txt
# Saved content for 'Démonomanie I.3_corrected' to ./tokenized/Démonomanie I.3_corrected.txt
# Saved content for 'Démonomanie I.4_corrected' to ./tokenized/Démonomanie I.4_corrected.txt
# Saved content for 'Démonomanie I.5_corrected' to ./tokenized/Démonomanie I.5_corrected.txt
# Saved content for 'Démonomanie I.6_corrected' to ./tokenized/Démonomanie I.6_corrected.txt
# Saved content for 'Démonomanie I.7_corrected' to ./tokenized/Démonomanie I.7_corrected.txt
# Saved content for 'Démonomanie II.1_corrected' to ./tokenized/Démonomanie II.1_corrected.txt
# Saved content for 'Démonomanie II.2_corrected' to ./tokenized/Démonomanie II.2_corrected.txt
# Saved content for 'Démonomanie II.3_corrected' to ./tokenized/Démonomanie II.3_corrected.txt
# Saved content for 'Démonomanie II.4_corrected' to ./tokenized/Démonomanie II.4_corrected.txt
# Saved content for 'Démonomanie II.5_corrected' to ./tokenized/Démonomanie II.5_corrected.txt
# Saved content for 'Démonomanie II.6_corrected' to ./tokenized/Démonomanie II.6_corrected.txt
# Saved content for 'Démonomanie II.7_corrected' to ./tokenized/Démonomanie II.7_corrected.txt
# Saved content for 'Démonomanie II.8_corrected' to ./tokenized/Démonomanie II.8_corrected.txt
# Saved content for 'Démonomanie III.1_corrected' to ./tokenized/Démonomanie III.1_corrected.txt
# Saved content for 'Démonomanie III.2_corrected' to ./tokenized/Démonomanie III.2_corrected.txt
# Saved content for 'Démonomanie III.3_corrected' to ./tokenized/Démonomanie III.3_corrected.txt
# Saved content for 'Démonomanie III.4_corrected' to ./tokenized/Démonomanie III.4_corrected.txt
# Saved content for 'Démonomanie III.5_corrected' to ./tokenized/Démonomanie III.5_corrected.txt
# Saved content for 'Démonomanie III.6_corrected' to ./tokenized/Démonomanie III.6_corrected.txt
# Saved content for 'Démonomanie IV.1_corrected' to ./tokenized/Démonomanie IV.1_corrected.txt
# Saved content for 'Démonomanie IV.2_corrected' to ./tokenized/Démonomanie IV.2_corrected.txt
# Saved content for 'Démonomanie IV.3_corrected' to ./tokenized/Démonomanie IV.3_corrected.txt
# Saved content for 'Démonomanie IV.4_corrected' to ./tokenized/Démonomanie IV.4_corrected.txt
# Saved content for 'Démonomanie IV.5_corrected' to ./tokenized/Démonomanie IV.5_corrected.txt
# Saved content for 'Démonomanie preface Repair_corrected' to ./tokenized/Démonomanie preface Repair_corrected.txt

# %%
print("Unigram texts:")
for key in unigrams:
    print(key)
# Out:
# Unigram texts:
# Démonomanie I.1_corrected
# Démonomanie I.2_corrected
# Démonomanie I.3_corrected
# Démonomanie I.4_corrected
# Démonomanie I.5_corrected
# Démonomanie I.6_corrected
# Démonomanie I.7_corrected
# Démonomanie II.1_corrected
# Démonomanie II.2_corrected
# Démonomanie II.3_corrected
# Démonomanie II.4_corrected
# Démonomanie II.5_corrected
# Démonomanie II.6_corrected
# Démonomanie II.7_corrected
# Démonomanie II.8_corrected
# Démonomanie III.1_corrected
# Démonomanie III.2_corrected
# Démonomanie III.3_corrected
# Démonomanie III.4_corrected
# Démonomanie III.5_corrected
# Démonomanie III.6_corrected
# Démonomanie IV.1_corrected
# Démonomanie IV.2_corrected
# Démonomanie IV.3_corrected
# Démonomanie IV.4_corrected
# Démonomanie IV.5_corrected
# Démonomanie preface Repair_corrected

# %%
# Count up the tokens using a Counter() object
unigram_counts = {}
for key, value in unigrams.items():
    unigram_counts_dict = Counter(value)
    unigram_counts[key] = unigram_counts_dict

print("Unigram Counts:")
for key in unigram_counts:
    print(key)

print_first_n_items(unigram_counts, 25)
# Out:
# Unigram Counts:
# Démonomanie I.1_corrected
# Démonomanie I.2_corrected
# Démonomanie I.3_corrected
# Démonomanie I.4_corrected
# Démonomanie I.5_corrected
# Démonomanie I.6_corrected
# Démonomanie I.7_corrected
# Démonomanie II.1_corrected
# Démonomanie II.2_corrected
# Démonomanie II.3_corrected
# Démonomanie II.4_corrected
# Démonomanie II.5_corrected
# Démonomanie II.6_corrected
# Démonomanie II.7_corrected
# Démonomanie II.8_corrected
# Démonomanie III.1_corrected
# Démonomanie III.2_corrected
# Démonomanie III.3_corrected
# Démonomanie III.4_corrected
# Démonomanie III.5_corrected
# Démonomanie III.6_corrected
# Démonomanie IV.1_corrected
# Démonomanie IV.2_corrected
# Démonomanie IV.3_corrected
# Démonomanie IV.4_corrected
# Démonomanie IV.5_corrected
# Démonomanie preface Repair_corrected
# First 25 items in Démonomanie I.1_corrected:
# : 1293
# que: 69
# de: 67
# il: 52
# en: 44
# les: 43
# qui: 42
# à: 39
# des: 39
# la: 39
# eft: 38
# qu: 38
# le: 37
# dieu: 33
# ce: 31
# l: 30
# a: 23
# d: 22
# comme: 21
# pour: 20
# et: 20
# e: 18
# ne: 17
# font: 17
# par: 16
#
# First 25 items in Démonomanie I.2_corrected:
# : 1245
# il: 108
# de: 80
# l: 70
# qu: 70
# les: 68
# que: 66
# le: 48
# dieu: 47
# à: 44
# qui: 41
# en: 41
# des: 31
# d: 31
# eft: 28
# la: 27
# pour: 26
# ce: 26
# ou: 25
# a: 23
# comme: 23
# par: 22
# n: 21
# vn: 20
# luy: 20
#
# First 25 items in Démonomanie I.3_corrected:
# : 1053
# de: 96
# les: 74
# que: 63
# des: 49
# qu: 48
# en: 47
# qui: 42
# il: 34
# à: 32
# la: 30
# d: 29
# eft: 28
# l: 27
# pour: 27
# le: 27
# par: 26
# a: 24
# on: 24
# n: 23
# plus: 23
# dieu: 21
# ne: 20
# esprits: 18
# ce: 17
#
# First 25 items in Démonomanie I.4_corrected:
# : 1273
# de: 115
# en: 62
# que: 61
# il: 58
# les: 56
# l: 52
# dieu: 52
# qui: 48
# à: 47
# la: 45
# le: 43
# qu: 41
# eft: 40
# d: 34
# n: 30
# des: 29
# on: 27
# ou: 27
# par: 24
# comme: 23
# c: 22
# pour: 22
# ce: 22
# a: 21
#
# First 25 items in Démonomanie I.5_corrected:
# : 2473
# de: 203
# que: 123
# la: 121
# des: 111
# les: 111
# il: 89
# en: 85
# qui: 84
# l: 82
# qu: 73
# eft: 65
# dieu: 65
# le: 62
# d: 60
# à: 58
# c: 50
# par: 49
# a: 45
# du: 43
# comme: 40
# ne: 39
# ce: 37
# et: 36
# n: 36
#
# First 25 items in Démonomanie I.6_corrected:
# : 1142
# qui: 82
# de: 76
# les: 52
# à: 41
# le: 39
# en: 37
# que: 37
# qu: 37
# eft: 34
# la: 34
# l: 32
# des: 31
# il: 30
# dieu: 30
# fort: 30
# d: 29
# pour: 29
# du: 29
# par: 22
# on: 20
# ce: 20
# ou: 19
# ils: 18
# comme: 18
#
# First 25 items in Démonomanie I.7_corrected:
# : 482
# de: 56
# la: 44
# des: 38
# que: 23
# qui: 19
# les: 19
# l: 18
# en: 18
# pour: 17
# à: 16
# dieu: 15
# le: 15
# qu: 14
# par: 12
# eft: 12
# ne: 12
# on: 11
# du: 11
# comme: 9
# autres: 9
# il: 9
# c: 8
# choses: 8
# plus: 8
#
# First 25 items in Démonomanie II.1_corrected:
# : 1227
# de: 110
# que: 71
# en: 68
# qu: 66
# qui: 57
# il: 56
# les: 52
# la: 48
# l: 44
# des: 43
# à: 41
# d: 36
# eft: 34
# le: 33
# on: 29
# a: 26
# c: 26
# vn: 25
# fe: 25
# ce: 25
# n: 24
# par: 22
# pour: 22
# y: 20
#
# First 25 items in Démonomanie II.2_corrected:
# : 1633
# de: 133
# que: 87
# en: 71
# la: 70
# qui: 70
# il: 68
# les: 66
# qu: 65
# à: 64
# le: 57
# des: 54
# d: 50
# eft: 48
# l: 47
# a: 40
# pour: 38
# dieu: 38
# n: 32
# on: 31
# ne: 29
# ce: 29
# c: 28
# du: 28
# vn: 26
#
# First 25 items in Démonomanie II.3_corrected:
# : 1713
# de: 137
# que: 86
# la: 82
# à: 81
# en: 80
# qu: 76
# qui: 68
# les: 67
# il: 66
# d: 63
# l: 55
# le: 51
# a: 44
# n: 40
# des: 38
# par: 35
# pour: 33
# c: 32
# s: 30
# dieu: 29
# eft: 29
# on: 29
# vn: 26
# ou: 25
#
# First 25 items in Démonomanie II.4_corrected:
# : 2368
# de: 114
# à: 79
# d: 69
# la: 67
# qu: 65
# le: 64
# en: 63
# que: 62
# l: 60
# il: 58
# les: 53
# qui: 53
# e: 36
# vn: 36
# a: 35
# par: 33
# des: 33
# au: 28
# diable: 28
# m: 28
# pour: 27
# c: 25
# sorciers: 25
# y: 25
#
# First 25 items in Démonomanie II.5_corrected:
# : 792
# de: 68
# qu: 47
# en: 46
# l: 44
# que: 39
# qui: 34
# à: 31
# des: 29
# les: 29
# la: 25
# d: 21
# le: 21
# il: 20
# eft: 17
# corps: 17
# vne: 16
# on: 16
# elle: 16
# du: 14
# n: 14
# et: 14
# sorciers: 13
# fon: 13
# ce: 13
#
# First 25 items in Démonomanie II.6_corrected:
# : 2921
# de: 107
# que: 86
# à: 80
# d: 80
# en: 74
# les: 60
# la: 54
# qu: 54
# m: 54
# il: 49
# le: 48
# a: 47
# c: 46
# qui: 45
# l: 43
# e: 43
# des: 40
# eft: 29
# n: 29
# et: 28
# p: 28
# par: 25
# y: 25
# vn: 24
#
# First 25 items in Démonomanie II.7_corrected:
# : 864
# de: 78
# en: 46
# que: 34
# à: 32
# qu: 30
# d: 30
# qui: 28
# l: 24
# la: 24
# m: 23
# a: 23
# le: 22
# il: 22
# les: 21
# vn: 18
# e: 15
# plus: 14
# du: 14
# des: 13
# c: 12
# eft: 11
# au: 11
# elle: 11
# x: 10
#
# First 25 items in Démonomanie II.8_corrected:
# : 1979
# de: 127
# qu: 87
# que: 78
# les: 72
# il: 71
# d: 64
# qui: 64
# en: 55
# à: 49
# la: 49
# l: 44
# le: 44
# dieu: 37
# des: 36
# vn: 35
# par: 32
# ce: 27
# a: 26
# au: 26
# ne: 26
# on: 26
# n: 24
# pour: 23
# eft: 23
#
# First 25 items in Démonomanie III.1_corrected:
# : 1593
# de: 140
# que: 88
# il: 86
# en: 85
# les: 77
# qui: 71
# la: 70
# qu: 67
# à: 64
# le: 64
# d: 61
# l: 52
# des: 48
# eft: 44
# dieu: 36
# plus: 34
# a: 31
# s: 31
# sorciers: 29
# ne: 27
# pour: 26
# n: 26
# vn: 26
# ce: 25
#
# First 25 items in Démonomanie III.2_corrected:
# : 631
# de: 66
# qu: 55
# il: 37
# les: 36
# la: 36
# que: 36
# le: 33
# à: 33
# qui: 32
# d: 28
# ne: 28
# en: 27
# vn: 26
# par: 21
# des: 20
# on: 20
# l: 19
# ils: 18
# mais: 16
# ou: 16
# elle: 16
# sorciers: 14
# pour: 13
# s: 13
#
# First 25 items in Démonomanie III.3_corrected:
# : 865
# de: 76
# que: 68
# la: 48
# les: 47
# en: 46
# qu: 45
# à: 44
# il: 43
# d: 39
# qui: 35
# le: 32
# l: 29
# a: 28
# des: 25
# vn: 23
# plus: 22
# ne: 22
# n: 22
# pour: 21
# c: 19
# dieu: 18
# ils: 15
# par: 15
# ce: 14
#
# First 25 items in Démonomanie III.4_corrected:
# : 682
# de: 76
# les: 55
# qu: 51
# que: 47
# il: 33
# en: 33
# ne: 32
# d: 29
# le: 27
# qui: 27
# la: 24
# à: 23
# ce: 22
# n: 21
# des: 21
# dieu: 18
# et: 16
# elle: 16
# par: 15
# eft: 15
# l: 15
# sorciers: 13
# plus: 13
# a: 13
#
# First 25 items in Démonomanie III.5_corrected:
# : 1523
# de: 128
# en: 82
# que: 80
# la: 72
# qu: 69
# il: 64
# qui: 63
# les: 59
# à: 57
# le: 54
# d: 53
# pour: 48
# on: 44
# des: 39
# eft: 39
# l: 37
# par: 37
# ne: 34
# ce: 32
# vn: 29
# a: 27
# c: 26
# du: 26
# y: 24
#
# First 25 items in Démonomanie III.6_corrected:
# : 1503
# de: 169
# en: 105
# qu: 97
# il: 91
# la: 79
# qui: 78
# l: 73
# que: 72
# les: 61
# d: 57
# le: 56
# vn: 52
# à: 47
# des: 46
# ne: 40
# eft: 36
# on: 35
# du: 33
# par: 32
# au: 32
# n: 31
# sathan: 29
# ce: 27
# c: 26
#
# First 25 items in Démonomanie IV.1_corrected:
# : 1272
# de: 108
# la: 68
# qu: 65
# que: 63
# il: 56
# les: 54
# en: 46
# d: 45
# à: 38
# qui: 36
# des: 30
# ne: 30
# l: 30
# le: 29
# ce: 28
# s: 28
# a: 27
# on: 26
# pour: 25
# n: 25
# eft: 24
# y: 22
# e: 21
# aux: 20
#
# First 25 items in Démonomanie IV.2_corrected:
# : 1768
# de: 164
# la: 61
# c: 58
# d: 58
# l: 57
# le: 57
# que: 56
# eft: 54
# en: 53
# il: 50
# qu: 44
# à: 43
# qui: 41
# les: 39
# ou: 36
# vn: 33
# in: 30
# s: 30
# on: 29
# a: 28
# du: 28
# n: 28
# fi: 27
# ce: 24
#
# First 25 items in Démonomanie IV.3_corrected:
# : 1130
# de: 77
# que: 53
# la: 43
# d: 43
# les: 42
# en: 38
# qui: 34
# l: 34
# des: 32
# eft: 31
# qu: 29
# le: 26
# ou: 25
# par: 24
# il: 22
# ne: 19
# pour: 19
# ce: 18
# à: 18
# a: 18
# c: 18
# pas: 16
# vn: 16
# et: 15
#
# First 25 items in Démonomanie IV.4_corrected:
# : 1811
# de: 140
# d: 55
# la: 54
# qu: 54
# l: 46
# il: 42
# qui: 42
# que: 40
# à: 39
# le: 38
# eft: 34
# c: 32
# s: 30
# a: 30
# ne: 29
# les: 28
# n: 28
# e: 26
# m: 24
# en: 23
# y: 21
# in: 21
# elle: 20
# on: 20
#
# First 25 items in Démonomanie IV.5_corrected:
# : 5079
# de: 391
# la: 188
# que: 186
# qui: 185
# d: 148
# qu: 143
# il: 130
# eft: 128
# les: 128
# à: 127
# en: 123
# l: 119
# le: 116
# des: 106
# c: 93
# ne: 87
# a: 83
# n: 81
# pour: 80
# ou: 73
# dieu: 73
# ce: 71
# par: 70
# e: 64
#
# First 25 items in Démonomanie preface Repair_corrected:
# : 2359
# de: 224
# les: 159
# qu: 143
# en: 130
# que: 129
# la: 115
# des: 112
# qui: 112
# il: 104
# à: 98
# d: 95
# l: 82
# le: 76
# a: 65
# ne: 55
# pour: 55
# on: 55
# au: 50
# eft: 50
# par: 49
# sorciers: 48
# ce: 48
# n: 45
# elle: 44

# %%
# Remove specified keys from the dictionary
stripped_unigrams = remove_keys_from_nested_dict(unigram_counts, stopwords)

print_first_n_items(stripped_unigrams, 30)
# Out:
# First 30 items in Démonomanie I.1_corrected:
# : 1293
# dieu: 33
# bien: 11
# monde: 11
# nature: 10
# esprits: 9
# sathan: 7
# mal: 7
# sorciers: 6
# escripture: 6
# anges: 6
# demons: 6
# hebrieux: 5
# malins: 5
# anciens: 5
# diables: 5
# definition: 4
# premier: 4
# mot: 4
# foy: 4
# con: 4
# dire: 4
# salomon: 4
# creé: 4
# mort: 4
# combien: 4
# bons: 4
# dir: 4
# toufiours: 4
# fin: 4
#
# First 30 items in Démonomanie I.2_corrected:
# : 1245
# dieu: 47
# esprit: 20
# bien: 18
# entre: 16
# anges: 16
# hommes: 15
# faire: 12
# ange: 10
# premier: 9
# homme: 9
# ame: 8
# peu: 8
# monde: 7
# voix: 7
# diét: 7
# chose: 7
# bons: 6
# uns: 6
# dire: 6
# vie: 6
# bon: 6
# mot: 6
# fort: 6
# choses: 5
# sorciers: 5
# beftes: 5
# hom: 5
# mauuais: 5
# garde: 5
#
# First 30 items in Démonomanie I.3_corrected:
# : 1053
# dieu: 21
# esprits: 18
# sorciers: 15
# malins: 14
# bien: 10
# bons: 10
# hommes: 10
# sathan: 8
# premier: 7
# diables: 7
# chose: 7
# dire: 7
# sorcier: 6
# foubs: 6
# dieux: 6
# difference: 5
# diable: 5
# faire: 5
# peuples: 5
# moyens: 4
# diaboliques: 4
# uns: 4
# voile: 4
# forte: 4
# fort: 4
# soleil: 4
# roy: 4
# maistre: 4
# donc: 4
#
# First 30 items in Démonomanie I.4_corrected:
# : 1273
# dieu: 52
# bien: 15
# fonges: 14
# prophetie: 12
# vifion: 12
# hebrieux: 10
# void: 10
# prophetes: 9
# vifions: 9
# chose: 9
# samuel: 8
# prophete: 8
# face: 8
# choses: 7
# pourquoy: 7
# veillant: 7
# dauid: 7
# esprit: 7
# homme: 6
# cap: 6
# longe: 6
# premier: 6
# escripture: 6
# dormant: 6
# fonge: 6
# thummim: 6
# appelle: 5
# saul: 5
# chapitre: 5
#
# First 30 items in Démonomanie I.5_corrected:
# : 2473
# dieu: 65
# choses: 22
# premier: 17
# faire: 17
# celestes: 16
# naturelles: 16
# dire: 15
# monde: 14
# nature: 14
# lune: 14
# bien: 12
# corps: 12
# matiere: 11
# naturelle: 10
# causes: 10
# sans: 10
# parle: 10
# esprits: 9
# cause: 9
# anges: 9
# chose: 9
# hommes: 9
# hebrieux: 8
# ciel: 8
# puissance: 8
# pourquoy: 8
# force: 8
# plantes: 8
# fin: 8
#
# First 30 items in Démonomanie I.6_corrected:
# : 1142
# dieu: 30
# fort: 30
# mot: 13
# bien: 12
# diable: 11
# encores: 9
# chose: 9
# fignifie: 9
# roy: 8
# moyens: 8
# illicites: 8
# sorciers: 8
# fçauoir: 8
# forts: 8
# premier: 7
# appelle: 7
# dire: 7
# sorcier: 6
# fin: 6
# verbe: 6
# sathan: 5
# mourir: 5
# defendu: 5
# entre: 5
# nombres: 5
# quine: 4
# toute: 4
# paruenir: 4
# diaboliques: 4
#
# First 30 items in Démonomanie I.7_corrected:
# : 482
# dieu: 15
# choses: 8
# feu: 7
# bien: 5
# miracles: 5
# nature: 5
# cours: 5
# outre: 5
# chose: 5
# telles: 5
# premier: 4
# faire: 4
# sorciers: 4
# air: 4
# hommes: 4
# dire: 4
# mer: 4
# void: 4
# lune: 4
# if: 3
# pourquoy: 3
# loy: 3
# fçauoir: 3
# aristote: 3
# oeuvres: 3
# eaux: 3
# apparut: 3
# remarqué: 3
# donc: 3
#
# First 30 items in Démonomanie II.1_corrected:
# : 1227
# dieu: 15
# bien: 13
# sorciers: 13
# diable: 10
# faire: 8
# disoit: 7
# magie: 6
# esprits: 6
# homme: 6
# paroles: 6
# chose: 5
# parle: 5
# fin: 5
# chacune: 5
# plusieurs: 5
# per: 5
# eftoient: 4
# payens: 4
# impieté: 4
# choses: 4
# sathan: 4
# ad: 4
# dæmons: 4
# cinquante: 4
# mot: 4
# mots: 4
# bon: 4
# malin: 4
# maistre: 4
#
# First 30 items in Démonomanie II.2_corrected:
# : 1633
# dieu: 38
# bien: 18
# paroles: 17
# loy: 14
# diable: 12
# faire: 10
# mots: 9
# sorciers: 8
# caracteres: 8
# hommes: 8
# telles: 7
# neantmoins: 7
# fort: 7
# hebrieux: 7
# dire: 7
# sorcier: 6
# vertu: 6
# quoy: 6
# chose: 6
# bouche: 6
# fel: 6
# ens: 6
# peuple: 6
# sans: 5
# fin: 5
# voix: 5
# moyen: 5
# choses: 5
# bons: 5
#
# First 30 items in Démonomanie II.3_corrected:
# : 1713
# dieu: 29
# corps: 16
# diable: 15
# mort: 14
# bien: 13
# faire: 12
# esprit: 11
# hommes: 9
# sorciers: 8
# veu: 8
# sathan: 8
# pourquoy: 8
# cause: 7
# samuel: 7
# quoy: 7
# dire: 7
# choses: 6
# forme: 6
# saul: 6
# combien: 6
# parties: 6
# contre: 5
# nui: 5
# vray: 5
# là: 5
# grande: 5
# sans: 5
# moins: 5
# fuft: 5
#
# First 30 items in Démonomanie II.4_corrected:
# : 2368
# diable: 28
# sorciers: 25
# dieu: 17
# faire: 13
# bien: 13
# lequel: 10
# hommes: 9
# dire: 9
# plusieurs: 9
# sorcier: 9
# bouc: 9
# marque: 8
# encores: 7
# procés: 7
# quelques: 7
# mourir: 6
# trouva: 6
# sorciere: 6
# voir: 6
# foudain: 6
# sans: 5
# entre: 5
# eftoyent: 5
# uns: 5
# fois: 5
# diables: 5
# compagnie: 5
# peur: 5
# cela: 5
#
# First 30 items in Démonomanie II.5_corrected:
# : 792
# corps: 17
# sorciers: 13
# esprit: 8
# plusieurs: 7
# ame: 7
# sans: 7
# diable: 7
# maistre: 6
# bien: 6
# mort: 6
# ecftafe: 5
# dieu: 5
# recite: 4
# forte: 4
# veulent: 4
# sorciere: 4
# alors: 4
# ensans: 4
# lan: 3
# chose: 3
# vifion: 3
# homme: 3
# puissance: 3
# hors: 3
# eftant: 3
# lequel: 3
# toute: 3
# cap: 3
# escript: 3
#
# First 30 items in Démonomanie II.6_corrected:
# : 2921
# sorciers: 14
# hommes: 14
# dieu: 13
# loups: 11
# encores: 10
# bien: 9
# cela: 9
# corps: 8
# veu: 7
# figure: 7
# homme: 7
# afne: 7
# beftes: 6
# bouc: 6
# sathan: 6
# humaine: 6
# fort: 6
# plusieurs: 6
# loup: 6
# ls: 6
# pm: 6
# fr: 6
# diable: 5
# dire: 5
# chose: 5
# parlant: 5
# peuples: 5
# euft: 5
# faifoit: 5
#
# First 30 items in Démonomanie II.7_corrected:
# : 864
# diables: 8
# dieu: 7
# aage: 7
# femme: 7
# mere: 6
# sathan: 5
# fort: 5
# escript: 5
# aufsi: 5
# histoire: 4
# confeffa: 4
# dés: 4
# diable: 4
# sorcieres: 4
# voir: 4
# sans: 4
# plusieurs: 4
# copulation: 4
# ensans: 4
# sorciere: 4
# forte: 3
# be: 3
# forme: 3
# poffible: 3
# toute: 3
# là: 3
# douze: 3
# noir: 3
# bien: 3
#
# First 30 items in Démonomanie II.8_corrected:
# : 1979
# dieu: 37
# sorciers: 20
# diable: 13
# sathan: 12
# faire: 12
# moyen: 10
# quelques: 9
# poudres: 9
# mourir: 9
# hommes: 8
# sorcieres: 8
# bien: 7
# parles: 7
# homme: 7
# toute: 7
# come: 7
# lifons: 6
# sorciere: 6
# puissance: 5
# dessus: 5
# permet: 5
# parolles: 5
# plusieurs: 5
# beftail: 5
# ensans: 5
# encores: 5
# void: 5
# lieu: 5
# loy: 5
#
# First 30 items in Démonomanie III.1_corrected:
# : 1593
# dieu: 36
# sorciers: 29
# bien: 17
# faire: 12
# malins: 11
# samedy: 11
# loy: 10
# iour: 10
# peuple: 9
# entre: 9
# sorcier: 9
# diable: 8
# esprits: 7
# encores: 7
# puissance: 6
# sathan: 6
# cela: 6
# veu: 6
# mal: 6
# nuit: 6
# maladies: 5
# histoire: 5
# plusieurs: 5
# parle: 5
# vie: 5
# contre: 5
# fort: 5
# efté: 5
# princes: 5
#
# First 30 items in Démonomanie III.2_corrected:
# : 631
# mort: 11
# con: 11
# cas: 9
# dieu: 9
# coll: 8
# tefmoings: 8
# doit: 8
# cela: 8
# contre: 8
# dire: 7
# sans: 7
# forte: 7
# bald: 7
# crime: 7
# droit: 6
# encores: 6
# ac: 6
# crimes: 6
# sorciere: 6
# diable: 6
# certaine: 6
# verité: 5
# claire: 5
# mesmes: 5
# vie: 5
# luge: 5
#
# First 30 items in Démonomanie IV.3_corrected:
# : 1130
# nature: 11
# sorciers: 10
# deuant: 8
# confession: 7
# mourir: 7
# loy: 7
# preuve: 7
# donc: 7
# contre: 6
# uns: 5
# con: 5
# iuge: 5
# veritable: 5
# bien: 5
# cít: 5
# latorture: 5
# dieu: 5
# lesautres: 4
# celle: 4
# hors: 4
# plusieurs: 4
# iugement: 4
# doit: 4
# faux: 4
# chose: 4
# per: 4
# to: 3
# confeffions: 3
# veu: 3
#
# First 30 items in Démonomanie IV.4_corrected:
# : 1811
# presomption: 12
# bien: 10
# sorcier: 10
# sorciers: 9
# preuve: 8
# ad: 8
# sans: 7
# res: 7
# diable: 7
# verité: 7
# reproche: 6
# droit: 6
# faire: 6
# sorciere: 6
# mort: 6
# doit: 6
# enfant: 5
# pere: 5
# contraire: 5
# contre: 5
# crimes: 5
# question: 5
# parle: 5
# queftion: 5
# con: 5
# depofition: 5
# loy: 4
# ls: 4
# prefumer: 4
#
# First 30 items in Démonomanie IV.5_corrected:
# : 5079
# dieu: 73
# sorciers: 52
# mort: 45
# peine: 41
# loy: 37
# bien: 31
# crime: 28
# doit: 27
# faire: 25
# cas: 19
# sans: 17
# encores: 17
# puny: 16
# sorcier: 16
# mourir: 15
# sathan: 15
# diable: 15
# contre: 14
# crimes: 14
# peines: 12
# ad: 11
# presomptions: 10
# lieu: 10
# autant: 10
# toute: 10
# plusieurs: 10
# iuges: 10
# deuant: 9
# combien: 9
#
# First 30 items in Démonomanie preface Repair_corrected:
# : 2359
# sorciers: 48
# dieu: 30
# choses: 25
# corps: 22
# faire: 20
# bien: 18
# aristote: 18
# lieu: 17
# veu: 17
# esprits: 17
# contre: 15
# diable: 14
# cause: 14
# homme: 13
# sorcieres: 13
# cens: 12
# nature: 12
# plusieurs: 11
# monde: 11
# forme: 10
# mort: 10
# toute: 10
# cieux: 10
# voit: 10
# dire: 10
# hommes: 9
# sans: 9
# loix: 9
# fin: 9

# %%
dictionary_to_file(stripped_unigrams, unigram_folder, 'unigram_counts')
# Out:
# Saved Démonomanie I.1_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved Démonomanie I.2_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved Démonomanie I.3_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved Démonomanie I.4_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved Démonomanie I.5_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved Démonomanie I.6_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved Démonomanie I.7_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved Démonomanie II.1_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved Démonomanie II.2_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved Démonomanie II.3_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved Démonomanie II.4_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved Démonomanie II.5_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved Démonomanie II.6_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved Démonomanie II.7_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved Démonomanie II.8_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved Démonomanie III.1_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved Démonomanie III.2_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved Démonomanie III.3_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved Démonomanie III.4_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved Démonomanie III.5_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved Démonomanie III.6_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved Démonomanie IV.1_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved Démonomanie IV.2_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved Démonomanie IV.3_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved Démonomanie IV.4_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved Démonomanie IV.5_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved Démonomanie preface Repair_corrected_unigram_counts.csv in tokenized/unigram_counts

# %%
bigrams = {}

for key, value in unigrams.items():
    unigram_list = [word for word in value if word.lower() not in stopwords]
    #unigram_list = [word for word in value]
    bigrams_list = list(nltk.bigrams(unigram_list))
    bigrams[key] = bigrams_list

print("Bigrams:")
for key in bigrams:
    print(key)
# Out:
# Bigrams:
# Démonomanie I.1_corrected
# Démonomanie I.2_corrected
# Démonomanie I.3_corrected
# Démonomanie I.4_corrected
# Démonomanie I.5_corrected
# Démonomanie I.6_corrected
# Démonomanie I.7_corrected
# Démonomanie II.1_corrected
# Démonomanie II.2_corrected
# Démonomanie II.3_corrected
# Démonomanie II.4_corrected
# Démonomanie II.5_corrected
# Démonomanie II.6_corrected
# Démonomanie II.7_corrected
# Démonomanie II.8_corrected
# Démonomanie III.1_corrected
# Démonomanie III.2_corrected
# Démonomanie III.3_corrected
# Démonomanie III.4_corrected
# Démonomanie III.5_corrected
# Démonomanie III.6_corrected
# Démonomanie IV.1_corrected
# Démonomanie IV.2_corrected
# Démonomanie IV.3_corrected
# Démonomanie IV.4_corrected
# Démonomanie IV.5_corrected
# Démonomanie preface Repair_corrected

# %%
bigram_counts = {}

for key, value in bigrams.items():
    string_bigrams = convert_tuple_bigrams(value)
    bigramCount = convert_strings_to_counts(string_bigrams)
    bigram_counts[key] = bigramCount

print("Bigram Counts:")
for key in bigram_counts:
    print(key)

print_first_n_items(bigram_counts, 30)
# Out:
# Bigram Counts:
# Démonomanie I.1_corrected
# Démonomanie I.2_corrected
# Démonomanie I.3_corrected
# Démonomanie I.4_corrected
# Démonomanie I.5_corrected
# Démonomanie I.6_corrected
# Démonomanie I.7_corrected
# Démonomanie II.1_corrected
# Démonomanie II.2_corrected
# Démonomanie II.3_corrected
# Démonomanie II.4_corrected
# Démonomanie II.5_corrected
# Démonomanie II.6_corrected
# Démonomanie II.7_corrected
# Démonomanie II.8_corrected
# Démonomanie III.1_corrected
# Démonomanie III.2_corrected
# Démonomanie III.3_corrected
# Démonomanie III.4_corrected
# Démonomanie III.5_corrected
# Démonomanie III.6_corrected
# Démonomanie IV.1_corrected
# Démonomanie IV.2_corrected
# Démonomanie IV.3_corrected
# Démonomanie IV.4_corrected
# Démonomanie IV.5_corrected
# Démonomanie preface Repair_corrected
# First 30 items in Démonomanie I.1_corrected:
# creé sathan: 3
# bonne foy: 2
# genre humain: 2
# saincte escripture: 2
# malins esprits: 2
# theologiens hebrieux: 2
# sathan malin: 2
# gloire dieu: 2
# particule monde: 2
# faire chose: 2
# peuvent faire: 2
# definition dv: 1
# chapitre premier: 1
# és orrcer: 1
# orrcer eftceluy: 1
# eftceluy moyens: 1
# moyens tns: 1
# breit effort: 1
# su parucnir: 1
# parucnir chose: 1
# pofe ye: 1
# ye definition: 1
# definition neceflaire: 1
# neceflaire feu: 1
# feu rd: 1
# nonfeulémentpour entédre: 1
# entédre trai: 1
# ainsaussi pourles: 1
# pourles iugemensque: 1
# iugemensque rendre: 1
#
# First 30 items in Démonomanie I.2_corrected:
# ange dieu: 4
# bien fort: 3
# entreles anges: 2
# nature intelligible: 2
# monde inferieur: 2
# mot hebrieu: 2
# franc arbitre: 2
# deuoit faire: 2
# hault dieu: 2
corrected_bigram_counts.csv in tokenized/bigram_counts
# Saved Démonomanie II.4_corrected_bigram_counts.csv in tokenized/bigram_counts
# Saved Démonomanie II.5_corrected_bigram_counts.csv in tokenized/bigram_counts
# Saved Démonomanie II.6_corrected_bigram_counts.csv in tokenized/bigram_counts
# Saved Démonomanie II.7_corrected_bigram_counts.csv in tokenized/bigram_counts
# Saved Démonomanie II.8_corrected_bigram_counts.csv in tokenized/bigram_counts
# Saved Démonomanie III.1_corrected_bigram_counts.csv in tokenized/bigram_counts
# Saved Démonomanie III.2_corrected_bigram_counts.csv in tokenized/bigram_counts
# Saved Démonomanie III.3_corrected_bigram_counts.csv in tokenized/bigram_counts
# Saved Démonomanie III.4_corrected_bigram_counts.csv in tokenized/bigram_counts
# Saved Démonomanie III.5_corrected_bigram_counts.csv in tokenized/bigram_counts
# Saved Démonomanie III.6_corrected_bigram_counts.csv in tokenized/bigram_counts
# Saved Démonomanie IV.1_corrected_bigram_counts.csv in tokenized/bigram_counts
# Saved Démonomanie IV.2_corrected_bigram_counts.csv in tokenized/bigram_counts
# Saved Démonomanie IV.3_corrected_bigram_counts.csv in tokenized/bigram_counts
# Saved Démonomanie IV.4_corrected_bigram_counts.csv in tokenized/bigram_counts
# Saved Démonomanie IV.5_corrected_bigram_counts.csv in tokenized/bigram_counts
# Saved Démonomanie preface Repair_corrected_bigram_counts.csv in tokenized/bigram_counts

# %%
trigrams = {}

for key, value in unigrams.items():
    unigram_list = [word for word in value if word.lower() not in stopwords]
    #unigram_list = [word for word in value]
    trigrams_list = list(nltk.trigrams(unigram_list))
    trigrams[key] = trigrams_list

print("Trigrams:")
for key in bigrams:
    print(key)
# Out:
# Trigrams:
# Démonomanie I.1_corrected
# Démonomanie I.2_corrected
# Démonomanie I.3_corrected
# Démonomanie I.4_corrected
# Démonomanie I.5_corrected
# Démonomanie I.6_corrected
# Démonomanie I.7_corrected
# Démonomanie II.1_corrected
# Démonomanie II.2_corrected
# Démonomanie II.3_corrected
# Démonomanie II.4_corrected
# Démonomanie II.5_corrected
# Démonomanie II.6_corrected
# Démonomanie II.7_corrected
# Démonomanie II.8_corrected
# Démonomanie III.1_corrected
# Démonomanie III.2_corrected
# Démonomanie III.3_corrected
# Démonomanie III.4_corrected
# Démonomanie III.5_corrected
# Démonomanie III.6_corrected
# Démonomanie IV.1_corrected
# Démonomanie IV.2_corrected
# Démonomanie IV.3_corrected
# Démonomanie IV.4_corrected
# Démonomanie IV.5_corrected
# Démonomanie preface Repair_corrected

# %%
trigram_counts = {}

for key, value in trigrams.items():
    string_trigrams = convert_tuple_trigrams(value)
    trigramCount = convert_strings_to_counts(string_trigrams)
    trigram_counts[key] = trigramCount

print("Trigram Counts:")
for key in trigram_counts:
    print(key)
    
print_first_n_items(trigram_counts, 30)
# Out:
# Trigram Counts:
# Démonomanie I.1_corrected
# Démonomanie I.2_corrected
# Démonomanie I.3_corrected
# Démonomanie I.4_corrected
# Démonomanie I.5_corrected
# Démonomanie I.6_corrected
# Démonomanie I.7_corrected
# Démonomanie II.1_corrected
# Démonomanie II.2_corrected
# Démonomanie II.3_corrected
# Démonomanie II.4_corrected
# Démonomanie II.5_corrected
# Démonomanie II.6_corrected
# Démonomanie II.7_corrected
# Démonomanie II.8_corrected
# Démonomanie III.1_corrected
# Démonomanie III.2_corrected
# Démonomanie III.3_corrected
# Démonomanie III.4_corrected
# Démonomanie III.5_corrected
# Démonomanie III.6_corrected
# Démonomanie IV.1_corrected
# Démonomanie IV.2_corrected
# Démonomanie IV.3_corrected
# Démonomanie IV.4_corrected
# Démonomanie IV.5_corrected
# Démonomanie preface Repair_corrected
# First 30 items in Démonomanie I.1_corrected:
# és orrcer eftceluy: 1
# orrcer eftceluy moyens: 1
# eftceluy moyens tns: 1
# su parucnir chose: 1
# pofe ye definition: 1
# ye definition neceflaire: 1
# definition neceflaire feu: 1
# neceflaire feu rd: 1
# nonfeulémentpour entédre trai: 1
# ainsaussi pourles iugemensque: 1
# pourles iugemensque rendre: 1
# iugemensque rendre contre: 1
# rendre contre sorciers: 1
# quia cl ob: 1
# bruflee toute viue: 1
#
# First 30 items in Démonomanie II.8_corrected:
# difons files sorciers: 1
# files sorciers puissance: 1
# amc sorciers pevvent: 1
# mons grande puissance: 1
# generalement anciens tenu: 1
# interp rete grec: 1
# rete grec desynefiusin: 1
# grec desynefiusin libro: 1
# mriorioidy aoi ped: 1
# aoi ped ài: 1
# quoi peo sopra: 1
# peo sopra lie: 1
# sopra lie um: 1
# lie um ob: 1
# um ob oie: 1
# ob oie don: 1
# oie don oéyres: 1
# don oéyres rares: 1
# menteurs poureftreplus efloignezde: 1
# poureftreplus efloignezde cognoilfan: 1
# maisnousavons dir dessus: 1
# dir dessus kw: 1
# dessus kw quetous: 1
# kw quetous demonsfont: 1
# quetous demonsfont malins: 1
# ennemys genre humain: 1
# puissance dieu permet: 1
# ha sorciers ram: 1
# fontes durare montes: 1
# durare montes diluere: 1
#
# First 30 items in Démonomanie III.1_corrected:
# faire amende honorable: 2
# ét ooly bon: 1
# ooly bon nsp: 1
# ib ve pie: 1
# ve pie nes: 1
# pie nes histoiresnous: 1
# nes histoiresnous apprennent: 1
# histoiresnous apprennent sorcelleries: 1
# apprennent sorcelleries nouucle: 1
# vs iab loy: 1
# iab loy dedieu: 1
# quieft publiecjil enuiron: 1
# nb histoiresion void: 1
# histoiresion void hays: 1
# eftoient ja remplis: 1
# ja remplis vermine: 1
# peines rigoureufes ordon: 1
# necs patla loy: 1
# patla loy dieucontrelessorciers: 1
# lefquelles fureur dieu: 1
# extirper terre cananeans: 1
# tres pechez eftoyent: 1
# pechez eftoyent alors: 1
# eftoyent alors communs: 1
# alors communs peuples: 1
# pourlessorcelezies abhominables dôr: 1
# abhominables dôr vfoyér: 1
# iio voyonsau parau: 1
# guerre det roye: 1
# det roye ui: 1
#
# First 30 items in Démonomanie III.2_corrected:
# sorciers hommes foyentfains: 1
# iouiffent plafirs plusieurs: 1
# plafirs plusieurs penfent: 1
# sj sorciersupeffenit affeurer: 1
# sorciersupeffenit affeurer santé: 1
# affeurer santé hommes: 1
# santé hommes alaigres: 1
# eftonersilya sorciers parle: 1
# sorciers parle monde: 1
# than quife vouëz: 1
# coit hommes entendus: 1
# hommes entendus defcouurent: 1
# entendus defcouurent foudain: 1
# sorciersfont beliftres pourla: 1
# beliftres pourla plupart: 1
# ficfte quily ades: 1
# quily ades personnesfi: 1
# ades personnesfi miferables: 1
# gettét meilleur fens: 1
# ontaux filets sathan: 1
# uns curiofité faire: 1
# curiofité faire preuve: 1
# faire preuve belles: 1
# preuve belles pro: 1
# belles pro mefles: 1
# pourront retirer quád: 1
# retirer quád voudront: 1
# encores plusieurs dediez: 1
# quiont renoncéà dieu: 1
# neantiiorns renoncent sathan: 1
#
# First 30 items in Démonomanie III.3_corrected:
# quiattireles malheureux precipice: 1
# malheureux precipice ape: 1
# precipice ape gliflant: 1
# ape gliflant chemin: 1
# gliflant chemin perdition: 1
# opinion deprauee ges: 1
# diable donne richefles: 1
# donne richefles pautires: 1
# neantmoins oncognoilt veuë: 1
# nousauous monstré deuant: 1
corrected_trigram_counts.csv in tokenized/trigram_counts
# Saved Démonomanie IV.5_corrected_trigram_counts.csv in tokenized/trigram_counts
# Saved Démonomanie preface Repair_corrected_trigram_counts.csv in tokenized/trigram_counts

# %%
colloc_dict = {}
colloc_counts = {}

for key, value in unigrams.items():
    unigram_list = [word for word in value if word.lower() not in stopwords]
    bigram_finder = BigramCollocationFinder.from_words(unigram_list)
    bigram_finder.apply_freq_filter(3)  # Make sure all collocations have occurred at least 5 times
    collocations = bigram_finder.nbest(BigramAssocMeasures.pmi, 500)
    filtered_collocations = [bigram for bigram in collocations if '' not in bigram]
    colloc_dict[key] = filtered_collocations
    
    # Initialize Counter for colloc_counts
    bigram_count_dict = Counter()

    # Count the occurrences of each bigram in the text
    bigram_finder = BigramCollocationFinder.from_words(unigram_list)
    bigram_freqs = bigram_finder.ngram_fd.items()
    
    # Filter bigram counts based on collocations
    for bigram, count in bigram_freqs:
        if bigram in filtered_collocations:
            bigram_count_dict[bigram] = count

    colloc_counts[key] = bigram_count_dict

print("Collocations:")
for key, value in colloc_dict.items():
    print(key)
    # for w1, w2 in value:
    #     print(' ', w1, w2)

print("Collocation Counts:")
for key in colloc_counts:
    print(key)
    # Print first n items, assuming print_first_n_items function is defined elsewhere
    for item, count in colloc_counts[key].most_common(30):
        bigram = " ".join(item)
        print(f"{bigram} {count}")
    print()

dictionary_to_file(colloc_counts, collocation_folder, 'collocation_counts')
# Out:
# Collocations:
# Démonomanie I.1_corrected
# Démonomanie I.2_corrected
# Démonomanie I.3_corrected
# Démonomanie I.4_corrected
# Démonomanie I.5_corrected
# Démonomanie I.6_corrected
# Démonomanie I.7_corrected
# Démonomanie II.1_corrected
# Démonomanie II.2_corrected
# Démonomanie II.3_corrected
# Démonomanie II.4_corrected
# Démonomanie II.5_corrected
# Démonomanie II.6_corrected
# Démonomanie II.7_corrected
# Démonomanie II.8_corrected
# Démonomanie III.1_corrected
# Démonomanie III.2_corrected
# Démonomanie III.3_corrected
# Démonomanie III.4_corrected
# Démonomanie III.5_corrected
# Démonomanie III.6_corrected
# Démonomanie IV.1_corrected
# Démonomanie IV.2_corrected
# Démonomanie IV.3_corrected
# Démonomanie IV.4_corrected
# Démonomanie IV.5_corrected
# Démonomanie preface Repair_corrected
# Collocation Counts:
# Démonomanie I.1_corrected
# creé sathan 3
#
# Démonomanie I.2_corrected
# ange dieu 4
# bien fort 3
#
# Démonomanie I.3_corrected
# malins esprits 11
# mauuais esprits 3
# moyens diaboliques 3
#
# Démonomanie I.4_corrected
# face face 4
#
# Démonomanie I.5_corrected
# moyens naturels 5
# corps celestes 4
# telles choses 4
# malins esprits 3
# lumieres celestes 3
# inclination naturelle 3
# causes naturelles 3
#
# Démonomanie I.6_corrected
# moyens illicites 3
# conseil dieu 3
# loy dieu 3
#
# Démonomanie I.7_corrected
# cours nature 3
# outre cours 3
# telles choses 3
#
# Démonomanie II.1_corrected
#
# Démonomanie II.2_corrected
# loy dieu 8
# malins esprits 3
# vertu paroles 3
#
# Démonomanie II.3_corrected
# corps mort 3
# parties honteuses 3
#
# Démonomanie II.4_corrected
#
# Démonomanie II.5_corrected
#
# Démonomanie II.6_corrected
# figure humaine 4
# malins esprits 3
#
# Démonomanie II.7_corrected
#
# Démonomanie II.8_corrected
#
# Démonomanie III.1_corrected
# malins esprits 5
# premiere heure 4
# loy dieu 3
# soleil couché 3
#
# Démonomanie III.2_corrected
#
# Démonomanie III.3_corrected
# sylueftre fecond 3
#
# Démonomanie III.4_corrected
#
# Démonomanie III.5_corrected
#
# Démonomanie III.6_corrected
# malins esprits 11
# malin esprit 9
# esprit dieu 4
# prier dieu 3
# hayoit mort 3
#
# Démonomanie IV.1_corrected
# dire verité 5
# princes sorciers 3
#
# Démonomanie IV.2_corrected
#
# Démonomanie IV.3_corrected
#
# Démonomanie IV.4_corrected
# sans reproche 5
# presomption droit 3
#
# Démonomanie IV.5_corrected
# loy dieu 12
# premiere fois 4
# presomptions violentes 3
# directement contre 3
# contre majefté 3
# majefté dieu 3
# renier dieu 3
# mis mort 3
# merite mort 3
# faire mourir 3
# quela peine 3
# peine corporelle 3
# enfant mort 3
#
# Démonomanie preface Repair_corrected
# malins esprits 7
# contre sorciers 5
# choses naturelles 4
# prince mirande 3
# rendre raison 3
# choses supernaturelles 3
# images cire 3
# cens quarante 3
# loy dieu 3
#
# Saved Démonomanie I.1_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved Démonomanie I.2_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved Démonomanie I.3_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved Démonomanie I.4_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved Démonomanie I.5_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved Démonomanie I.6_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved Démonomanie I.7_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved Démonomanie II.1_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved Démonomanie II.2_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved Démonomanie II.3_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved Démonomanie II.4_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved Démonomanie II.5_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved Démonomanie II.6_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved Démonomanie II.7_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved Démonomanie II.8_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved Démonomanie III.1_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved Démonomanie III.2_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved Démonomanie III.3_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved Démonomanie III.4_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved Démonomanie III.5_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved Démonomanie III.6_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved Démonomanie IV.1_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved Démonomanie IV.2_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved Démonomanie IV.3_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved Démonomanie IV.4_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved Démonomanie IV.5_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved Démonomanie preface Repair_corrected_collocation_counts.csv in tokenized/collocation_counts

# %%
trigram_colloc_dict = {}
trigram_colloc_counts = {}

for key, value in unigrams.items():
    unigram_list = [word for word in value if word.lower() not in stopwords]
    trigram_finder = TrigramCollocationFinder.from_words(unigram_list)
    trigram_finder.apply_freq_filter(3)  # Ensure all collocations have occurred at least 5 times
    collocations = trigram_finder.nbest(TrigramAssocMeasures.pmi, 500)
    filtered_collocations = [trigram for trigram in collocations if '' not in trigram]
    trigram_colloc_dict[key] = filtered_collocations
    
    # Initialize Counter for trigram_colloc_counts
    trigram_count_dict = Counter()

    # Count the occurrences of each trigram in the text
    trigram_freqs = trigram_finder.ngram_fd.items()
    
    # Filter trigram counts based on collocations
    for trigram, count in trigram_freqs:
        if trigram in filtered_collocations:
            trigram_count_dict[trigram] = count

    trigram_colloc_counts[key] = trigram_count_dict

print("Trigram Collocations:")
for key, value in trigram_colloc_dict.items():
    print(key)
    #for w1, w2, w3 in value:
    #    print(' ', w1, w2, w3)

print("Trigram Collocation Counts:")
for key in trigram_colloc_counts:
    print(key)
    # Print first n items, assuming print_first_n_items function is defined elsewhere
    for item, count in trigram_colloc_counts[key].most_common(30):
        trigram = " ".join(item)
        print(f"{trigram} {count}")
    print()

dictionary_to_file(trigram_colloc_counts, trigram_collocation_folder, 'trigram_collocation_counts')
# Out:
# Trigram Collocations:
# Démonomanie I.1_corrected
# Démonomanie I.2_corrected
# Démonomanie I.3_corrected
# Démonomanie I.4_corrected
# Démonomanie I.5_corrected
# Démonomanie I.6_corrected
# Démonomanie I.7_corrected
# Démonomanie II.1_corrected
# Démonomanie II.2_corrected
# Démonomanie II.3_corrected
# Démonomanie II.4_corrected
# Démonomanie II.5_corrected
# Démonomanie II.6_corrected
# Démonomanie II.7_corrected
# Démonomanie II.8_corrected
# Démonomanie III.1_corrected
# Démonomanie III.2_corrected
# Démonomanie III.3_corrected
# Démonomanie III.4_corrected
# Démonomanie III.5_corrected
# Démonomanie III.6_corrected
# Démonomanie IV.1_corrected
# Démonomanie IV.2_corrected
# Démonomanie IV.3_corrected
# Démonomanie IV.4_corrected
# Démonomanie IV.5_corrected
# Démonomanie preface Repair_corrected
# Trigram Collocation Counts:
# Démonomanie I.1_corrected
#
# Démonomanie I.2_corrected
#
# Démonomanie I.3_corrected
#
# Démonomanie I.4_corrected
#
# Démonomanie I.5_corrected
#
# Démonomanie I.6_corrected
#
# Démonomanie I.7_corrected
#
# Démonomanie II.1_corrected
#
# Démonomanie II.2_corrected
#
# Démonomanie II.3_corrected
#
# Démonomanie II.4_corrected
#
# Démonomanie II.5_corrected
#
# Démonomanie II.6_corrected
#
# Démonomanie II.7_corrected
#
# Démonomanie II.8_corrected
#
# Démonomanie III.1_corrected
#
# Démonomanie III.2_corrected
#
# Démonomanie III.3_corrected
#
# Démonomanie III.4_corrected
#
# Démonomanie III.5_corrected
#
# Démonomanie III.6_corrected
#
# Démonomanie IV.1_corrected
#
# Démonomanie IV.2_corrected
#
# Démonomanie IV.3_corrected
#
# Démonomanie IV.4_corrected
#
# Démonomanie IV.5_corrected
# contre majefté dieu 3
#
# Démonomanie preface Repair_corrected
#
# Saved Démonomanie I.1_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved Démonomanie I.2_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved Démonomanie I.3_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved Démonomanie I.4_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved Démonomanie I.5_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved Démonomanie I.6_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved Démonomanie I.7_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved Démonomanie II.1_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved Démonomanie II.2_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved Démonomanie II.3_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved Démonomanie II.4_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved Démonomanie II.5_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved Démonomanie II.6_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved Démonomanie II.7_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved Démonomanie II.8_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved Démonomanie III.1_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved Démonomanie III.2_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved Démonomanie III.3_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved Démonomanie III.4_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved Démonomanie III.5_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved Démonomanie III.6_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved Démonomanie IV.1_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved Démonomanie IV.2_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved Démonomanie IV.3_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved Démonomanie IV.4_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved Démonomanie IV.5_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved Démonomanie preface Repair_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts

# %%
underscore_dict = {}
for key, value in unigrams.items():

    tokenized_words = unigrams.get(key)
    collocations = colloc_dict.get(key)
    
    colloc_words = []
    
    # Iterate through the words making new versions combining collocations
    i = 0
    while i < len(tokenized_words) - 1:
        # If we find a collocation, add and advance by two words
        if (tokenized_words[i], tokenized_words[i + 1]) in collocations:
            colloc_words.append('_'.join((tokenized_words[i], tokenized_words[i + 1])))
            i += 2
        # Otherwise, advance by one word
        else:
            colloc_words.append(tokenized_words[i])
            i += 1

    # Add the last word (if any)
    if i == len(tokenized_words) - 1:
        colloc_words.append(tokenized_words[i])
    underscore_dict[key] = colloc_words

print("Underscore Dictionary:")
for key in underscore_dict:
    print(key)

write_dict_to_files_with_suffix(underscore_dict, underscore_folder, 'underscore_bigrams')
# Out:
# Underscore Dictionary:
# Démonomanie I.1_corrected
# Démonomanie I.2_corrected
# Démonomanie I.3_corrected
# Démonomanie I.4_corrected
# Démonomanie I.5_corrected
# Démonomanie I.6_corrected
# Démonomanie I.7_corrected
# Démonomanie II.1_corrected
# Démonomanie II.2_corrected
# Démonomanie II.3_corrected
# Démonomanie II.4_corrected
# Démonomanie II.5_corrected
# Démonomanie II.6_corrected
# Démonomanie II.7_corrected
# Démonomanie II.8_corrected
# Démonomanie III.1_corrected
# Démonomanie III.2_corrected
# Démonomanie III.3_corrected
# Démonomanie III.4_corrected
# Démonomanie III.5_corrected
# Démonomanie III.6_corrected
# Démonomanie IV.1_corrected
# Démonomanie IV.2_corrected
# Démonomanie IV.3_corrected
# Démonomanie IV.4_corrected
# Démonomanie IV.5_corrected
# Démonomanie preface Repair_corrected
# Démonomanie I.1_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# Démonomanie I.2_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# Démonomanie I.3_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# Démonomanie I.4_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# Démonomanie I.5_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# Démonomanie I.6_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# Démonomanie I.7_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# Démonomanie II.1_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# Démonomanie II.2_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# Démonomanie II.3_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# Démonomanie II.4_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# Démonomanie II.5_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# Démonomanie II.6_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# Démonomanie II.7_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# Démonomanie II.8_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# Démonomanie III.1_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# Démonomanie III.2_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# Démonomanie III.3_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# Démonomanie III.4_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# Démonomanie III.5_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# Démonomanie III.6_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# Démonomanie IV.1_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# Démonomanie IV.2_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# Démonomanie IV.3_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# Démonomanie IV.4_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# Démonomanie IV.5_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# Démonomanie preface Repair_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams

# %%
trigram_underscore_dict = {}

for key, tokenized_words in unigrams.items():
    collocations = trigram_colloc_dict.get(key, [])
    colloc_words = []
    i = 0
    while i < len(tokenized_words) - 2:
        # If we find a trigram collocation, add and advance by three words
        trigram = (tokenized_words[i], tokenized_words[i + 1], tokenized_words[i + 2])
        if trigram in collocations:
            colloc_words.append('_'.join(trigram))
            i += 3
        else:
            colloc_words.append(tokenized_words[i])
            i += 1
    # Add the last words (if any)
    while i < len(tokenized_words):
        colloc_words.append(tokenized_words[i])
        i += 1
    trigram_underscore_dict[key] = colloc_words

print("Trigram underscore Dictionary:")
for key in trigram_underscore_dict:
    print(key)

write_dict_to_files_with_suffix(trigram_underscore_dict, trigram_underscore_folder, 'underscore_trigrams')
# Out:
# Trigram underscore Dictionary:
# Démonomanie I.1_corrected
# Démonomanie I.2_corrected
# Démonomanie I.3_corrected
# Démonomanie I.4_corrected
# Démonomanie I.5_corrected
# Démonomanie I.6_corrected
# Démonomanie I.7_corrected
# Démonomanie II.1_corrected
# Démonomanie II.2_corrected
# Démonomanie II.3_corrected
# Démonomanie II.4_corrected
# Démonomanie II.5_corrected
# Démonomanie II.6_corrected
# Démonomanie II.7_corrected
# Démonomanie II.8_corrected
# Démonomanie III.1_corrected
# Démonomanie III.2_corrected
# Démonomanie III.3_corrected
# Démonomanie III.4_corrected
# Démonomanie III.5_corrected
# Démonomanie III.6_corrected
# Démonomanie IV.1_corrected
# Démonomanie IV.2_corrected
# Démonomanie IV.3_corrected
# Démonomanie IV.4_corrected
# Démonomanie IV.5_corrected
# Démonomanie preface Repair_corrected
# Démonomanie I.1_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# Démonomanie I.2_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# Démonomanie I.3_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# Démonomanie I.4_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# Démonomanie I.5_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# Démonomanie I.6_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# Démonomanie I.7_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# Démonomanie II.1_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# Démonomanie II.2_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# Démonomanie II.3_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# Démonomanie II.4_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# Démonomanie II.5_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# Démonomanie II.6_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# Démonomanie II.7_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# Démonomanie II.8_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# Démonomanie III.1_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# Démonomanie III.2_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# Démonomanie III.3_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# Démonomanie III.4_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# Démonomanie III.5_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# Démonomanie III.6_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# Démonomanie IV.1_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# Démonomanie IV.2_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# Démonomanie IV.3_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# Démonomanie IV.4_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# Démonomanie IV.5_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# Démonomanie preface Repair_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
