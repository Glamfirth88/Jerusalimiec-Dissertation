# %%
import os
from nltk.stem.snowball import SnowballStemmer
from french_lefff_lemmatizer.french_lefff_lemmatizer import FrenchLefffLemmatizer

# Initialize the stemmer and lemmatizer for French
stemmer = SnowballStemmer(language='french')
lemmatizer = FrenchLefffLemmatizer()

# Define custom stemming/lemmatization rules sorted alphabetically with five entries per line
CUSTOM_RULES = {
    "abfolu": "absolu", "abfoluë": "absolu", "accuf": "accus", "aduient": "advient", "aduis": "advis",
    "affemble": "assemble", "aguerr": "guerr", "aifn": "aisn", "alor": "alors", "ariftot": "aristot", "aufquel": "ausquel",
    "auantag": "avantag", "auon": "avon", "auoyent": "avoyent", "beft": "best", "bourgcoif": "bourgeois",
    "cai": "cayer", "ceft": "cest", "chágement": "changemen", "comand": "command", "comiffion": "commission",
    "commiffion": "commission", "commiflair": "commissair", "commiflion": "commission", "confent ": "consent", "confeff": "confess",
    "conful": "consul", "coft": "cost", "costé": "côté", "debuoir": "debvoir", "defquel": "desquel",
    "desloix": "des loi", "deteft": "detest", "difcord": "discord", "difent": "disent", "difoit": "disoit",
    "diuif": "divis", "diuin": "divin", "droi": "doit", "droict": "droit", "edit": "édict",
    "édictz": "édict", "eglif": "eglis", "efcript": "escript", "efpaign": "espaigne", "efpargn": "espargn",
    "efpec": "espec", "efprit": "esprit", "eftant": "estant", "efté": "esté", "eftim": "estim",
    "eftoyent": "estoyent", "empefch": "empesch", "enfans": "enfant", "enfembl": "ensembl", "ennem": "ennemy", "ensan": "enfant",
    "ensans": "enfant", "enuer": "enver", "esglis": "églis", "espic": "épice", "estar": "estat",
    "estatz": "estat", "état": "estat", "euft": "eust", "fag": "sag", "faif": "sais",
    "faifoit": "faisoit", "facrific": "sacrific", "fedit": "sedit", "feliqu": "felicit", "fembl": "sembl", "femblabl": "semblabl",
    "fecond": "second", "fept": "sept", "feulg": "seul", "felon": "selon", "fent": "sent",
    "feroit": "seroit", "fcauoir": "savoir", "fcigneur": "seigneur", "fçauoir": "savoir", "finon": "sinon",
    "fimpl": "simpl", "fignif": "signif", "file": "fill", "fong": "song", "foyent": "soyent",
    "fouuet": "souvent", "fucced": "succeed", "fucceffeur": "successeur", "fuft": "fust", "foudain": "soudain",
    "gouuern": "gouvern", "gouuerneur": "gouverneur", "hebrieux": "hebrieu", "iug": "jug", "iufqu": "iusqu",
    "iurifdiet": "iurisdict", "iurifdict": "iurisdict", "iust": "just", "iustic": "justic", "impoft": "impost",
    "laloy": "la loi", "laiff": "laiss", "lefquel": "lesquel", "leroy": "le roy", "lesloix": "les loi",
    "lifon": "lison", "liur": "livr", "loix": "loi", "loy": "loi", "loyx": "loi",
    "maicft": "maiest", "maifon": "maison", "maiftr": "maistr", "majeft": "majest", "magiftrat": "magistrat",
    "magiftrats": "magistrat", "magiltrat": "magistrat", "mefine": "même", "mefines": "mêmes", "meím": "mesm",
    "mesmoir": "memoir", "monftr": "monstr", "naturc": "natur", "noftr": "nostr", "obeiff": "obeiss",
    "obeifl": "obeiss", "pai": "pay", "parlem": "parlement", "parlements": "parlement", "penf": "pens",
    "peuuent": "peuvent", "pluficur": "plusieur", "plutfoft": "plustost", "pouuoir": "pouvoir", "pouuoit": "pouvoit",
    "pourueu": "pourveu", "prefent": "present", "prefqu": "prequ", "preftr": "prestr", "prerogatiu": "prerogativ",
    "prifonni": "prisonni", "prin c": "prince", "prin ces": "princ", "pris": "prix", "priuileg": "privileg", "priuileig": "privileg", "procez": "procès",
    "puiff": "puiss", "puifle": "puiss", "puiffanc": "puissanc", "quc": "que", "queftion": "question",
    "raifon": "raison", "reffort": "ressort", "republie": "republ", "repvbliqu": "republ", "républicque": "républ",
    "royaulm": "royaum", "royau me": "royaum", "sorcicr": "sorcier", "sorciere": "sorci", "sorcieres": "sorci",
    "soubverain": "souverain", "souverian": "souverain", "souverianet": "souverainet", "subject": "sujet", "subjectz": "sujet",
    "tiltr": "titr", "toufiour": "tousiour", "traitt": "traict", "trouu": "trouv", "vaffal": "vassal", "vaflal": "vassal",
    "vertus": "vertu", "viur": "vivr", "vifion": "vision", "ftatut": "statut", "blafph": "blasph", 
    "blafphem":"blasphem", "feruir":"servir", "iuft":"just","mefchan":"meschan","mefchancet":"meschancet", "perpetucl":"perpetuel", "ferment":"serment",
    "commád":"command", "commifl":"commiss", "defenf":"defens","fuperieur":"superieur","iurifconfult":"jurisconsult","ofhcier":"officier"
}

def custom_stem_or_lemmatize(word, use_lemmatizer):
    """
    Apply custom rules during stemming or lemmatizing on a single token.
    """
    if word in CUSTOM_RULES:
        return CUSTOM_RULES[word]
    if use_lemmatizer:
        lemmatized_word = lemmatizer.lemmatize(word)
        return CUSTOM_RULES.get(lemmatized_word, lemmatized_word)
    else:
        stemmed_word = stemmer.stem(word)
        return CUSTOM_RULES.get(stemmed_word, stemmed_word)

def return_stem(text, use_lemmatizer=False):
    """
    Replace multi-token sequences first, then process the text token by token.

    Multi-token replacement works by scanning the entire text for any key in CUSTOM_RULES
    that contains a space. Since these keys represent phrases that should be merged into a single token,
    the code replaces each occurrence with its corresponding value (which does not contain the space).
    This way, when the text is later split into tokens (using text.split()),
    phrases like "royau me" (if present in CUSTOM_RULES) will be replaced by "royaum" and treated as one token.
    """
    # Replace multi-token sequences before tokenizing.
    for phrase, replacement in CUSTOM_RULES.items():
        if " " in phrase:
            text = text.replace(phrase, replacement)
    tokens = text.split()
    final_processed = [custom_stem_or_lemmatize(token, use_lemmatizer) for token in tokens]
    return ' '.join(final_processed)

def process_file(file_path, use_lemmatizer=True):
    """
    Process the contents of a file using custom rules.
    """
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()
    processed_content = return_stem(content, use_lemmatizer)
    return processed_content

def save_processed_content(original_file, processed_content, use_lemmatizer):
    """
    Save processed content to a new file in a 'lemmatized' subdirectory.
    """
    output_dir = os.path.join(os.getcwd(), 'lemmatized')
    os.makedirs(output_dir, exist_ok=True)
    suffix = '_lemmatized.txt' if use_lemmatizer else '_stemmed.txt'
    new_file_name = os.path.splitext(os.path.basename(original_file))[0] + suffix
    new_file_path = os.path.join(output_dir, new_file_name)
    with open(new_file_path, 'w', encoding='utf-8') as file:
        file.write(processed_content)
    print(f"Processed content saved to {new_file_path}")

def select_subdirectory():
    """
    Prompt the user to select a subdirectory or use the current directory.
    """
    current_directory = os.getcwd()
    subdirectories = sorted([d for d in os.listdir(current_directory) if os.path.isdir(d)])
    if not subdirectories:
        print("No subdirectories found.")
        return None
    print("Available subdirectories:")
    for i, subdir in enumerate(subdirectories):
        print(f"{i + 1}. {subdir}")
    while True:
        user_input = input("Select a subdirectory number for target files (leave empty for current directory): ").strip()
        if not user_input:
            return current_directory
        try:
            choice = int(user_input) - 1
            if choice < 0 or choice >= len(subdirectories):
                print("Invalid choice. Please enter a valid number.")
                continue
            return os.path.join(current_directory, subdirectories[choice])
        except ValueError:
            print("Invalid input. Please enter a number.")

def select_files():
    """
    List and allow the user to select text files from a directory.
    """
    directory = select_subdirectory()
    if directory is None:
        directory = os.getcwd()
    txt_files = sorted([f for f in os.listdir(directory) if f.endswith('.txt')])
    if not txt_files:
        print("No text files found in the selected directory.")
        return []
    print("Available text files:")
    for i, file in enumerate(txt_files):
        print(f"{i + 1}. {file}")
    selected_files = []
    while True:
        user_input = input("Select file numbers (e.g., 1,3-5 or press Enter to select all): ").strip()
        if not user_input:
            selected_files = txt_files
            break
        try:
            parts = user_input.split(',')
            for part in parts:
                if '-' in part:
                    start, end = map(int, part.split('-'))
                    selected_files.extend(txt_files[start - 1:end])
                else:
                    selected_files.append(txt_files[int(part) - 1])
            break
        except (ValueError, IndexError):
            print("Invalid input. Please enter valid numbers or ranges.")
    selected_files = [os.path.join(directory, file) for file in selected_files]
    return selected_files

def main():
    """
    Main function to handle file processing.
    """
    file_paths = select_files()
    if not file_paths:
        return
    use_lemmatizer = input("Use FrenchLefffLemmatizer? (y/n, default is n): ").strip().lower() == 'y'
    for file_path in file_paths:
        processed_content = process_file(file_path, use_lemmatizer)
        save_processed_content(file_path, processed_content, use_lemmatizer)

# %%
if __name__ == "__main__":
    main()
# Out:
# Available subdirectories:
# 1. .ipynb_checkpoints
# 2. Démonomanie
# 3. République
# 4. lemmatized
# Select a subdirectory number for target files (leave empty for current directory):
# Available text files:
# 1. Discours des raisons_corrected.txt
# 2. Démonomanie I.1_corrected.txt
# 3. Démonomanie I.2_corrected.txt
# 4. Démonomanie I.3_corrected.txt
# 5. Démonomanie I.4_corrected.txt
# 6. Démonomanie I.5_corrected.txt
# 7. Démonomanie I.6_corrected.txt
# 8. Démonomanie I.7_corrected.txt
# 9. Démonomanie II.1_corrected.txt
# 10. Démonomanie II.2_corrected.txt
# 11. Démonomanie II.3_corrected.txt
# 12. Démonomanie II.4_corrected.txt
# 13. Démonomanie II.5_corrected.txt
# 14. Démonomanie II.6_corrected.txt
# 15. Démonomanie II.7_corrected.txt
# 16. Démonomanie II.8_corrected.txt
# 17. Démonomanie III.1_corrected.txt
# 18. Démonomanie III.2_corrected.txt
# 19. Démonomanie III.3_corrected.txt
# 20. Démonomanie III.4_corrected.txt
# 21. Démonomanie III.5_corrected.txt
# 22. Démonomanie III.6_corrected.txt
# 23. Démonomanie IV.1_corrected.txt
# 24. Démonomanie IV.2_corrected.txt
# 25. Démonomanie IV.3_corrected.txt
# 26. Démonomanie IV.4_corrected.txt
# 27. Démonomanie IV.5_corrected.txt
# 28. Démonomanie preface Repair_corrected.txt
# 29. Harangue - Fontainebleau_corrected.txt
# 30. Harangue - Orléans 2_corrected.txt
# 31. Harangue - Orléans_corrected.txt
# 32. Harangue - Poissy_corrected.txt
# 33. Harangue - Rouen_corrected.txt
# 34. Harangue - Saint Germain_corrected.txt
# 35. Harangue - lit de justice_corrected.txt
# 36. Harangue - ouverture de parlement_corrected.txt
# 37. Harangue - parlement 2_corrected.txt
# 38. Harangue - parlement 3_corrected.txt
# 39. Harangue - parlement_corrected.txt
# 40. Harangue - religion_corrected.txt
# 41. Harangue - septembre_corrected.txt
# 42. La réponse_corrected.txt
# 43. Le paradoxe_corrected.txt
# 44. Lettre_corrected.txt
# 45. Lit de justice_corrected.txt
# 46. Memoire - Namur_corrected.txt
# 47. Memoire - le but_corrected.txt
# 48. Memoire au roi_corrected.txt
# 49. Memoires d'État Refuge_corrected.txt
# 50. Memoires d'état_corrected.txt
# 51. Recueil_corrected.txt
# 52. Remonstrances - Royaume_corrected.txt
# 53. Remonstrances - parlement_corrected.txt
# 54. République I.1_corrected.txt
# 55. République I.2_corrected.txt
# 56. République I.3_corrected.txt
# 57. République I.4_corrected.txt
# 58. République I.5_corrected.txt
# 59. République I.6_corrected.txt
# 60. République I.7_corrected.txt
# 61. République I.8_corrected.txt
# 62. République I.910_corrected.txt
# 63. République I.911_corrected.txt
# 64. République I.9_corrected.txt
# 65. République II.1_corrected.txt
# 66. République II.2_corrected.txt
# 67. République II.3_corrected.txt
# 68. République II.4_corrected.txt
# 69. République II.5_corrected.txt
# 70. République II.6_corrected.txt
# 71. République II.7_corrected.txt
# 72. République III.1_corrected.txt
# 73. République III.2_corrected.txt
# 74. République III.3_corrected.txt
# 75. République III.4_corrected.txt
# 76. République III.5_corrected.txt
# 77. République III.6_corrected.txt
# 78. République III.7_corrected.txt
# 79. République IV.1_corrected.txt
# 80. République IV.2_corrected.txt
# 81. République IV.3_corrected.txt
# 82. République IV.4_corrected.txt
# 83. République IV.5_corrected.txt
# 84. République IV.6_corrected.txt
# 85. République IV.7_corrected.txt
# 86. République V.1_corrected.txt
# 87. République V.2_corrected.txt
# 88. République V.3_corrected.txt
# 89. République V.4_corrected.txt
# 90. République V.5_corrected.txt
# 91. République VI.1_corrected.txt
# 92. République VI.2_corrected.txt
# 93. République VI.3_corrected.txt
# 94. République VI.4_corrected.txt
# 95. République VI.5_corrected.txt
# 96. République VI.6_corrected.txt
# 97. République preface_corrected.txt
# 98. Théatre III_corrected.txt
# 99. Théatre II_corrected.txt
# 100. Théatre IV_corrected.txt
# 101. Théatre I_corrected.txt
# 102. Théatre V_corrected.txt
# 103. Théatre summary_corrected.txt
# 104. Traite Justice VII_corrected.txt
# 105. Traite Justice VI_corrected.txt
# 106. Traite Justice V_corrected.txt
# 107. Traité Justice III_corrected.txt
# 108. Traité Justice II_corrected.txt
# 109. Traité Justice IV_corrected.txt
# 110. Traité Justice I_corrected.txt
# Select file numbers (e.g., 1,3-5 or press Enter to select all):
# Use FrenchLefffLemmatizer? (y/n, default is n):  n
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Discours des raisons_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Démonomanie I.1_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Démonomanie I.2_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Démonomanie I.3_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Démonomanie I.4_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Démonomanie I.5_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Démonomanie I.6_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Démonomanie I.7_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Démonomanie II.1_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Démonomanie II.2_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Démonomanie II.3_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Démonomanie II.4_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Démonomanie II.5_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Démonomanie II.6_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Démonomanie II.7_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Démonomanie II.8_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Démonomanie III.1_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Démonomanie III.2_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Démonomanie III.3_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Démonomanie III.4_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Démonomanie III.5_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Démonomanie III.6_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Démonomanie IV.1_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Démonomanie IV.2_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Démonomanie IV.3_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Démonomanie IV.4_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Démonomanie IV.5_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Démonomanie preface Repair_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Harangue - Fontainebleau_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Harangue - Orléans 2_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Harangue - Orléans_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Harangue - Poissy_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Harangue - Rouen_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Harangue - Saint Germain_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Harangue - lit de justice_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Harangue - ouverture de parlement_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Harangue - parlement 2_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Harangue - parlement 3_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Harangue - parlement_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Harangue - religion_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Harangue - septembre_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/La réponse_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Le paradoxe_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Lettre_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Lit de justice_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Memoire - Namur_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Memoire - le but_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Memoire au roi_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Memoires d'État Refuge_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Memoires d'état_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Recueil_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Remonstrances - Royaume_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Remonstrances - parlement_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République I.1_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République I.2_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République I.3_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République I.4_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République I.5_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République I.6_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République I.7_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République I.8_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République I.910_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République I.911_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République I.9_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République II.1_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République II.2_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République II.3_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République II.4_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République II.5_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République II.6_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République II.7_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République III.1_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République III.2_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République III.3_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République III.4_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République III.5_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République III.6_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République III.7_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République IV.1_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République IV.2_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République IV.3_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République IV.4_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République IV.5_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République IV.6_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République IV.7_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République V.1_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République V.2_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République V.3_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République V.4_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République V.5_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République VI.1_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République VI.2_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République VI.3_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République VI.4_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République VI.5_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République VI.6_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/République preface_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Théatre III_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Théatre II_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Théatre IV_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Théatre I_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Théatre V_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Théatre summary_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Traite Justice VII_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Traite Justice VI_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Traite Justice V_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Traité Justice III_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Traité Justice II_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Traité Justice IV_corrected_stemmed.txt
# Processed content saved to /home/lucas-jerusalimiec/Documents/OCR Text/Text/Sectionized/lemmatized/Traité Justice I_corrected_stemmed.txt
