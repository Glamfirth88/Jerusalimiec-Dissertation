# %%
# -*- coding: utf-8 -*-
"""
Integrated script for MALLET-based topic modeling with per-file Fisher’s Exact
filtering and stopword exclusion. UTF-8 friendly.
Outputs:
  - Topic keys
  - Per-document topic distributions
  - Excel workbook with:
      • Topic tokens
      • Token counts per document
      • Topic probabilities per document
  - Separate Excel workbook with top-document titles per topic

Graphical output (heatmap & boxplots) is disabled in this pipeline.
See plotting_helpers.py for on-demand plotting.
"""

import os
import csv
import time
from pathlib import Path
from collections import Counter

import pandas as pd
from scipy.stats import fisher_exact
import little_mallet_wrapper
from openpyxl import Workbook
from openpyxl.utils.dataframe import dataframe_to_rows

# Path to your MALLET binary (adjust if needed)
path_to_mallet = os.path.expanduser("~/mallet-2.0.8/bin/mallet")

# These will be set by main() and picked up by plotting_helpers.py
OUTPUT_DIR = None
NUM_TOPICS = None

def tokenize_file(filepath):
    """Load a UTF-8 text file and split on whitespace (preserves accents)."""
    with open(filepath, "r", encoding="utf-8") as f:
        return f.read().split()

def list_txt_files(directory):
    """Return a sorted list of all .txt filenames in a directory."""
    return sorted(fn for fn in os.listdir(directory) if fn.endswith(".txt"))

def list_csv_files(directory):
    """
    Recursively find all .csv files under a directory, skipping
    any .ipynb_checkpoints folders.
    """
    csv_paths = []
    for root, dirs, files in os.walk(directory):
        if ".ipynb_checkpoints" in dirs:
            dirs.remove(".ipynb_checkpoints")
        for fn in files:
            if fn.lower().endswith(".csv"):
                csv_paths.append(os.path.join(root, fn))
    return csv_paths

def choose_directory(prompt):
    """
    Display a numbered list of immediate subdirectories (plus current dir)
    and return the full path selected by the user.
    """
    cwd = os.getcwd()
    base = Path(cwd).name
    subdirs = [
        d for d in os.listdir(cwd)
        if os.path.isdir(os.path.join(cwd, d)) and d != ".ipynb_checkpoints"
    ]
    options = [(os.path.join(cwd, d), f"{base}/{d}") for d in subdirs]
    options.append((cwd, base))

    print(prompt)
    for i, (_, label) in enumerate(options, start=1):
        print(f"{i}. {label}")

    while True:
        try:
            choice = int(input("Enter number: ").strip())
            if 1 <= choice <= len(options):
                return options[choice - 1][0]
        except ValueError:
            pass
        print("Invalid choice, please try again.")

def choose_files(filenames):
    """
    Let user pick one or more filenames by:
      - indices ("2" or "1,3")
      - index ranges ("1-4")
      - prefix matching ("report")
      - or the keyword "all" to select every file.
    Returns a sorted, unique list of chosen filenames.
    """
    print("Available files:")
    for i, fn in enumerate(filenames, start=1):
        print(f"{i}. {fn}")
    choice = input("Select files (indices, ranges, prefix, or 'all'): ").strip().lower()

    if choice == "all":
        return filenames.copy()

    selected = []
    for part in choice.split(","):
        part = part.strip()
        if part == "all":
            return filenames.copy()
        if "-" in part:
            a, b = map(int, part.split("-"))
            selected.extend(filenames[a - 1:b])
        elif part.isdigit():
            selected.append(filenames[int(part) - 1])
        else:
            selected.extend(fn for fn in filenames if fn.startswith(part))
    return sorted(set(selected))

def choose_csv_file(csv_paths):
    """
    Prompt the user to select one CSV from a list of paths.
    Returns the chosen filepath.
    """
    cwd = os.getcwd()
    base = Path(cwd).name
    print("Select your stopwords CSV:")
    for i, full in enumerate(csv_paths, start=1):
        rel = os.path.relpath(full, cwd)
        print(f"{i}. {base}/{rel}")

    while True:
        try:
            choice = int(input("Enter number: ").strip())
            if 1 <= choice <= len(csv_paths):
                return csv_paths[choice - 1]
        except ValueError:
            pass
        print("Invalid choice, please try again.")

def read_stopwords(filepath):
    """Load stopwords from a CSV, splitting on commas and trimming whitespace."""
    sw = []
    with open(filepath, "r", encoding="utf-8") as f:
        for row in csv.reader(f):
            for cell in row:
                sw.extend(cell.split(","))
    return [w.strip() for w in sw if w.strip()]

def get_fishers(word, freq_dict, rate_dict, alternative="greater"):
    """
    Perform Fisher’s Exact Test on one token:
        [[observed, total-observed],
         [expected, total-expected]]
    Returns the p-value.
    """
    observed = freq_dict.get(word, 0)
    total = sum(freq_dict.values())
    expected = round(rate_dict.get(word, 0) * total)
    table = [
        [observed, total - observed],
        [expected, total - expected]
    ]
    _, pval = fisher_exact(table, alternative=alternative)
    return pval

def calculate_rate_dictionary(rate_files, rate_dir):
    """
    Build a background rate dictionary from reference documents.
    Returns a mapping { token: relative_frequency }.
    """
    counter = Counter()
    total_tokens = 0
    for fn in rate_files:
        tokens = tokenize_file(os.path.join(rate_dir, fn))
        counter.update(tokens)
        total_tokens += len(tokens)
    return {tok: cnt / total_tokens for tok, cnt in counter.items()}

def prepare_training_data(files, directory, stopwords, rate_dict, alpha):
    """
    For each file:
      1. Tokenize and count every token.
      2. Exclude stopwords and tokens with Fisher p-value ≥ alpha.
      3. Collect filtered document text and raw token counts.
    Prints per-file progress with elapsed time.
    Returns:
      - docs: list of filtered document strings for MALLET input
      - distributions: list of Counter objects of raw token counts
    """
    docs = []
    distributions = []
    total = len(files)
    overall_start = time.time()

    for idx, fn in enumerate(files, start=1):
        file_start = time.time()
        print(f"[{idx}/{total}] ⏳ Processing '{fn}'... ", end="", flush=True)

        path = os.path.join(directory, fn)
        tokens = tokenize_file(path)
        freq = Counter(tokens)

        filtered = [
            w for w in tokens
            if w not in stopwords and get_fishers(w, freq, rate_dict) < alpha
        ]
        docs.append(" ".join(filtered))
        distributions.append(freq)

        elapsed = time.time() - file_start
        kept = len(filtered)
        before = len(tokens)
        pct = (kept / before * 100) if before else 0
        print(f"done in {elapsed:.1f}s – kept {kept}/{before} tokens ({pct:.1f}%).")

    total_elapsed = time.time() - overall_start
    print(f"[Done] Prepared {total} documents in {total_elapsed:.1f}s.\n")
    return docs, distributions

def train_topic_model(training_docs, num_topics, output_dir):
    """
    Train a MALLET model via little_mallet_wrapper
    Returns:
      - topics: list of token lists (topic keys)
      - doc_topics: list of probability lists (per-document topic distributions)
    """
    Path(output_dir).mkdir(parents=True, exist_ok=True)

    little_mallet_wrapper.quick_train_topic_model(
        path_to_mallet,
        output_dir,
        num_topics,
        training_docs
    )

    key_file = f"{output_dir}/mallet.topic_keys.{num_topics}"
    topics = little_mallet_wrapper.load_topic_keys(key_file)

    dist_file = f"{output_dir}/mallet.topic_distributions.{num_topics}"
    doc_topics = little_mallet_wrapper.load_topic_distributions(dist_file)

    return topics, doc_topics

def save_results_to_excel(excel_path, topics, token_distributions, doc_topics, files):
    """
    Create an Excel workbook with:
      1) 'Topics' sheet: one row per topic (Topic#, top tokens...)
      2) One sheet per document: raw token counts (removing '_stemmed' suffix)
      3) 'DocTopicDist' sheet: topic probabilities per document
    """
    wb = Workbook()
    ws0 = wb.active
    ws0.title = "Topics"
    for idx, topic in enumerate(topics):
        ws0.append([f"Topic {idx}"] + topic)

    for fn, dist in zip(files, token_distributions):
        # Remove '_stemmed' suffix from sheet names
        sheet_name = Path(fn).stem.replace("_stemmed", "")
        sheet = wb.create_sheet(title=sheet_name)
        df = pd.DataFrame.from_dict(dist, orient="index", columns=["count"])
        for row in dataframe_to_rows(df, index=True, header=True):
            sheet.append(row)

    ws3 = wb.create_sheet(title="DocTopicDist")
    header = ["Document"] + [f"Topic{t}" for t in range(len(topics))]
    ws3.append(header)
    for fn, probs in zip(files, doc_topics):
        doc_name = Path(fn).stem.replace("_stemmed", "")
        ws3.append([doc_name] + [round(p, 4) for p in probs])

    wb.save(excel_path)

def save_top_titles_excel(xlsx_path, topics, training_docs, doc_topics, doc_titles, n_docs):
    """
    Save the top n_docs document titles per topic into an Excel file,
    one sheet per topic named 'Topic{#}', and remove the default blank sheet.
    """
    wb = Workbook()
    # Remove the default blank sheet
    default_sheet = wb.active
    wb.remove(default_sheet)

    for t_idx in range(len(topics)):
        ws = wb.create_sheet(title=f"Topic{t_idx}")
        ws.append(["Probability", "Document Title"])
        for prob, doc in little_mallet_wrapper.get_top_docs(
            training_docs, doc_topics, t_idx, n=n_docs
        ):
            title = doc_titles.get(doc, Path(doc).stem)
            ws.append([round(prob, 4), title])

    wb.save(xlsx_path)

def input_float(prompt, min_val=None, max_val=None):
    """Prompt until the user enters a valid float (and optionally within range)."""
    while True:
        resp = input(prompt).strip()
        try:
            val = float(resp)
            if min_val is not None and val < min_val:
                print(f"Value must be at least {min_val}.")
                continue
            if max_val is not None and val > max_val:
                print(f"Value must be at most {max_val}.")
                continue
            return val
        except ValueError:
            print("Invalid input, please enter a valid number.")

def input_int(prompt, min_val=None, max_val=None):
    """Prompt until the user enters a valid integer (and optionally within range)."""
    while True:
        resp = input(prompt).strip()
        try:
            val = int(resp)
            if min_val is not None and val < min_val:
                print(f"Value must be at least {min_val}.")
                continue
            if max_val is not None and val > max_val:
                print(f"Value must be at most {max_val}.")
                continue
            return val
        except ValueError:
            print("Invalid input, please enter a valid integer.")

def main():
    global OUTPUT_DIR, NUM_TOPICS

    # 1) Choose and load stopwords CSV
    stop_csv = choose_csv_file(list_csv_files(os.getcwd()))
    stopwords = read_stopwords(stop_csv)

    # 2) Build background rate dictionary
    rate_dir = choose_directory("Select reference text directory:")
    rate_files = choose_files(list_txt_files(rate_dir))
    rate_dict = calculate_rate_dictionary(rate_files, rate_dir)

    # 3) Select target files
    target_dir = choose_directory("Select target text directory:")
    target_files = choose_files(list_txt_files(target_dir))

    # 4) Fisher’s Exact threshold
    alpha = input_float(
        "Enter Fisher’s Exact alpha threshold (e.g. 0.05): ",
        min_val=0.0, max_val=1.0
    )

    # 5) Prepare filtered training data
    training_docs, token_distributions = prepare_training_data(
        target_files, target_dir, stopwords, rate_dict, alpha
    )

    # 6) Number of topics
    num_topics = input_int("Enter number of topics to generate: ", min_val=1)

    # 7) How many top documents per topic
    n_top_docs = input_int("Enter number of top documents per topic: ", min_val=1)

    # 8) Output folder
    while True:
        out_sub = input("Enter name for output folder: ").strip()
        if out_sub:
            break
        print("Output folder name cannot be empty.")
    OUTPUT_DIR = os.path.join(os.getcwd(), out_sub)
    NUM_TOPICS = num_topics
    Path(OUTPUT_DIR).mkdir(parents=True, exist_ok=True)

    # 9) Train model and load topic keys + doc-topic distributions
    topics, doc_topics = train_topic_model(
        training_docs, NUM_TOPICS, OUTPUT_DIR
    )

    # Save the list of processed files for plotting_helpers
    fn_list_path = os.path.join(OUTPUT_DIR, "input_filenames.txt")
    with open(fn_list_path, "w", encoding="utf-8") as f:
        for fn in target_files:
            f.write(fn + "\n")

    # 10) Save combined results to Excel
    excel_results = os.path.join(OUTPUT_DIR, "topic_model_results.xlsx")
    save_results_to_excel(
        excel_results, topics, token_distributions, doc_topics, target_files
    )

    # 11) Save top titles per topic to separate workbook
    doc_titles = {doc: Path(fn).stem for doc, fn in zip(training_docs, target_files)}
    top_titles_path = os.path.join(OUTPUT_DIR, "top_titles.xlsx")
    save_top_titles_excel(
        top_titles_path, topics, training_docs, doc_topics, doc_titles, n_top_docs
    )

    print("✅ Topic modeling pipeline completed successfully!")
    print("ℹ️  No plots were generated. To create heatmaps or boxplots,")
    print("    import and run plotting_helpers.generate_heatmap() or generate_boxplots().")

if __name__ == "__main__":
    main()
# Out:
# Select your stopwords CSV:
# 1. lemmatized/stop_words.csv
# Enter number:  1
# Select reference text directory:
# 1. lemmatized
# Enter number:  1
# Available files:
# 1. Bodin_stemmed.txt
# 2. L'Hospital_stemmed.txt
# Select files (indices, ranges, prefix, or 'all'):  all
# Select target text directory:
# 1. lemmatized
# Enter number:  1
# Available files:
# 1. Bodin_stemmed.txt
# 2. L'Hospital_stemmed.txt
# Select files (indices, ranges, prefix, or 'all'):  all
# Enter Fisher’s Exact alpha threshold (e.g. 0.05):  0.05
# [1/2] ⏳ Processing 'Bodin_stemmed.txt'... done in 132.7s – kept 44708/753572 tokens (5.9%).
# [2/2] ⏳ Processing 'L'Hospital_stemmed.txt'... done in 15.2s – kept 55386/263789 tokens (21.0%).
# [Done] Prepared 2 documents in 147.9s.
# Enter number of topics to generate:  8
# Enter number of top documents per topic:  10
# Enter name for output folder:  8Topics
# Importing data...
# Complete
# Training topic model...
# Mallet LDA: 8 topics, 3 topic bits, 111 topic mask
# Data loaded.
# max tokens: 54876
# total tokens: 98266
# <10> LL/token: -6.5027
# <20> LL/token: -6.36403
# <30> LL/token: -6.27321
# <40> LL/token: -6.21825
#
# 0	0.625	chos corp form veu fort fin lesquel deu jug matier natur senat eau pierr feu mour part pat plant alors
# 1	0.625	justic bien comt bon temp mal raison parc court injustic vray roy droit franc sort feit vertu sainct dont traict
# 2	0.625	ven soix nomm bien mill telz rang médecin homm gen ault daulphin affect somm ten invent refus suiss conten multitud
# 3	0.625	conscienc util beaulx honnest jeun dev innocent jugurth reign feirent appanaig obvi réform trafic veneus juillet usaig exécut advou œuvr
# 4	0.625	roy estat bien don judg bon justic ordon mémoir procès paix dev argent veult bel mill laiss honneur charg charl
# 5	0.625	fort republ part chos puissanc combien natur magistrat doit pourquoy sorci fois fer ame naturel corp populair voir animal iour
# 6	0.625	trouv ordre temp party just roy prendr tort respublicqu empesch feurent bien aultruy facon majest regn francois soy disciplin ten
# 7	0.625	roy homm conseil caus réform justic bien jour duc charg offic royaum main affair gard ruyn vérit afin con enver
#
# <50> LL/token: -6.17186
# <60> LL/token: -6.14508
# <70> LL/token: -6.1068
# <80> LL/token: -6.08116
# <90> LL/token: -6.06985
#
# 0	0.625	chos fort form fois corp natur lesquel veu deu senat fin aristot naturel part pierr feu outr veut mour verit
# 1	0.625	justic temp comt bien mal raison main parc court vertu bon injustic dont person vray sort sainct harangu gen franc
# 2	0.625	vérit ven chanceli conscienc soix telz nomm soy repos médecin rang argent ault daulphin divers affect jusqu conten conven multitud
# 3	0.625	puiss religion bel extresm oultr roy except rend beaulx honnest refus sacr sieg rembours moeur cal favoris util cung exécut
# 4	0.625	roy bon bien don estat mémoir judg ordon duc procès laiss justic droit mill lettr rendr honneur pro dis veult
# 5	0.625	republ fort part puissanc pourquoy combien magistrat ame doit fer sorci corp jug populair fin chos voir eau animal natur
# 6	0.625	party trouv prendr ordre ten just dev empesch tort rich respublicqu feurent facon regn francois viv disciplin obeyss nécess veoi
# 7	0.625	roy homm réform caus bien conseil charg jour justic royaum gard con judg offic apré estat affair ruyn regard veoir
#
# <100> LL/token: -6.05475
# <110> LL/token: -6.0518
# <120> LL/token: -6.03908
# <130> LL/token: -6.03462
# <140> LL/token: -6.02394
#
# 0	0.625	chos fort corp natur form magistrat fin lesquel deu senat fois aristot puissanc pierr outr veu veut mour verit pat
# 1	0.625	justic temp bien comt mal raison main parc court trouv vertu harangu homm injustic dont person vray sort sainct charl
# 2	0.625	vérit chanceli conscienc soix nomm ven telz désordr pun rang soy médecin longueur ault daulphin divers injur tent meschancet conten
# 3	0.625	bel puiss roy rend remonstr ferm extresm beaulx except sieg sacr honnest impun affect compos refus dommaig rembours moeur reg
# 4	0.625	roy bon bien don mémoir honneur duc ordon judg procès mill estat laiss argent lettr rendr néantmoin pro veult dis
# 5	0.625	part republ pourquoy combien ame jug puissanc eau doit fer sorci fort veu populair naturel voir animal soleil fois haut
# 6	0.625	party prendr ordre dev ten just empesch tort rich respublicqu feurent aultruy facon veulent regn francois disciplin obeyss viv public
# 7	0.625	roy estat réform caus homm conseil charg bien jour judg justic droit gard con veoir offic apré royaum affair ruyn
#
# <150> LL/token: -6.01556
# <160> LL/token: -6.01134
# <170> LL/token: -6.00794
# <180> LL/token: -6.00638
# <190> LL/token: -6.01408
#
# 0	0.625	chos fort corp natur fois form magistrat fin deu naturel senat lesquel aristot pierr veu puissanc outr veut mour verit
# 1	0.625	bien justic temp comt mal raison main parc court franc trouv vertu injustic dont person harangu vray sort sainct homm
# 2	0.625	vérit ven conscienc soix nomm telz pun soy désordr rang longueur ault daulphin util divers tent suiss invent chanceli mesti
# 3	0.625	bel puiss bon rend rest remonstr président roy ferm extresm coeur except dommaig sacr honnest possibl impun messieur partout compos
# 4	0.625	roy bon don mémoir honneur duc ordon procès mill laiss paix argent lettr rendr néantmoin pro veult dis bien icel
# 5	0.625	part republ pourquoy puissanc sorci jug combien ame eau doit fer fort populair veu voir animal soleil haut iour savoir
# 6	0.625	party prendr ordre dev ten just empesch tort respublicqu regn veulent facon francois aultruy disciplin obeyss feurent jur rich veoi
# 7	0.625	estat justic roy bien judg caus réform homm conseil charg droit jour royaum gard con veoir offic apré affair ruyn
#
# <200> LL/token: -6.00174
# [beta: 0.03021]
# <210> LL/token: -5.99301
# [beta: 0.03804]
# <220> LL/token: -6.03383
# [beta: 0.04261]
# <230> LL/token: -6.06224
# [beta: 0.0451]
# <240> LL/token: -6.07741
#
# 0	0.17438	chos fort corp natur fin fois form magistrat veu lesquel senat deu aristot pierr outr veut mour ble pat plant
# 1	0.16608	justic temp bien comt mal raison main franc parc court vertu harangu injustic person trouv sort vray sainct dont charl
# 2	0.12947	vérit ven chanceli conscienc profict soix vénal désordr judg repos soy veoi rang pun gaign crainct ault sien enfin telz
# 3	0.12766	puiss bel jean rest offens grac remonstr président rend hériti except bourgongn hommaig sacr honnest impun extresm ambassadeur nobless pré
# 4	0.16032	bon roy don mémoir honneur duc ordon procès mill estat laiss argent lettr bien pro veult dis icel philipp néantmoin
# 5	0.18223	part republ puissanc pourquoy sorci jug combien ame eau naturel doit fer populair animal fort soleil haut voir iour savoir
# 6	0.13976	party prendr ordre ten just dev respublicqu tort aultruy nomm veulent facon francois feurent disciplin obeyss paix gen nécess jur
# 7	0.16687	roy bien estat justic judg caus réform homm conseil charg droit jour gard veoir con offic royaum affair apré ruyn
#
# [beta: 0.04526]
# <250> LL/token: -6.07302
# [beta: 0.04612]
# <260> LL/token: -6.08467
# [beta: 0.04698]
# <270> LL/token: -6.09361
# [beta: 0.04664]
# <280> LL/token: -6.08579
# [beta: 0.04812]
# <290> LL/token: -6.08942
#
# 0	0.09101	chos fort natur corp fin fois form magistrat veu lesquel senat deu aristot pierr outr veut mour verit ble pat
# 1	0.08819	justic temp comt mal royaum raison main bien franc court vertu parc dont sort con vray trouv gen harangu person
# 2	0.07899	justic vérit profict chanceli ven hommaig sainct demand pluspart volont pun soy vénal désordr manier veoi crainct sien remesd conscienc
# 3	0.07819	puiss bel traict pré jean fais rest judg injur meschan grac occas innocent président offens mieulx contrainct plustost rend passion
# 4	0.0865	roy bon don mémoir duc ordon procès honneur mill laiss dev paix argent lettr néantmoin veult dis pro icel philipp
# 5	0.09373	republ part puissanc pourquoy fort sorci jug combien ame naturel doit eau fer voir animal soleil haut iour populair savoir
# 6	0.08026	party prendr ordre ten just arriv scavoir respublicqu tort outraig disciplin facon paris obeyss nécess jur soing nomm épice richess
# 7	0.08901	bien roy estat homm judg réform caus justic conseil charg droit jour gard veoir offic apré affair ruyn afin demeur
#
# [beta: 0.0485]
# <300> LL/token: -6.0897
# [beta: 0.04887]
# <310> LL/token: -6.1055
# [beta: 0.05042]
# <320> LL/token: -6.11658
# [beta: 0.04862]
# <330> LL/token: -6.10732
# [beta: 0.04769]
# <340> LL/token: -6.11082
#
# 0	0.08319	chos natur corp magistrat fort fin fois veu form puissanc lesquel senat aristot feu pierr outr verit deu ble pat
# 1	0.08048	justic temp comt mal raison main parc franc trouv vertu vray dont gen royaum con charl feit nom court jusqu
# 2	0.07529	justic vérit sainct profict court author polic pluspart crainct commenc ven siecl demand aultruy vénal désordr nécess royn veoi soy
# 3	0.07438	traict mieulx puiss bel injur jean chanceli rest rend offens maulvais arriv afin plustost fais meschan extresm pré nobless dommaig
# 4	0.07931	bon don mémoir honneur duc roy ordon procès party dev laiss mill paix néantmoin dis pro veult églis person argent
# 5	0.08469	republ part fort sorci jug combien ame eau naturel doit fer pourquoy voir puissanc animal soleil haut iour savoir air
# 6	0.07514	harangu prendr ten scavoir ordre just hommaig tort respublicqu feurent nomm assembl outraig obeyss gaig sort party richess veulent genz
# 7	0.08151	roy bien estat homm judg réform caus conseil charg jour droit bon gard veoir offic justic apré affair regard enver
#
# [beta: 0.04783]
# <350> LL/token: -6.10844
# [beta: 0.04834]
# <360> LL/token: -6.11685
# [beta: 0.04752]
# <370> LL/token: -6.10155
# [beta: 0.04698]
# <380> LL/token: -6.10009
# [beta: 0.04812]
# <390> LL/token: -6.09577
#
# 0	0.08237	chos fort puissanc natur magistrat fois fin veu form corp lesquel senat aristot outr veut pierr populair verit ble pat
# 1	0.07962	justic temp royaum comt mal raison main court franc parc gen trouv vray sainct person ordre charl vertu pass sort
# 2	0.07484	vérit profict justic dont commenc chanceli polic pluspart crainct dignit facon dev aultruy soy demand nécess occas proced manier veoi
# 3	0.07383	traict mieulx afin pré arriv injur puiss siecl respublicqu rest offens fais plustost maulvais soix vent trouv différend oppress lorsqu
# 4	0.07818	bon don mémoir duc honneur procès ordon party feit injustic laiss mill estat pro dis bel veult églis philipp just
# 5	0.08385	republ part pourquoy sorci jug fort combien ame naturel eau fer doit corp voir animal deu soleil haut iour savoir
# 6	0.07485	harangu prendr ten offici scavoir assembl fidel ordon consider nomm veulent néantmoin feurent gaig outraig disciplin desquelz vertu servyc honor
# 7	0.08113	roy bien estat homm judg réform caus justic bon conseil charg droit jour gard veoir offic apré affair ruyn regard
#
# [beta: 0.0469]
# <400> LL/token: -6.09153
# [beta: 0.04847]
# <410> LL/token: -6.10081
# [beta: 0.04852]
# <420> LL/token: -6.10318
# [beta: 0.04729]
# <430> LL/token: -6.09026
# [beta: 0.04717]
# <440> LL/token: -6.09217
#
# 0	0.08257	chos fort puissanc natur magistrat fin fois form veu corp populair lesquel part senat aristot pierr outr veut verit ble
# 1	0.07984	temp justic comt mal royaum main parc raison franc court trouv estat vertu person sort vray gen charl ordre argent
# 2	0.07488	vérit dont mémoir dev don profict commenc pluspart asseur respublicqu dur esper aultruy ruyn duc gouvern soy vénal disciplin fortun
# 3	0.07448	mémoir traict mieulx saig afin pré arriv hault siecl vent droit francois injur maulvais corrupt provinc plustost lesquelz ais seroient
# 4	0.07789	bon don party procès injustic ordon laiss paix duc feit dis veult églis bel avant philipp grac frer praticqu pro
# 5	0.08355	republ part pourquoy sorci jug combien ame eau naturel doit corp fer voir deu soleil haut iour fort animal air
# 6	0.07485	honneur harangu prendr ten néantmoin offici ordon scavoir hommaig jean tort just regard feurent assembl malheur puisqu gaig honor adviz
# 7	0.08069	roy bien justic homm judg bon réform caus estat conseil jour charg gard veoir con droit offic apré affair mill
#
# [beta: 0.04763]
# <450> LL/token: -6.09922
# [beta: 0.04759]
# <460> LL/token: -6.10083
# [beta: 0.04894]
# <470> LL/token: -6.10219
# [beta: 0.04821]
# <480> LL/token: -6.09572
# [beta: 0.04826]
# <490> LL/token: -6.10991
#
# 0	0.08273	chos fort puissanc natur magistrat fin fois veu form corp populair lesquel senat part aristot pierr outr veut verit ble
# 1	0.07975	temp comt mal charg raison court parc estat justic franc trouv main person vray vertu gen charl duc homm sort
# 2	0.07532	mémoir dev profict injustic dur parmy polic vérit demand jour aultruy fidel commenc amy esper sénat disciplin plustost fortun pluspart
# 3	0.07506	mémoir ordon traict prendr afin lesquelz général arriv sainct provinc injur hault rest personnaig vertueux offens effect con men corrupt
# 4	0.07766	don honneur party procès paix feit ruyn bon rendr sainct veult laiss dis bel pro injustic paris offici philipp églis
# 5	0.08344	republ part pourquoy sorci jug ame eau naturel doit corp fer combien fort voir animal deu haut iour savoir air
# 6	0.07442	ten mieulx argent néantmoin harangu assembl couron jean feurent sieur teneu consider author malheur obeyss honor dign plais sang integr
# 7	0.08072	roy bien justic bon judg estat réform homm caus conseil droit gard veoir jour offic con apré lettr affair mill
#
# [beta: 0.04793]
# <500> LL/token: -6.10605
# [beta: 0.04945]
# <510> LL/token: -6.11813
# [beta: 0.04812]
# <520> LL/token: -6.09682
# [beta: 0.04625]
# <530> LL/token: -6.08458
# [beta: 0.04831]
# <540> LL/token: -6.10606
#
# 0	0.08267	chos fort puissanc natur magistrat fin fois veu form part populair lesquel senat aristot pierr verit ble pat plant alors
# 1	0.0799	homm temp comt mal raison parc estat franc vertu harangu person sort vray justic charl gen main nom duc trouv
# 2	0.07582	mémoir bon party jour profict ten commenc aulcun polic demand dignit affair pluspart esper compaign parmy disciplin plustost proced rang
# 3	0.075	prendr traict sainct afin lesquelz publicqu arriv scavoir injur trouv author asseur judg corrupt francois offens provinc sénat advocat général
# 4	0.07761	don honneur royaum ordon procès injustic dont laiss dev paix duc ruyn bon vérit veult main rendr paris bel avant
# 5	0.08349	republ corp pourquoy sorci jug ame combien eau naturel doit fer part fort animal deu haut iour savoir air semblabl
# 6	0.07361	mieulx court just jean charg sieur bien hault estat outraig obeyss conserv couron maulvais jur dign vénal integr perdr général
# 7	0.08068	roy bien justic judg bon réform caus estat conseil droit gard con offic mill veoir feit enver somm présent ordre
#
# [beta: 0.04812]
# <550> LL/token: -6.10172
# [beta: 0.04673]
# <560> LL/token: -6.0941
# [beta: 0.0467]
# <570> LL/token: -6.08293
# [beta: 0.046]
# <580> LL/token: -6.07461
# [beta: 0.04663]
# <590> LL/token: -6.07485
#
# 0	0.08263	chos fort puissanc natur magistrat fin fois veu form populair part lesquel senat aristot pierr different verit ble pat plant
# 1	0.08014	homm temp estat comt mal raison charg main parc franc person vray sort vertu harangu court gen trouv nom pass
# 2	0.07608	mémoir party jour justic affair aulcun commenc dont profict duc paix bon polic demand dignit pluspart feurent siecl respublicqu couron
# 3	0.07469	sainct prendr traict vérit gard lesquelz général publicqu arriv compt afin assembl injur trouv pouvoir advocat feit francois rendr offens
# 4	0.07751	don honneur ordon procès injustic duc royaum laiss dev ruyn ten apré veult bel dont philipp avant saig charl chanceli
# 5	0.08351	republ corp part pourquoy sorci jug combien ame eau naturel doit fer voir animal feu deu haut iour air savoir
# 6	0.07368	veoir mieulx just nomm nécessair vénal amour sieur dign hault auparav rapport dur mesch administr obeyss malheur lorsqu sed conserv
# 7	0.08049	roy bien justic bon judg réform caus estat conseil droit con offic mill ordre enver présent feust feit selon propos
#
# [beta: 0.0465]
# <600> LL/token: -6.06919
# [beta: 0.04679]
# <610> LL/token: -6.07966
# [beta: 0.04796]
# <620> LL/token: -6.08129
# [beta: 0.04744]
# <630> LL/token: -6.07579
# [beta: 0.04691]
# <640> LL/token: -6.07033
#
# 0	0.0828	chos fort puissanc natur magistrat fin fois veu form part populair lesquel senat aristot pierr different verit ble plant alors
# 1	0.07987	estat justic homm temp mal comt raison parc charg franc trouv harangu sort vertu person vray court charl gen argent
# 2	0.07602	mémoir party royaum justic paix affair main aulcun commenc long polic pluspart offici fidel feurent demand siecl doibt respublicqu frer
# 3	0.07551	sainct prendr traict vérit gard afin général publicqu estim saig compt pouvoir provinc francois offens regard observ assembl maulvais déclar
# 4	0.07759	don honneur duc procès ordon injustic dont laiss apré ruyn dev ten lettr veult rendr bel philipp églis grac royaum
# 5	0.08339	republ corp pourquoy part jug sorci combien ame eau naturel doit fer voir animal deu feu iour haut savoir air
# 6	0.074	veoir mieulx nécessair consider content hault huy rend just vénal viv obeyss amour rapport huict zel util effect mesch reigl
# 7	0.0803	roy bien bon judg justic réform caus conseil droit jour con offic mill ordre faveur enver présent feust selon propos
#
# [beta: 0.04703]
# <650> LL/token: -6.07403
# [beta: 0.04595]
# <660> LL/token: -6.0774
# [beta: 0.04706]
# <670> LL/token: -6.08931
# [beta: 0.04805]
# <680> LL/token: -6.08489
# [beta: 0.0481]
# <690> LL/token: -6.08408
#
# 0	0.0829	chos fort puissanc natur magistrat fin fois veu form part sorci populair lesquel senat aristot different pierr verit ble corp
# 1	0.07977	estat homm justic temp mal charg comt raison court franc trouv vertu vray sort person gen charl parc harangu pauvr
# 2	0.07671	royaum mémoir party justic paix affair demeur aulcun offici commenc frer vivr long chambr polic demand chanceli public esper compaign
# 3	0.07497	gard sainct prendr traict vérit regard afin général saig publicqu compt pouvoir nomm advocat paris offens observ obeyss récompens parc
# 4	0.07781	don duc ordon honneur procès injustic droit laiss apré dev ten main ruyn doibt veult bel lettr lesquelz philipp dont
# 5	0.08333	republ corp pourquoy jug combien ame part naturel doit eau fer voir deu feu haut animal iour savoir soleil air
# 6	0.07415	dont mieulx veoir parmy hault content harangu duch vénal amour honor dign francois plais vent consider besoing sion zel condit
# 7	0.08008	roy bien bon judg justic caus réform conseil con offic jour mill feit ordre présent néantmoin faveur feust somm veoir
#
# [beta: 0.04731]
# <700> LL/token: -6.08279
# [beta: 0.04749]
# <710> LL/token: -6.07905
# [beta: 0.04716]
# <720> LL/token: -6.06526
# [beta: 0.04581]
# <730> LL/token: -6.05861
# [beta: 0.04597]
# <740> LL/token: -6.06495
#
# 0	0.08318	chos fort puissanc natur magistrat fin fois veu part form sorci corp populair lesquel senat aristot pierr different verit ble
# 1	0.07954	estat homm justic temp comt mal charg court trouv franc harangu vertu raison vray sort gen person charl argent main
# 2	0.07606	mémoir royaum party paix justic offici demeur aulcun chanceli long frer vivr public main chambr siecl esper dignit nom polic
# 3	0.07554	prendr vérit traict sainct afin gard général saig publicqu estim compt tort duch provinc parc nomm vent pouvoir advocat amy
# 4	0.07788	don duc honneur ordon droit injustic procès apré dev ruyn ten jusqu doibt rendr bel lesquelz philipp laiss veult églis
# 5	0.08308	republ pourquoy jug combien ame naturel doit corp fer part eau voir animal deu feu haut iour savoir air matier
# 6	0.07431	veoir dont mieulx enver dis assez parmy jeun hault telz sieur amour conserv plais commenc zel condit présent vénal lorsqu
# 7	0.08033	roy bien bon justic judg réform caus conseil jour con offic mill ordre feit faveur lettr néantmoin affair mois feust
#
# [beta: 0.04597]
# <750> LL/token: -6.06161
# [beta: 0.04567]
# <760> LL/token: -6.06395
# [beta: 0.04609]
# <770> LL/token: -6.06964
# [beta: 0.04794]
# <780> LL/token: -6.07971
# [beta: 0.04807]
# <790> LL/token: -6.08279
#
# 0	0.08319	chos fort puissanc natur fin fois magistrat veu sorci form part corp populair lesquel senat aristot pierr different verit ble
# 1	0.0797	estat homm temp mal comt raison franc trouv main sort justic person vertu charg charl laiss court argent gen pauvr
# 2	0.07539	mémoir royaum paix nom charg aulcun offici long chanceli vivr chambr rendr présen envoi respublicqu polic esper besoing volont disciplin
# 3	0.0759	sainct parc gard prendr vérit afin traict néantmoin saig estim publicqu regard commenc tort content duch nomm compt vent apré
# 4	0.07797	don honneur ordon droit duc procès dont injustic dev ten ruyn jusqu veult bien lesquelz mieulx philipp apré frer religion
# 5	0.08304	republ pourquoy jug ame corp naturel doit part fer combien eau voir animal deu soleil haut iour feu savoir air
# 6	0.07366	veoir vray dis just hault fais compaign jeun francois conserv provinc telz troubl parmy sion veoi retourn présent chemin util
# 7	0.08048	roy bien justic bon judg réform caus conseil jour con offic party ordre mill feit pass lettr faveur feust oultr
#
# [beta: 0.04694]
# <800> LL/token: -6.08125
# [beta: 0.04735]
# <810> LL/token: -6.07832
# [beta: 0.04857]
# <820> LL/token: -6.09833
# [beta: 0.04714]
# <830> LL/token: -6.09379
# [beta: 0.04797]
# <840> LL/token: -6.08957
#
# 0	0.08323	chos fort puissanc natur part magistrat fin fois sorci veu corp form populair eau lesquel senat aristot mieux pierr different
# 1	0.07972	estat homm temp comt mal charg raison parc franc court main vertu harangu sort gen veoir person laiss argent trouv
# 2	0.07543	mémoir royaum nom bel offici demeur aulcun chanceli vivr paix trouv guer polic envoi respublicqu siecl longu plainct besoing esper
# 3	0.0755	sainct prendr gard afin néantmoin commenc estim publicqu nécessair arriv rendr content pouvoir injustic nomm vent paix personnaig corrupt soy
# 4	0.07775	don honneur ordon droit procès dont apré dev ten ruyn duc mieulx jusqu traict religion général injustic bien hommaig grac
# 5	0.08299	republ pourquoy jug ame doit fer naturel corp combien voir animal part deu soleil haut iour savoir air matier semblabl
# 6	0.07438	roy veult vray con avant praticqu debvoir fais parmy hault dis sieur compaign francois just doibvent enver veulent vénal compt
# 7	0.08049	roy bien justic bon judg réform caus conseil jour party mill ordre offic feit pass lettr public faveur présent oultr
#
# [beta: 0.04635]
# <850> LL/token: -6.08754
# [beta: 0.04716]
# <860> LL/token: -6.09064
# [beta: 0.04663]
# <870> LL/token: -6.08286
# [beta: 0.04754]
# <880> LL/token: -6.09228
# [beta: 0.04797]
# <890> LL/token: -6.0836
#
# 0	0.08346	chos fort corp puissanc natur magistrat fin fois sorci veu form part populair lesquel senat feu mieux aristot eau different
# 1	0.07954	estat homm temp comt mal charg parc court vertu harangu person sort veoir franc charl vray laiss raison argent trouv
# 2	0.07536	mémoir royaum nom demeur aulcun bel publicqu trouv mieulx vivr duc présen envoi guer siecl demand chambr corrupt disciplin outraig
# 3	0.07494	sainct prendr royaum paix genz néantmoin commenc provinc duch saig pouvoir content estim arriv titr nécessair amy personnaig sénat soy
# 4	0.07755	don honneur ordon droit procès injustic dont duc vérit apré ruyn ten jusqu dev religion grac hommaig avaric églis dur
# 5	0.08274	republ pourquoy part jug ame naturel doit fer combien voir animal deu soleil haut iour air matier semblabl savoir mouv
# 6	0.0749	main roy veult dis just feust avant estat offici debvoir enver hault assez doibvent conserv praticqu compaign homm veulent teneu
# 7	0.08085	roy bien justic bon judg caus réform conseil jour party offic mill feit con gard ordre affair traict doibt public
#
# [beta: 0.04827]
# <900> LL/token: -6.0826
# [beta: 0.04846]
# <910> LL/token: -6.08054
# [beta: 0.04722]
# <920> LL/token: -6.07678
# [beta: 0.04836]
# <930> LL/token: -6.08681
# [beta: 0.04862]
# <940> LL/token: -6.08712
#
# 0	0.08358	chos fort corp puissanc natur magistrat fin fois sorci veu form populair eau lesquel senat aristot mieux combien part different
# 1	0.07945	estat temp homm comt charg mal franc harangu vertu parc person vray sort main veoir charl court argent laiss trouv
# 2	0.07498	mémoir nom mois profict mieulx trouv bel aulcun présen saig respublicqu sieur titr avaric corrupt outraig guer côté obeyss disciplin
# 3	0.07509	royaum sainct prendr gen afin raison commenc ordon genz main demeur arriv duch fidel facon amy demand crainct traict sénat
# 4	0.07743	don honneur duc droit procès dont injustic vérit dev apré ruyn ordon jusqu églis ten paix grac hommaig frer estim
# 5	0.08257	republ part pourquoy ame naturel doit fer jug voir animal deu soleil haut iour savoir air combien semblabl matier mouv
# 6	0.0746	con homm veult feust just dis offici avant praticqu mérit pass enver teneu troubl compaign viv déclar vertueux récompens soy
# 7	0.08117	roy bien justic bon judg réform conseil jour caus gard offic feit mill party raison ordre affair lettr public lesquelz
#
# [beta: 0.04808]
# <950> LL/token: -6.07985
# [beta: 0.04666]
# <960> LL/token: -6.06984
# [beta: 0.04612]
# <970> LL/token: -6.0628
# [beta: 0.04669]
# <980> LL/token: -6.05805
# [beta: 0.04703]
# <990> LL/token: -6.06484
#
# 0	0.08361	chos fort corp puissanc natur magistrat fin fois sorci veu form eau populair senat lesquel aristot mieux combien different souverainet
# 1	0.0795	estat temp comt charg mal homm franc main vertu trouv person sort veoir parc vray gen charl laiss argent harangu
# 2	0.07443	mémoir ordre aulcun profict saig mois publicqu avaric vivr pré présen sieur respublicqu siecl nom heureux doibvent disciplin corrupt obeyss
# 3	0.0747	royaum sainct prendr paix demeur genz arriv roy afin fidel content crainct facon sénat demand puisqu occas serv raison veoit
# 4	0.07773	don honneur duc droit ordon procès dont injustic vérit apré dev conseil ruyn somm rendr églis homm hommaig estim chanceli
# 5	0.08251	republ part pourquoy jug ame naturel doit fer voir animal deu soleil haut iour feu savoir combien air matier semblabl
# 6	0.07507	con homm mémoir pass ten feust just veult dis mérit praticqu envoi court compaign offici soy viv vertueux récompens harangu
# 7	0.08109	roy bien justic bon judg réform caus jour party raison gard offic feit mill traict conseil affair faveur lettr néantmoin
#
# [beta: 0.04772]
# <1000> LL/token: -6.07005
#
# Total time: 4 seconds
# Complete
# ✅ Topic modeling pipeline completed successfully!
# ℹ️  No plots were generated. To create heatmaps or boxplots,
#     import and run plotting_helpers.generate_heatmap() or generate_boxplots().

# %%
import os
from pathlib import Path
import matplotlib.pyplot as plt
import little_mallet_wrapper

# Defaults
DEFAULT_DPI = 300
DEFAULT_DIM_INCHES = (13, 9)  # (width in inches, height in inches)

def _load_model_results():
    """
    Load topic keys, distributions, and filenames from the last pipeline run.
    """
    if not OUTPUT_DIR or not NUM_TOPICS:
        raise RuntimeError(
            "OUTPUT_DIR and NUM_TOPICS must be set at module level. "
            "Define them before calling plotting functions."
        )

    key_file = os.path.join(OUTPUT_DIR, f"mallet.topic_keys.{NUM_TOPICS}")
    dist_file = os.path.join(OUTPUT_DIR, f"mallet.topic_distributions.{NUM_TOPICS}")
    topics = little_mallet_wrapper.load_topic_keys(key_file)
    doc_topics = little_mallet_wrapper.load_topic_distributions(dist_file)

    fn_list = os.path.join(OUTPUT_DIR, "input_filenames.txt")
    with open(fn_list, "r", encoding="utf-8") as f:
        files = [line.strip() for line in f]

    return files, topics, doc_topics

def generate_heatmap():
    """
    Prompt for a desired chart width in pixels, then generate and save a
    topic-by-document heatmap. The chart height and DPI adjust automatically
    to preserve proportions and resolution.  Exports only PDF + PNG.
    """
    # 1) Prompt user for chart width in pixels
    try:
        width_px = int(input("Enter heatmap width in pixels (e.g. 1600): ").strip())
    except ValueError:
        width_px = int(DEFAULT_DIM_INCHES[0] * DEFAULT_DPI)
        print(f"Invalid input, defaulting to {width_px} px width ({DEFAULT_DPI} DPI).")

    # 2) Compute figure size in inches to maintain aspect ratio
    dpi_value = DEFAULT_DPI
    aspect = DEFAULT_DIM_INCHES[1] / DEFAULT_DIM_INCHES[0]
    height_px = int(width_px * aspect)
    figsize = (width_px / dpi_value, height_px / dpi_value)

    # 3) Load model results
    files, topics, doc_topics = _load_model_results()
    labels = [Path(fn).stem for fn in files]

    # 4) Close any prior figure
    plt.close('all')

    # 5) Generate heatmap; wrapper will save PDF internally
    pdf_out = os.path.join(OUTPUT_DIR, "categories_by_topics.pdf")
    fig = little_mallet_wrapper.plot_categories_by_topics_heatmap(
        labels,
        doc_topics,
        topics,
        pdf_out,
        target_labels=labels,
        dim=figsize
    )

    # 6) Ensure we have a Matplotlib Figure
    if fig is None:
        fig = plt.gcf()

    # 7) Draw and save as PNG
    fig.canvas.draw()
    png_out = os.path.join(OUTPUT_DIR, "heatmap.png")
    fig.savefig(png_out, dpi=dpi_value)
    plt.close(fig)

    print(f"Heatmap saved: {pdf_out}, {png_out}")

def generate_boxplot_grid():
    """
    Prompt for a desired chart width in pixels, then draw a grid of boxplots
    (one subplot per topic) and save as a single PDF + PNG. Height and DPI
    adjust automatically to preserve proportions and resolution. Exports only PDF + PNG.
    """
    # 1) Prompt user for chart width in pixels
    try:
        width_px = int(input("Enter boxplot-grid width in pixels (e.g. 1600): ").strip())
    except ValueError:
        width_px = int(DEFAULT_DIM_INCHES[0] * DEFAULT_DPI)
        print(f"Invalid input, defaulting to {width_px} px width ({DEFAULT_DPI} DPI).")

    # 2) Compute figure size in inches
    dpi_value = DEFAULT_DPI
    aspect = DEFAULT_DIM_INCHES[1] / DEFAULT_DIM_INCHES[0]
    height_px = int(width_px * aspect)
    figsize = (width_px / dpi_value, height_px / dpi_value)

    # 3) Load model results
    files, topics, doc_topics = _load_model_results()
    labels = [Path(fn).stem for fn in files]
    n_topics = len(topics)

    # 4) Layout: 2 columns, as many rows as needed
    cols = 2
    rows = (n_topics + cols - 1) // cols

    # 5) Create figure + axes grid
    plt.close('all')
    fig, axes = plt.subplots(rows, cols,
                             figsize=figsize,
                             dpi=dpi_value,
                             sharex=True)
    axes = axes.flatten()

    # 6) Populate each subplot with horizontal boxplot for one topic
    for t_idx in range(n_topics):
        ax = axes[t_idx]
        data = [doc_topics[i][t_idx] for i in range(len(doc_topics))]
        ax.boxplot(data, vert=False)
        ax.set_title(f"Topic {t_idx}")
        ax.set_yticks([])

    # 7) Turn off any unused axes
    for ax in axes[n_topics:]:
        ax.axis("off")

    fig.tight_layout()

    # 8) Save outputs
    pdf_path = os.path.join(OUTPUT_DIR, "all_topic_boxplots.pdf")
    png_path = os.path.join(OUTPUT_DIR, "all_topic_boxplots.png")
    fig.savefig(pdf_path)
    fig.savefig(png_path, dpi=dpi_value)
    plt.close(fig)

    print(f"Boxplot grid saved: {pdf_path}, {png_path}")

def generate_all_plots():
    """
    1) Generate heatmap (width prompt)
    2) Generate a grid of boxplots (width prompt)
    """
    generate_heatmap()
    generate_boxplot_grid()

# Example usage:
# >>> OUTPUT_DIR = "/path/to/output"
# >>> NUM_TOPICS = 10
# >>> generate_all_plots()
if __name__ == "__main__":
    generate_all_plots()
# Out:
# Enter heatmap width in pixels (e.g. 1600):  3500
# Heatmap saved: /home/lucas-jerusalimiec/Documents/OCR Text/Text/Corpora/Concatenated/lemmatized/8Topics/categories_by_topics.pdf
# Enter boxplot-grid width in pixels (e.g. 1600):  3500
# Boxplot grid saved: /home/lucas-jerusalimiec/Documents/OCR Text/Text/Corpora/Concatenated/lemmatized/8Topics/all_topic_boxplots.pdf, /home/lucas-jerusalimiec/Documents/OCR Text/Text/Corpora/Concatenated/lemmatized/8Topics/all_topic_boxplots.png
