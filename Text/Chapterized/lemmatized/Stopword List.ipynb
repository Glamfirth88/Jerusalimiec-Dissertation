# %%
#!pip install -q nltk
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Creating a stop_words list from the NLTK.
import csv # Import the csv module to work with csv files
from nltk.corpus import stopwords # Import stopwords from nltk.corpus
print(stopwords.fileids())
# Out:
# ['albanian', 'arabic', 'azerbaijani', 'basque', 'belarusian', 'bengali', 'catalan', 'chinese', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek', 'hebrew', 'hinglish', 'hungarian', 'indonesian', 'italian', 'kazakh', 'nepali', 'norwegian', 'portuguese', 'romanian', 'russian', 'slovene', 'spanish', 'swedish', 'tajik', 'tamil', 'turkish']

# %%
stop_words = stopwords.words('french') # Create a list `stop_words` that contains the French stop words list

# %%
list(sorted(stop_words)) # Show each string in our stopwords list
# Out:
# ['ai',
#  'aie',
#  'aient',
#  'aies',
#  'ait',
#  'as',
#  'au',
#  'aura',
#  'aurai',
#  'auraient',
#  'aurais',
#  'aurait',
#  'auras',
#  'aurez',
#  'auriez',
#  'aurions',
#  'aurons',
#  'auront',
#  'aux',
#  'avaient',
#  'avais',
#  'avait',
#  'avec',
#  'avez',
#  'aviez',
#  'avions',
#  'avons',
#  'ayant',
#  'ayante',
#  'ayantes',
#  'ayants',
#  'ayez',
#  'ayons',
#  'c',
#  'ce',
#  'ces',
#  'd',
#  'dans',
#  'de',
#  'des',
#  'du',
#  'elle',
#  'en',
#  'es',
#  'est',
#  'et',
#  'eu',
#  'eue',
#  'eues',
#  'eurent',
#  'eus',
#  'eusse',
#  'eussent',
#  'eusses',
#  'eussiez',
#  'eussions',
#  'eut',
#  'eux',
#  'eûmes',
#  'eût',
#  'eûtes',
#  'furent',
#  'fus',
#  'fusse',
#  'fussent',
#  'fusses',
#  'fussiez',
#  'fussions',
#  'fut',
#  'fûmes',
#  'fût',
#  'fûtes',
#  'il',
#  'ils',
#  'j',
#  'je',
#  'l',
#  'la',
#  'le',
#  'les',
#  'leur',
#  'lui',
#  'm',
#  'ma',
#  'mais',
#  'me',
#  'mes',
#  'moi',
#  'mon',
#  'même',
#  'n',
#  'ne',
#  'nos',
#  'notre',
#  'nous',
#  'on',
#  'ont',
#  'ou',
#  'par',
#  'pas',
#  'pour',
#  'qu',
#  'que',
#  'qui',
#  's',
#  'sa',
#  'se',
#  'sera',
#  'serai',
#  'seraient',
#  'serais',
#  'serait',
#  'seras',
#  'serez',
#  'seriez',
#  'serions',
#  'serons',
#  'seront',
#  'ses',
#  'soient',
#  'sois',
#  'soit',
#  'sommes',
#  'son',
#  'sont',
#  'soyez',
#  'soyons',
#  'suis',
#  'sur',
#  't',
#  'ta',
#  'te',
#  'tes',
#  'toi',
#  'ton',
#  'tu',
#  'un',
#  'une',
#  'vos',
#  'votre',
#  'vous',
#  'y',
#  'à',
#  'étaient',
#  'étais',
#  'était',
#  'étant',
#  'étante',
#  'étantes',
#  'étants',
#  'étiez',
#  'étions',
#  'été',
#  'étée',
#  'étées',
#  'étés',
#  'êtes']

# %%
middle_french_stopwords = [
'a', 'aa', 'aaa', 'aag', 'ae', 'ag', 'ain', 'ains', 'ainsi', 'ainsy',
'aist', 'al', 'am', 'an', 'ans', 'apre', 'apres', 'ar', 'ara', 'at',
'aucun', 'aucung', 'aulcung', 'aultr', 'aucc', 'aujourd', 'audict', 'auoit', 'auoir', 'aultre',
'auec', 'aufi', 'auffi', 'auss', 'aussi', 'aussy', 'aut', 'autre', 'autres', 'autr',
'auxdict', 'avoir', 'avoyent', 'avecqu', 'avecque', 'avoient', 'avoit', 'ay', 'ayt', 'b',
'bi', 'bl', 'car', 'cc', 'cel', 'celuy', 'cen', 'cent', 'certes', 'cet',
'ceste', 'cest', 'ceulx', 'ceux', 'cf', 'cft', 'cftoit', 'cg', 'chap', 'chacun',
'chaqu', 'chascung', 'cinq', 'cinquiesm', 'clle', 'co', 'com', 'comb', 'comme', 'comm',
'constituendá', 'cn', 'contr', 'cr', 'cy', 'da', 'dan', 'dc', 'de', 'dé',
'del', 'dela', 'den', 'depuis', 'deux', 'di', 'dict', 'dift', 'dit', 'dix',
'dixiem', 'dixieme', 'do', 'dom', 'douz', 'dud', 'dudict', 'dudit', 'duquel', 'e',
'é', 'ee', 'ec', 'ef', 'efl', 'eft', 'eftoit', 'eftre', 'el', 'ellas',
'elles', 'enl', 'encor', 'encore', 'ena', 'er', 'estant', 'estre', 'estoit', 'estoient',
'estoy', 'estoyent', 'este', 'esté', 'etoient', 'étoient', 'etoit', 'étoit', 'étre', 'étre',
'euffent', 'eulx', 'eust', 'ex', 'f', 'fa', 'faifoyent', 'fait', 'faict', 'fai',
'fair', 'fan', 'fault', 'faut', 'fc', 'fe', 'feroyent', 'feut', 'fes', 'ff',
'fi', 'fil', 'fift', 'firent', 'fit', 'foit', 'fon', 'font', 'ft', 'foub',
'fur', 'fuffent', 'fust', 'g', 'ge', 'grand', 'h', 'he', 'ho', 'i',
'ia', 'iam', 'iamais', 'ic', 'ie', 'iij', 'iir', 'ilz', 'im', 'in',
'ion', 'it', 'iusqu', 'iv', 'ix', 'jam', 'k', 'laquelle', 'ladict', 'ladicte',
'ladit', 'ladite', 'laquel', 'lc', 'led', 'ledict', 'ledit', 'lesdict', 'lesdictz', 'lesdit',
'leurs', 'li', 'lib', 'livr', 'livre', 'livres', 'll', 'lu', 'luy', 'lx',
'lzs', 'm', 'memoir', 'ment', 'mesm', 'mesme', 'mefme', 'mefmes', 'mil', 'million', 'même',
'moy', 'mp', 'mv', 'nc', 'neantmoin', 'ni', 'no', 'non', 'nostr', 'noz',
'nu', 'ny', 'nw', 'o', 'op', 'or', 'ores', 'où', 'oy', 'p',
'pa', 'parl', 'pe', 'peult', 'peulvent', 'peut', 'plus', 'poinct', 'point', 'pourc',
'pourl', 'pourt', 'pre', 'premi', 'pr', 'puis', 'q', 'quand', 'quatr', 'quatre',
'quatriesm', 'quatriesme', 'quele', 'queles', 'quelqu', 'quelque', 'quelquesfois', 'quel', 'quiatellementdifpo', 'quil', 'qut',
'rar', 're', 'r', 'ri', 'rien', 'ro', 'rr', 'san', 'section', 'second', 'ser',
'serois', 'seroit', 'seul', 'si', 'sil', 'six', 'sixiesm', 'sixiesme', 'soubs', 'soub',
'sr', 'tant', 'tel', 'tett', 'tout', 'touts', 'tous', 'tousjour', 'toutes', 'toutesfois',
'trait', 'tr', 'tré', 'tre', 'trois', 'troisieme', 'troisiesm', 'troisiesme', 'trop', 'tt',
'u', 'ua', 'ue', 'ung', 'ur', 'v', 'vingt', 'vi', 'vn', 'vnc',
'vne', 'vnes', 'vostr', 'votr', 'voz', 'w', 'x', 'xx', 'y', 'ya',
'ycel', 'ure', 'z', 'lesquel', 'combien', 'different', 'parc', 'veoir', 'trouv', 'aulcun', 'pré',
'veoit', 'puisqu', 'dont' 'apré', 'somm', 'semblabl', 'pourquoy', 'con', 'ten','feust', 'soy',
'feit', 'main', 'pass', 'dont', 'voir', 'lesquelz', 'fais', 'pluspart', 'néantmoin', 'pro', 'huy',
'parmy', 'mill', 'arriv', 'assez', 'men', 'mieulx', 'commenc', 'mois', 'ore', 'tousiour', 'ble',
'prendr', 'ven', 'avant', 'pend', 'jusqu', 'enver', 'selon', 'deu', 'celà', 'apré','feurent', 'per', 'soyent','fix', 'quin',
'lequel', 'dis', 'dir', 'icel','auff','aufl', 'deffus', 'cít', 'fen', 'eftan', 'oultr', 'présent', 'pat', 'pluftoft', 'alors', 'foy', 'dev',
'aur', 'moin', 'desquelz', 'plustost', 'tost', 'aul', 'aultruy', 'voyon', 'ausquel' 'mef', 'àla', 'presqu',
'plaif', 'parau', 'caril', 'mef', 'ent', 'desquel', 'fuit', 'eur', 'telz', 'soix', 'outr', 'mémoir',
'def', 'lesautr', 'leu', 'ail', 'afin', 'harangu', 'lorsqu', 'sien', 'faudroit', 'oit', 'onque',
'auparav', 'quelconqu', 'prochain', 'seroient', 'autruy', 'nec', 'sion', 'quam', 'commeil', 'mel', 'quaf', 'ila', 'cho', 'ainf',
'ren', 'tousl', 'plufpart', 'maisil', 'faisoient', 'ault', 'surtout', 'desdict', 'come', 'huict',
'iceulx', 'dif', 'ausquel','quelz','possit','positum', 'quod', 'cóme', 'jus', 'dient', 'sed', 'donc', 'avon', 'lor', 'donqu',
'tou', 'cecy', 'sinon', 'dic', 'donqu', 'fac', 'prin', 'plu', 'sept', 'entre', 'disoit', 'ver', 'fub', 'plusieur', 'remarqu', 'disent', 'voilà', 'cap', 'cert',
'vient', 'cz'
]

combined_stopwords = stop_words + middle_french_stopwords
# list(combined_stopwords)[-10:]  # Previous behavior: only show last 10
# New behavior: sort alphabetically and print full list
sorted_combined_stopwords = sorted(set(combined_stopwords))  # Use set to remove duplicates before sorting
print("Total unique stopwords:", len(sorted_combined_stopwords))
# Old per-line output retained for reference:
# for w in sorted_combined_stopwords:
#     print(w)
# Single-line version (kept commented):
# print(', '.join(sorted_combined_stopwords))
# Wrapped output (max ~120 chars per line) for easier copying without horizontal scrolling
import textwrap
csv_line = ', '.join(sorted_combined_stopwords)
for segment in textwrap.wrap(csv_line, width=120):
    print(segment)
# Out:
# Total unique stopwords: 663
# a, aa, aaa, aag, ae, afin, ag, ai, aie, aient, aies, ail, ain, ainf, ains, ainsi, ainsy, aist, ait, al, alors, am, an,
# ans, apre, apres, apré, ar, ara, arriv, as, assez, at, au, aucc, aucun, aucung, audict, auec, auff, auffi, aufi, aufl,
# aujourd, aul, aulcun, aulcung, ault, aultr, aultre, aultruy, auoir, auoit, auparav, aur, aura, aurai, auraient, aurais,
# aurait, auras, aurez, auriez, aurions, aurons, auront, ausquel, ausquelmef, auss, aussi, aussy, aut, autr, autre,
# autres, autruy, aux, auxdict, avaient, avais, avait, avant, avec, avecqu, avecque, avez, aviez, avions, avoient, avoir,
# avoit, avon, avons, avoyent, ay, ayant, ayante, ayantes, ayants, ayez, ayons, ayt, b, bi, bl, ble, c, cap, car, caril,
# cc, ce, cecy, cel, celuy, celà, cen, cent, cert, certes, ces, cest, ceste, cet, ceulx, ceux, cf, cft, cftoit, cg,
# chacun, chap, chaqu, chascung, cho, cinq, cinquiesm, clle, cn, co, com, comb, combien, come, comm, comme, commeil,
# commenc, con, constituendá, contr, cr, cy, cz, cít, cóme, d, da, dan, dans, dc, de, def, deffus, del, dela, den, depuis,
# des, desdict, desquel, desquelz, deu, deux, dev, di, dic, dict, dient, dif, different, dift, dir, dis, disent, disoit,
# dit, dix, dixiem, dixieme, do, dom, donc, donqu, dont, dontapré, douz, du, dud, dudict, dudit, duquel, dé, e, ec, ee,
# ef, efl, eft, eftan, eftoit, eftre, el, ellas, elle, elles, en, ena, encor, encore, enl, ent, entre, enver, er, es, est,
# estant, este, estoient, estoit, estoy, estoyent, estre, esté, et, etoient, etoit, eu, eue, eues, euffent, eulx, eur,
# eurent, eus, eusse, eussent, eusses, eussiez, eussions, eust, eut, eux, ex, eûmes, eût, eûtes, f, fa, fac, fai, faict,
# faifoyent, fair, fais, faisoient, fait, fan, faudroit, fault, faut, fc, fe, feit, fen, feroyent, fes, feurent, feust,
# feut, ff, fi, fift, fil, firent, fit, fix, foit, fon, font, foub, foy, ft, fub, fuffent, fuit, fur, furent, fus, fusse,
# fussent, fusses, fussiez, fussions, fust, fut, fûmes, fût, fûtes, g, ge, grand, h, harangu, he, ho, huict, huy, i, ia,
# iam, iamais, ic, icel, iceulx, ie, iij, iir, il, ila, ils, ilz, im, in, ion, it, iusqu, iv, ix, j, jam, je, jus, jusqu,
# k, l, la, ladict, ladicte, ladit, ladite, laquel, laquelle, lc, le, led, ledict, ledit, lequel, les, lesautr, lesdict,
# lesdictz, lesdit, lesquel, lesquelz, leu, leur, leurs, li, lib, livr, livre, livres, ll, lor, lorsqu, lu, lui, luy, lx,
# lzs, m, ma, main, mais, maisil, me, mef, mefme, mefmes, mel, memoir, men, ment, mes, mesm, mesme, mieulx, mil, mill,
# million, moi, moin, mois, mon, moy, mp, mv, mémoir, même, n, nc, ne, neantmoin, nec, ni, no, non, nos, nostr, notre,
# nous, noz, nu, nw, ny, néantmoin, o, oit, on, onque, ont, op, or, ore, ores, ou, oultr, outr, oy, où, p, pa, par, parau,
# parc, parl, parmy, pas, pass, pat, pe, pend, per, peult, peulvent, peut, plaif, plu, plufpart, pluftoft, plus, plusieur,
# pluspart, plustost, poinct, point, positum, possit, pour, pourc, pourl, pourquoy, pourt, pr, pre, premi, prendr, presqu,
# prin, pro, prochain, pré, présent, puis, puisqu, q, qu, quaf, quam, quand, quatr, quatre, quatriesm, quatriesme, que,
# quel, quelconqu, quele, queles, quelqu, quelque, quelquesfois, quelz, qui, quiatellementdifpo, quil, quin, quod, qut, r,
# rar, re, remarqu, ren, ri, rien, ro, rr, s, sa, san, se, second, section, sed, selon, semblabl, sept, ser, sera, serai,
# seraient, serais, serait, seras, serez, seriez, serions, seroient, serois, seroit, serons, seront, ses, seul, si, sien,
# sil, sinon, sion, six, sixiesm, sixiesme, soient, sois, soit, soix, somm, sommes, son, sont, soub, soubs, soy, soyent,
# soyez, soyons, sr, suis, sur, surtout, t, ta, tant, te, tel, telz, ten, tes, tett, toi, ton, tost, tou, tous, tousiour,
# tousjour, tousl, tout, toutes, toutesfois, touts, tr, trait, tre, trois, troisieme, troisiesm, troisiesme, trop, trouv,
# tré, tt, tu, u, ua, ue, un, une, ung, ur, ure, v, ven, veoir, veoit, ver, vi, vient, vingt, vn, vnc, vne, vnes, voilà,
# voir, vos, vostr, votr, votre, vous, voyon, voz, w, x, xx, y, ya, ycel, z, à, àla, é, étaient, étais, était, étant,
# étante, étantes, étants, étiez, étions, étoient, étoit, étre, été, étée, étées, étés, êtes

# %%
with open('./stop_words.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(combined_stopwords)
