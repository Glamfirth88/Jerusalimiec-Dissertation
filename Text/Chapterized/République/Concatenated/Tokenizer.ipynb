# %%
from pathlib import Path
import glob
import os
import sys
import csv
import nltk
from collections import Counter
from nltk.tokenize import word_tokenize,wordpunct_tokenize
from nltk.collocations import BigramCollocationFinder, BigramAssocMeasures, TrigramCollocationFinder, TrigramAssocMeasures

import locale
# Set the locale to your desired setting (e.g., 'fr_FR.UTF-8' for French)
locale.setlocale(locale.LC_ALL, 'fr_FR.UTF-8')
# Out:
# 'fr_FR.UTF-8'

# %%
sys.path.append("/home/lucas-jerusalimiec/Documents/OCR Text/Notebooks")
from tokenizer_func  import (wordcleaner, write_words_to_file, dictionary_to_file, convert_tuple_bigrams,
convert_tuple_trigrams)

from extra_token_func import print_first_n_items, remove_keys_from_nested_dict

from additional_token_func import convert_strings_to_counts

from dict_write import write_dict_to_files_with_suffix

# %%
text_loc = Path("./final")
text_files = sorted(glob.glob(f"{text_loc}/*.txt"), key=locale.strxfrm)
output_folder = './tokenized/'
tokenized_folder = Path(output_folder)
tokenized_folder.mkdir(exist_ok=True)

output_unigram = f'{output_folder}unigram_counts'
unigram_folder = Path(output_unigram)
unigram_folder.mkdir(exist_ok=True)

output_bigram = f'{output_folder}bigram_counts'
bigram_folder = Path(output_bigram)
bigram_folder.mkdir(exist_ok=True)

output_trigram = f'{output_folder}trigram_counts'
trigram_folder = Path(output_trigram)
trigram_folder.mkdir(exist_ok=True)

output_collocation = f'{output_folder}collocation_counts'
collocation_folder = Path(output_collocation)
collocation_folder.mkdir(exist_ok=True)

output_trigram_collocation = f'{output_folder}trigram_collocation_counts'
trigram_collocation_folder = Path(output_trigram_collocation)
trigram_collocation_folder.mkdir(exist_ok=True)

output_underscore = f'{output_folder}underscore_bigrams'
underscore_folder = Path(output_underscore)
underscore_folder.mkdir(exist_ok=True)

output_trigram_underscore = f'{output_folder}underscore_trigrams'
trigram_underscore_folder = Path(output_trigram_underscore)
trigram_underscore_folder.mkdir(exist_ok=True)

print("Text files in the spellchecked directory:", text_files)
# Out:
# Text files in the spellchecked directory: ['final/République I_corrected.txt', 'final/République II_corrected.txt', 'final/République III_corrected.txt', 'final/République IV_corrected.txt', 'final/République V_corrected.txt', 'final/République VI_corrected.txt', 'final/Réublique Preface_corrected.txt']

# %%
# Open stopwords CSV file and list the contents
with open('./stop_words.csv', 'r') as f:
    stopwords = f.read().strip().split(",")
stopwords[-10:]
# Out:
# ['v', 'vn', 'vne', 'vnes', 'w', 'x', 'ya', 'encores', 'quele', 'queles']

# %%
tokenized_texts = {}
for txt in text_files:
    with open(txt, 'r') as f:
        content = f.read()
        file_name = txt.split('\\')[-1]
        #key = file_name.split('.')[0]
        key = os.path.splitext(os.path.basename(file_name))[0]
        tokenized_texts[key] = content
print("Raw texts:", list(tokenized_texts.keys()))
# Out:
# Raw texts: ['République I_corrected', 'République II_corrected', 'République III_corrected', 'République IV_corrected', 'République V_corrected', 'République VI_corrected', 'Réublique Preface_corrected']

# %%
unigrams = {}

for key, value in tokenized_texts.items():
    unigram_list = wordpunct_tokenize(value)
    cleanwords = [wordcleaner(w) for w in unigram_list]
    unigrams[key] = cleanwords

for key, value in unigrams.items():
    filename = f"./tokenized/{key}.txt"
    write_words_to_file(value, filename, words_per_line=20)
    print(f"Saved content for '{key}' to {filename}")
# Out:
# Saved content for 'République I_corrected' to ./tokenized/République I_corrected.txt
# Saved content for 'République II_corrected' to ./tokenized/République II_corrected.txt
# Saved content for 'République III_corrected' to ./tokenized/République III_corrected.txt
# Saved content for 'République IV_corrected' to ./tokenized/République IV_corrected.txt
# Saved content for 'République V_corrected' to ./tokenized/République V_corrected.txt
# Saved content for 'République VI_corrected' to ./tokenized/République VI_corrected.txt
# Saved content for 'Réublique Preface_corrected' to ./tokenized/Réublique Preface_corrected.txt

# %%
print("Unigram texts:")
for key in unigrams:
    print(key)
# Out:
# Unigram texts:
# République I_corrected
# République II_corrected
# République III_corrected
# République IV_corrected
# République V_corrected
# République VI_corrected
# Réublique Preface_corrected

# %%
# Count up the tokens using a Counter() object
unigram_counts = {}
for key, value in unigrams.items():
    unigram_counts_dict = Counter(value)
    unigram_counts[key] = unigram_counts_dict

print("Unigram Counts:")
for key in unigram_counts:
    print(key)

print_first_n_items(unigram_counts, 25)
# Out:
# Unigram Counts:
# République I_corrected
# République II_corrected
# République III_corrected
# République IV_corrected
# République V_corrected
# République VI_corrected
# Réublique Preface_corrected
# First 25 items in République I_corrected:
# : 30923
# de: 4020
# la: 1936
# les: 1837
# que: 1674
# en: 1590
# le: 1472
# d: 1365
# l: 1350
# qui: 1341
# il: 1285
# qu: 1235
# à: 1146
# des: 1043
# est: 922
# du: 840
# n: 821
# pour: 720
# ne: 707
# par: 695
# au: 621
# ce: 572
# roy: 524
# a: 514
# ou: 482
#
# First 25 items in République II_corrected:
# : 8723
# de: 1105
# la: 559
# les: 544
# que: 503
# en: 471
# l: 431
# il: 427
# qui: 388
# qu: 368
# d: 363
# à: 359
# le: 356
# des: 355
# est: 267
# n: 225
# du: 212
# par: 211
# plus: 204
# ou: 198
# pour: 190
# a: 187
# vn: 180
# au: 164
# comme: 161
#
# First 25 items in République III_corrected:
# : 16751
# de: 1830
# les: 1051
# la: 1002
# que: 914
# en: 880
# le: 789
# il: 784
# qu: 749
# qui: 740
# des: 710
# l: 645
# d: 620
# à: 610
# est: 492
# n: 490
# du: 455
# par: 449
# pour: 435
# ou: 433
# ce: 420
# ne: 389
# au: 372
# a: 323
# on: 308
#
# First 25 items in République IV_corrected:
# : 19161
# de: 2149
# les: 1229
# la: 1164
# que: 1073
# en: 1055
# il: 908
# qui: 875
# l: 847
# d: 832
# le: 827
# qu: 817
# des: 779
# à: 750
# est: 512
# du: 462
# n: 451
# plus: 448
# au: 415
# pour: 412
# par: 396
# ne: 375
# vn: 357
# a: 348
# ce: 342
#
# First 25 items in République V_corrected:
# : 12431
# de: 1477
# les: 965
# la: 762
# que: 707
# en: 670
# d: 593
# qui: 591
# l: 581
# qu: 555
# des: 553
# il: 521
# le: 498
# à: 429
# plus: 381
# est: 348
# pour: 327
# n: 296
# du: 271
# ne: 269
# au: 266
# aux: 259
# ce: 215
# ils: 213
# par: 206
#
# First 25 items in République VI_corrected:
# : 21985
# de: 2688
# les: 1517
# la: 1377
# en: 1285
# que: 1257
# d: 1170
# le: 1097
# qui: 1061
# l: 1048
# il: 1018
# qu: 971
# des: 873
# à: 826
# est: 726
# pour: 666
# plus: 587
# n: 579
# vn: 510
# du: 495
# au: 485
# par: 484
# ne: 466
# a: 425
# ce: 398
#
# First 25 items in Réublique Preface_corrected:
# : 311
# de: 53
# la: 40
# les: 29
# que: 28
# l: 27
# en: 26
# qui: 25
# des: 24
# a: 22
# pour: 21
# le: 19
# c: 18
# d: 16
# qu: 15
# il: 14
# à: 13
# par: 12
# ce: 11
# aux: 11
# du: 10
# toutes: 10
# plus: 10
# ont: 9
# princes: 9

# %%
# Remove specified keys from the dictionary
stripped_unigrams = remove_keys_from_nested_dict(unigram_counts, stopwords)

print_first_n_items(stripped_unigrams, 30)
# Out:
# First 30 items in République I_corrected:
# : 30923
# roy: 524
# bien: 327
# prince: 281
# puissance: 262
# empereur: 213
# aussi: 208
# faire: 198
# peuple: 198
# sujets: 192
# princes: 191
# republique: 190
# droit: 184
# france: 184
# celuy: 157
# an: 154
# pape: 152
# loy: 151
# foit: 150
# contre: 147
# estre: 140
# entre: 137
# empire: 135
# premier: 134
# souverain: 134
# romains: 134
# loix: 128
# foy: 127
# sujet: 123
# mesmes: 121
#
# First 30 items in République II_corrected:
# : 8723
# estat: 143
# roy: 128
# bien: 126
# peuple: 101
# puissance: 84
# prince: 82
# republique: 80
# aussi: 67
# faire: 62
# empire: 62
# sujets: 59
# princes: 59
# estats: 57
# populaire: 57
# foit: 56
# roys: 55
# tyran: 53
# empereur: 53
# trois: 45
# estre: 45
# monarchie: 44
# mort: 42
# celuy: 42
# souveraineté: 41
# senat: 40
# grand: 39
# dire: 39
# republiques: 38
# contre: 37
#
# First 30 items in République III_corrected:
# : 16751
# magistrats: 233
# puissance: 206
# bien: 186
# senat: 155
# faire: 151
# prince: 139
# magistrat: 134
# peuple: 128
# aussi: 115
# roy: 101
# conseil: 100
# republique: 97
# corps: 97
# loy: 95
# estat: 93
# foit: 90
# non: 88
# doit: 81
# college: 76
# loix: 75
# quand: 74
# charge: 74
# chose: 70
# estre: 67
# colleges: 67
# lettres: 67
# lieu: 65
# estats: 65
# plusieurs: 64
#
# First 30 items in République IV_corrected:
# : 19161
# bien: 232
# estat: 221
# roy: 207
# peuple: 167
# republique: 148
# aussi: 146
# ans: 139
# prince: 123
# sujets: 123
# faire: 119
# depuis: 106
# foit: 101
# republiques: 98
# peu: 95
# an: 95
# puissance: 93
# estre: 88
# iusques: 87
# grand: 84
# entre: 82
# plusieurs: 80
# contre: 79
# faut: 79
# princes: 79
# quand: 78
# estats: 78
# populaire: 75
# magistrats: 73
# trois: 72
#
# First 30 items in République V_corrected:
# : 12431
# bien: 198
# aussi: 127
# peuple: 115
# roy: 111
# peuples: 110
# estat: 85
# pays: 77
# faire: 69
# hommes: 66
# prince: 63
# sujets: 62
# estre: 60
# foit: 60
# peu: 59
# republique: 57
# guerre: 56
# romains: 54
# moyen: 53
# biens: 53
# moins: 52
# faut: 51
# empereur: 45
# ville: 44
# entre: 44
# grand: 44
# cause: 43
# fort: 43
# rien: 43
# princes: 42
#
# First 30 items in République VI_corrected:
# : 21985
# roy: 301
# bien: 234
# estat: 208
# peuple: 184
# aussi: 163
# republique: 150
# faire: 142
# mil: 136
# foit: 124
# royaume: 119
# argent: 109
# entre: 109
# princes: 107
# trois: 106
# an: 104
# cens: 102
# prince: 100
# sujets: 95
# deniers: 95
# loy: 91
# estre: 89
# faut: 89
# populaire: 86
# grand: 85
# ans: 84
# moins: 84
# peu: 84
# tousjours: 83
# quand: 82
#
# First 30 items in Réublique Preface_corrected:
# : 311
# princes: 9
# mieux: 6
# faire: 6
# republiques: 6
# republique: 5
# estre: 5
# estat: 5
# bien: 5
# depuis: 5
# affaires: 5
# loix: 4
# moins: 4
# grand: 4
# fois: 4
# iustice: 4
# ex: 3
# royaume: 3
# efl: 3
# nature: 3
# non: 3
# cest: 3
# fort: 3
# platon: 3
# monde: 3
# cr: 3
# cg: 3
# age: 3
# enuers: 3
# terre: 3

# %%
dictionary_to_file(stripped_unigrams, unigram_folder, 'unigram_counts')
# Out:
# Saved République I_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved République II_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved République III_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved République IV_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved République V_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved République VI_corrected_unigram_counts.csv in tokenized/unigram_counts
# Saved Réublique Preface_corrected_unigram_counts.csv in tokenized/unigram_counts

# %%
bigrams = {}

for key, value in unigrams.items():
    unigram_list = [word for word in value if word.lower() not in stopwords]
    #unigram_list = [word for word in value]
    bigrams_list = list(nltk.bigrams(unigram_list))
    bigrams[key] = bigrams_list

print("Bigrams:")
for key in bigrams:
    print(key)
# Out:
# Bigrams:
# République I_corrected
# République II_corrected
# République III_corrected
# République IV_corrected
# République V_corrected
# République VI_corrected
# Réublique Preface_corrected

# %%
bigram_counts = {}

for key, value in bigrams.items():
    string_bigrams = convert_tuple_bigrams(value)
    bigramCount = convert_strings_to_counts(string_bigrams)
    bigram_counts[key] = bigramCount

print("Bigram Counts:")
for key in bigram_counts:
    print(key)

print_first_n_items(bigram_counts, 30)
# Out:
# Bigram Counts:
# République I_corrected
# République II_corrected
# République III_corrected
# République IV_corrected
# République V_corrected
# République VI_corrected
# Réublique Preface_corrected
# First 30 items in République I_corrected:
# prince souverain: 62
# roy france: 48
# empereur charles: 24
# ains aussi: 21
# non seulement: 20
# roys france: 18
# bien certain: 17
# sujet naturel: 17
# roy charles: 17
# menu peuple: 16
# roy françois: 16
# bien souvent: 15
# cas pareil: 15
# homme lige: 15
# princes souverains: 15
# cy dessus: 14
# doit estre: 13
# faire mourir: 13
# droit bourgeoisie: 13
# toute republique: 12
# trois cens: 12
# roy louis: 12
# entre princes: 11
# puissance paternelle: 11
# peu peu: 11
# prince souverian: 11
# hommage lige: 11
# droit gouvernement: 10
# quelque chose: 10
# toute puissance: 10
#
# First 30 items in République II_corrected:
# estat populaire: 21
# moindre partie: 12
# gens bien: 12
# cy dessus: 12
# prince souverain: 11
# bien souvent: 11
# grand conseil: 11
# villes imperiales: 10
# puissance souveraine: 9
# monarchie seigneuriale: 8
# partie peuple: 7
# menu peuple: 7
# mil citoyens: 7
# aussi bien: 6
# ains aussi: 6
# grand nombre: 6
# bien fort: 6
# loix nature: 6
# monarque seigneurial: 6
# monstré cy: 6
# voye iustice: 6
# non seulement: 6
# privé conseil: 6
# anciennes familles: 6
# estat aristocratique: 5
# estat fera: 5
# bien vray: 5
# contre roy: 5
# donne estats: 5
# cas pareil: 5
#
# First 30 items in République III_corrected:
# cy dessus: 23
# puissance commander: 21
# conseil privé: 17
# quelques uns: 15
# cas pareil: 12
# doit estre: 12
# prince souverain: 12
# ains aussi: 11
# non seulement: 10
# voix deliberative: 10
# parlement paris: 10
# bien souvent: 9
# quand question: 9
# lettres iustice: 9
# menu peuple: 8
# estat populaire: 8
# puissance faire: 8
# doit faire: 8
# charge publique: 8
# quatre cens: 8
# tribun peuple: 8
# lettres patentes: 8
# faire guerre: 8
# magistrat doit: 8
# passer outre: 8
# toute republique: 7
# advis senat: 7
# ains seulement: 7
# peu peu: 7
# beaucoup moins: 7
#
# First 30 items in République IV_corrected:
# estat populaire: 51
# ains aussi: 23
# cy dessus: 20
# guerres civiles: 19
# estats populaires: 18
# peu peu: 17
# hautes planettes: 16
# bien souvent: 13
# roy france: 13
# guerre civile: 13
# trois cens: 12
# non seulement: 11
# mois septembre: 11
# menu peuple: 10
# tire foy: 10
# trois hautes: 10
# cens ans: 9
# quelques uns: 9
# sept cens: 9
# ruines republiques: 9
# peuple romain: 8
# roy macedoine: 8
# grands seigneurs: 8
# ioint aussi: 8
# creation monde: 8
# doit faire: 8
# bien certain: 7
# empire romain: 7
# cens cinquante: 7
# mil hommes: 7
#
# First 30 items in République V_corrected:
# peuples septentrion: 21
# estat populaire: 18
# peuple meridional: 16
# menu peuple: 12
# loy dieu: 10
# non seulement: 9
# guerres civiles: 9
# bien fort: 8
# peuples midy: 8
# ains aussi: 8
# peu peu: 7
# gens bien: 7
# long temps: 6
# sept mil: 6
# cens ans: 6
# roy france: 6
# bien certain: 6
# cinq cens: 6
# beaucoup mieux: 6
# aussi voit: 6
# bien souvent: 6
# places fortes: 6
# pays meridional: 5
# aussi voyons: 5
# pauvreté extreme: 5
# doit estre: 5
# empereur charles: 5
# estat aristocratique: 5
# cy dessus: 5
# biens condamnez: 5
#
# First 30 items in République VI_corrected:
# estat populaire: 60
# cens mil: 25
# menu peuple: 25
# mil escus: 23
# cinq cens: 20
# roy france: 17
# bien souvent: 14
# non seulement: 13
# quatre cens: 13
# ains aussi: 13
# proportion geometrique: 13
# bien fort: 12
# iustice harmonique: 12
# cy dessus: 11
# trois cens: 11
# gens bien: 11
# roy françois: 11
# quatre deniers: 11
# guerres civiles: 11
# doit estre: 10
# seigneurs ligues: 10
# cens ans: 10
# forme republique: 10
# grand nombre: 9
# dix mil: 9
# peu peu: 9
# mil cinq: 8
# cy deuant: 8
# parce moyen: 8
# estat finances: 8
#
# First 30 items in Réublique Preface_corrected:
# ruine republiques: 2
# maniement affaires: 2
# vertueux princes: 2
# an lise: 1
# sat æ: 1
# pretage uantrien: 1
# uantrien mieux: 1
# entrepris discours: 1
# discours republique: 1
# langue populaire: 1
# fources langue: 1
# langue latine: 1
# feicheront barbarie: 1
# barbarie caufce: 1
# caufce guerres: 1
# guerres civiles: 1
# civiles continue: 1
# continue estre: 1
# estre mieux: 1
# tendu françois: 1
# françois naturels: 1
# dy desir: 1
# ex vouloir: 1
# vouloir perpetuel: 1
# perpetuel voir: 1
# estat royaume: 1
# royaume premiere: 1
# p endeur: 1
# endeur fleurissant: 1
# fleurissant armes: 1

# %%
dictionary_to_file(bigram_counts, bigram_folder, 'bigram_counts')
# Out:
# Saved République I_corrected_bigram_counts.csv in tokenized/bigram_counts
# Saved République II_corrected_bigram_counts.csv in tokenized/bigram_counts
# Saved République III_corrected_bigram_counts.csv in tokenized/bigram_counts
# Saved République IV_corrected_bigram_counts.csv in tokenized/bigram_counts
# Saved République V_corrected_bigram_counts.csv in tokenized/bigram_counts
# Saved République VI_corrected_bigram_counts.csv in tokenized/bigram_counts
# Saved Réublique Preface_corrected_bigram_counts.csv in tokenized/bigram_counts

# %%
trigrams = {}

for key, value in unigrams.items():
    unigram_list = [word for word in value if word.lower() not in stopwords]
    #unigram_list = [word for word in value]
    trigrams_list = list(nltk.trigrams(unigram_list))
    trigrams[key] = trigrams_list

print("Trigrams:")
for key in bigrams:
    print(key)
# Out:
# Trigrams:
# République I_corrected
# République II_corrected
# République III_corrected
# République IV_corrected
# République V_corrected
# République VI_corrected
# Réublique Preface_corrected

# %%
trigram_counts = {}

for key, value in trigrams.items():
    string_trigrams = convert_tuple_trigrams(value)
    trigramCount = convert_strings_to_counts(string_trigrams)
    trigram_counts[key] = trigramCount

print("Trigram Counts:")
for key in trigram_counts:
    print(key)
    
print_first_n_items(trigram_counts, 30)
# Out:
# Trigram Counts:
# République I_corrected
# République II_corrected
# République III_corrected
# République IV_corrected
# République V_corrected
# République VI_corrected
# Réublique Preface_corrected
# First 30 items in République I_corrected:
# quelque forte foit: 5
# droit gouvernement plusieurs: 3
# long temps parauant: 3
# cens mil escus: 3
# augufte roy depoloigne: 3
# caril bien certain: 3
# sujet naturel roy: 3
# homme lige pape: 3
# puissance faire loix: 3
# monstré cy dessus: 3
# auoyent force an: 3
# donner loy general: 3
# toute republique bien: 2
# republique estre bien: 2
# contemplation choses naturelles: 2
# souverain bien gift: 2
# aussi bien republique: 2
# grand monarque terre: 2
# peres enuers enfans: 2
# reuerence enfans enuers: 2
# republique bien ordônee: 2
# pere enuers enfans: 2
# maiftre enuers feruiteurs: 2
# duquel mot vfent: 2
# faire mourir femme: 2
# sept cens ans: 2
# faire quelque chose: 2
# auós laloy dieu: 2
# combien philippe valois: 2
# mere enuers enfans: 2
#
# First 30 items in République II_corrected:
# monstré cy dessus: 5
# moindre partie peuple: 4
# moindre partie citoyens: 4
# quatrieme meflee trois: 2
# doner loy sujets: 2
# prince donne estats: 2
# conuenir finon celuy: 2
# contre prince souverain: 2
# bien petit nombre: 2
# dix mil citoyens: 2
# cinq iuges criminels: 2
# auons monstré cy: 2
# estat fera populaire: 2
# estats menu peuple: 2
# repvblique mort vle: 1
# mort vle marques: 1
# vle marques referuees: 1
# marques referuees prince: 1
# referuees prince souverain: 1
# voila nt principaux: 1
# nt principaux points: 1
# principaux points concernans: 1
# points concernans maiesté: 1
# concernans maiesté souveriane: 1
# maiesté souveriane fuement: 1
# poffible traicté matiere: 1
# nent liure imperio: 1
# lique depend tiennent: 1
# depend tiennent souverianeté: 1
# difons combien fortes: 1
#
# First 30 items in République III_corrected:
# auons cy dessus: 5
# monstré cy dessus: 3
# auons monstré cy: 3
# fix cens senateurs: 2
# vaut beaucoup mieux: 2
# peine deleze maicfté: 2
# prefenter requeste peuple: 2
# mieux gardé venize: 2
# moftré cy dessus: 2
# officier personne publique: 2
# quelque forte foit: 2
# efl ad populum: 2
# commiflaires deputez souverain: 2
# iugé arrest parlement: 2
# imperio effe donec: 2
# puissance faire adiourner: 2
# condamné iugement public: 2
# dire force commander: 2
# iugent quelques uns: 2
# aussi pouuons dire: 2
# contre loy dieu: 2
# rien contre loy: 2
# quatre cens mil: 2
# magistrat doit faire: 2
# grands estats peuple: 2
# prince commande rien: 2
# commande rien foit: 2
# mourir deuant voir: 2
# pouuoir adioufter diminuer: 2
# entrer auant difpute: 2
#
# First 30 items in République IV_corrected:
# trois hautes planettes: 10
# monstré cy dessus: 6
# sept cens ans: 5
# mil trois cens: 5
# mil cinq cens: 4
# creation monde iusques: 4
# grand dieu nature: 4
# foy bien souvent: 3
# cinq mil cinq: 3
# bien petit nombre: 3
# neuf cens mil: 2
# cens cinquante ans: 2
# aduient souvent estats: 2
# souvent estats populaires: 2
# estat populaire monarchie: 2
# deuantle peuple romain: 2
# estat populaire ariftocratie: 2
# ariftocratie estat populaire: 2
# guerre civile entre: 2
# aduient guerre civile: 2
# depuis trois cens: 2
# remarqué cy dessus: 2
# faire grandes choses: 2
# grandes choses creatures: 2
# confeffe merueilleux effects: 2
# puissance dieu monstre: 2
# dieu monstre ad: 2
# neantmoinsil retire aussitostquand: 2
# retire aussitostquand plaift: 2
# beaucoup moins effects: 2
#
# First 30 items in République V_corrected:
# vaut beaucoup mieux: 3
# lifons histoires indes: 2
# peuples regions moyennes: 2
# tacite parlant almans: 2
# aussi peuples septentrion: 2
# iusques portes milan: 2
# fix cens enfans: 2
# aussi peuples midy: 2
# cent cinquante ans: 2
# grande peuples septentrion: 2
# elles feront longues: 2
# quelque prix cefoit: 2
# quatre cinq cens: 2
# trois cens mil: 2
# roy agesi laus: 2
# difpofer testament immeubles: 2
# sept mil spartiates: 2
# refoudre quelque chose: 2
# roy françois premier: 2
# achepter voix peuple: 2
# auons monstré cy: 2
# monstré cy dessus: 2
# capitaine paul æmyl: 2
# ville bien munie: 2
# sujets guerriers mutins: 2
# vil favt tenir: 1
# favt tenir povr: 1
# tenir povr accommoder: 1
# vsqv icy auonstouché: 1
# icy auonstouché cequi: 1
#
# First 30 items in République VI_corrected:
# mil cinq cens: 8
# cens mil escus: 8
# quatre cens mil: 5
# cinq cens mil: 5
# mil escus couronne: 5
# cinq cens cinquante: 4
# monstré cy deuant: 4
# millions cinq cens: 4
# deniers douze grains: 4
# deniers feize grains: 4
# remarqué cy dessus: 3
# faire fonds finances: 3
# quatre cens cinquante: 3
# cés mil escus: 3
# està peu pres: 3
# fols fix deniers: 3
# mil sept cens: 3
# trois quars carat: 3
# deniers trois grains: 3
# auons monstré cy: 3
# quatre cens ans: 3
# lon mettoit denier: 2
# où lon mettoit: 2
# unt ciuium capita: 2
# mil trois cens: 2
# trois cens foixante: 2
# aussi parce moyen: 2
# cest empire là: 2
# an pourle moins: 2
# faits entre princes: 2
#
# First 30 items in Réublique Preface_corrected:
# pretage uantrien mieux: 1
# entrepris discours republique: 1
# fources langue latine: 1
# feicheront barbarie caufce: 1
# barbarie caufce guerres: 1
# caufce guerres civiles: 1
# guerres civiles continue: 1
# civiles continue estre: 1
# continue estre mieux: 1
# tendu françois naturels: 1
# ex vouloir perpetuel: 1
# vouloir perpetuel voir: 1
# estat royaume premiere: 1
# p endeur fleurissant: 1
# endeur fleurissant armes: 1
# fleurissant armes loix: 1
# iamais republique ff: 1
# republique ff excelléte: 1
# ff excelléte beauté: 1
# excelléte beauté vicilliffe: 1
# commesujette torrét nature: 1
# torrét nature fluide: 1
# face forte changement: 1
# forte changement doux: 1
# faire gr non: 1
# gr non violent: 1
# non violent fanglant: 1
# points traiclé cest: 1
# traiclé cest oeuvre: 1
# difcourant membre republique: 1

# %%
dictionary_to_file(trigram_counts, trigram_folder, 'trigram_counts')
# Out:
# Saved République I_corrected_trigram_counts.csv in tokenized/trigram_counts
# Saved République II_corrected_trigram_counts.csv in tokenized/trigram_counts
# Saved République III_corrected_trigram_counts.csv in tokenized/trigram_counts
# Saved République IV_corrected_trigram_counts.csv in tokenized/trigram_counts
# Saved République V_corrected_trigram_counts.csv in tokenized/trigram_counts
# Saved République VI_corrected_trigram_counts.csv in tokenized/trigram_counts
# Saved Réublique Preface_corrected_trigram_counts.csv in tokenized/trigram_counts

# %%
colloc_dict = {}
colloc_counts = {}

for key, value in unigrams.items():
    unigram_list = [word for word in value if word.lower() not in stopwords]
    bigram_finder = BigramCollocationFinder.from_words(unigram_list)
    bigram_finder.apply_freq_filter(3)  # Make sure all collocations have occurred at least 5 times
    collocations = bigram_finder.nbest(BigramAssocMeasures.pmi, 500)
    filtered_collocations = [bigram for bigram in collocations if '' not in bigram]
    colloc_dict[key] = filtered_collocations
    
    # Initialize Counter for colloc_counts
    bigram_count_dict = Counter()

    # Count the occurrences of each bigram in the text
    bigram_finder = BigramCollocationFinder.from_words(unigram_list)
    bigram_freqs = bigram_finder.ngram_fd.items()
    
    # Filter bigram counts based on collocations
    for bigram, count in bigram_freqs:
        if bigram in filtered_collocations:
            bigram_count_dict[bigram] = count

    colloc_counts[key] = bigram_count_dict

print("Collocations:")
for key, value in colloc_dict.items():
    print(key)
    # for w1, w2 in value:
    #     print(' ', w1, w2)

print("Collocation Counts:")
for key in colloc_counts:
    print(key)
    # Print first n items, assuming print_first_n_items function is defined elsewhere
    for item, count in colloc_counts[key].most_common(30):
        bigram = " ".join(item)
        print(f"{bigram} {count}")
    print()

dictionary_to_file(colloc_counts, collocation_folder, 'collocation_counts')
# Out:
# Collocations:
# République I_corrected
# République II_corrected
# République III_corrected
# République IV_corrected
# République V_corrected
# République VI_corrected
# Réublique Preface_corrected
# Collocation Counts:
# République I_corrected
# prince souverain 62
# roy france 48
# empereur charles 24
# ains aussi 21
# non seulement 20
# roys france 18
# bien certain 17
# sujet naturel 17
# roy charles 17
# menu peuple 16
# roy françois 16
# bien souvent 15
# cas pareil 15
# homme lige 15
# princes souverains 15
# cy dessus 14
# doit estre 13
# faire mourir 13
# droit bourgeoisie 13
# toute republique 12
# trois cens 12
# roy louis 12
# entre princes 11
# puissance paternelle 11
# peu peu 11
# prince souverian 11
# hommage lige 11
# droit gouvernement 10
# quelque chose 10
# toute puissance 10
#
# République II_corrected
# estat populaire 21
# moindre partie 12
# gens bien 12
# cy dessus 12
# prince souverain 11
# bien souvent 11
# grand conseil 11
# villes imperiales 10
# puissance souveraine 9
# monarchie seigneuriale 8
# partie peuple 7
# menu peuple 7
# mil citoyens 7
# aussi bien 6
# ains aussi 6
# grand nombre 6
# bien fort 6
# loix nature 6
# monarque seigneurial 6
# monstré cy 6
# voye iustice 6
# non seulement 6
# privé conseil 6
# anciennes familles 6
# estat aristocratique 5
# estat fera 5
# bien vray 5
# contre roy 5
# donne estats 5
# cas pareil 5
#
# République III_corrected
# cy dessus 23
# puissance commander 21
# conseil privé 17
# quelques uns 15
# cas pareil 12
# doit estre 12
# prince souverain 12
# ains aussi 11
# non seulement 10
# voix deliberative 10
# parlement paris 10
# bien souvent 9
# quand question 9
# lettres iustice 9
# menu peuple 8
# estat populaire 8
# puissance faire 8
# doit faire 8
# charge publique 8
# quatre cens 8
# tribun peuple 8
# lettres patentes 8
# faire guerre 8
# magistrat doit 8
# passer outre 8
# toute republique 7
# advis senat 7
# ains seulement 7
# peu peu 7
# beaucoup moins 7
#
# République IV_corrected
# estat populaire 51
# ains aussi 23
# cy dessus 20
# guerres civiles 19
# estats populaires 18
# peu peu 17
# hautes planettes 16
# bien souvent 13
# roy france 13
# guerre civile 13
# trois cens 12
# non seulement 11
# mois septembre 11
# menu peuple 10
# tire foy 10
# trois hautes 10
# cens ans 9
# quelques uns 9
# sept cens 9
# ruines republiques 9
# peuple romain 8
# roy macedoine 8
# grands seigneurs 8
# ioint aussi 8
# creation monde 8
# doit faire 8
# bien certain 7
# empire romain 7
# cens cinquante 7
# mil hommes 7
#
# République V_corrected
# peuples septentrion 21
# estat populaire 18
# peuple meridional 16
# menu peuple 12
# loy dieu 10
# non seulement 9
# guerres civiles 9
# bien fort 8
# peuples midy 8
# ains aussi 8
# peu peu 7
# gens bien 7
# long temps 6
# sept mil 6
# cens ans 6
# roy france 6
# bien certain 6
# cinq cens 6
# beaucoup mieux 6
# aussi voit 6
# bien souvent 6
# places fortes 6
# pays meridional 5
# aussi voyons 5
# pauvreté extreme 5
# doit estre 5
# empereur charles 5
# estat aristocratique 5
# cy dessus 5
# biens condamnez 5
#
# République VI_corrected
# estat populaire 60
# cens mil 25
# menu peuple 25
# mil escus 23
# cinq cens 20
# roy france 17
# bien souvent 14
# non seulement 13
# quatre cens 13
# ains aussi 13
# proportion geometrique 13
# bien fort 12
# iustice harmonique 12
# cy dessus 11
# trois cens 11
# gens bien 11
# roy françois 11
# quatre deniers 11
# guerres civiles 11
# doit estre 10
# seigneurs ligues 10
# cens ans 10
# forme republique 10
# grand nombre 9
# dix mil 9
# peu peu 9
# mil cinq 8
# cy deuant 8
# parce moyen 8
# estat finances 8
#
# Réublique Preface_corrected
#
# Saved République I_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved République II_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved République III_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved République IV_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved République V_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved République VI_corrected_collocation_counts.csv in tokenized/collocation_counts
# Saved Réublique Preface_corrected_collocation_counts.csv in tokenized/collocation_counts

# %%
trigram_colloc_dict = {}
trigram_colloc_counts = {}

for key, value in unigrams.items():
    unigram_list = [word for word in value if word.lower() not in stopwords]
    trigram_finder = TrigramCollocationFinder.from_words(unigram_list)
    trigram_finder.apply_freq_filter(3)  # Ensure all collocations have occurred at least 5 times
    collocations = trigram_finder.nbest(TrigramAssocMeasures.pmi, 500)
    filtered_collocations = [trigram for trigram in collocations if '' not in trigram]
    trigram_colloc_dict[key] = filtered_collocations
    
    # Initialize Counter for trigram_colloc_counts
    trigram_count_dict = Counter()

    # Count the occurrences of each trigram in the text
    trigram_freqs = trigram_finder.ngram_fd.items()
    
    # Filter trigram counts based on collocations
    for trigram, count in trigram_freqs:
        if trigram in filtered_collocations:
            trigram_count_dict[trigram] = count

    trigram_colloc_counts[key] = trigram_count_dict

print("Trigram Collocations:")
for key, value in trigram_colloc_dict.items():
    print(key)
    #for w1, w2, w3 in value:
    #    print(' ', w1, w2, w3)

print("Trigram Collocation Counts:")
for key in trigram_colloc_counts:
    print(key)
    # Print first n items, assuming print_first_n_items function is defined elsewhere
    for item, count in trigram_colloc_counts[key].most_common(30):
        trigram = " ".join(item)
        print(f"{trigram} {count}")
    print()

dictionary_to_file(trigram_colloc_counts, trigram_collocation_folder, 'trigram_collocation_counts')
# Out:
# Trigram Collocations:
# République I_corrected
# République II_corrected
# République III_corrected
# République IV_corrected
# République V_corrected
# République VI_corrected
# Réublique Preface_corrected
# Trigram Collocation Counts:
# République I_corrected
# quelque forte foit 5
# droit gouvernement plusieurs 3
# long temps parauant 3
# cens mil escus 3
# augufte roy depoloigne 3
# caril bien certain 3
# sujet naturel roy 3
# homme lige pape 3
# puissance faire loix 3
# monstré cy dessus 3
# auoyent force an 3
# donner loy general 3
#
# République II_corrected
# monstré cy dessus 5
# moindre partie peuple 4
# moindre partie citoyens 4
#
# République III_corrected
# auons cy dessus 5
# monstré cy dessus 3
# auons monstré cy 3
#
# République IV_corrected
# trois hautes planettes 10
# monstré cy dessus 6
# sept cens ans 5
# mil trois cens 5
# mil cinq cens 4
# creation monde iusques 4
# grand dieu nature 4
# foy bien souvent 3
# cinq mil cinq 3
# bien petit nombre 3
#
# République V_corrected
# vaut beaucoup mieux 3
#
# République VI_corrected
# mil cinq cens 8
# cens mil escus 8
# quatre cens mil 5
# cinq cens mil 5
# mil escus couronne 5
# cinq cens cinquante 4
# monstré cy deuant 4
# millions cinq cens 4
# deniers douze grains 4
# deniers feize grains 4
# remarqué cy dessus 3
# faire fonds finances 3
# quatre cens cinquante 3
# cés mil escus 3
# està peu pres 3
# fols fix deniers 3
# mil sept cens 3
# trois quars carat 3
# deniers trois grains 3
# auons monstré cy 3
# quatre cens ans 3
#
# Réublique Preface_corrected
#
# Saved République I_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved République II_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved République III_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved République IV_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved République V_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved République VI_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts
# Saved Réublique Preface_corrected_trigram_collocation_counts.csv in tokenized/trigram_collocation_counts

# %%
underscore_dict = {}
for key, value in unigrams.items():

    tokenized_words = unigrams.get(key)
    collocations = colloc_dict.get(key)
    
    colloc_words = []
    
    # Iterate through the words making new versions combining collocations
    i = 0
    while i < len(tokenized_words) - 1:
        # If we find a collocation, add and advance by two words
        if (tokenized_words[i], tokenized_words[i + 1]) in collocations:
            colloc_words.append('_'.join((tokenized_words[i], tokenized_words[i + 1])))
            i += 2
        # Otherwise, advance by one word
        else:
            colloc_words.append(tokenized_words[i])
            i += 1

    # Add the last word (if any)
    if i == len(tokenized_words) - 1:
        colloc_words.append(tokenized_words[i])
    underscore_dict[key] = colloc_words

print("Underscore Dictionary:")
for key in underscore_dict:
    print(key)

write_dict_to_files_with_suffix(underscore_dict, underscore_folder, 'underscore_bigrams')
# Out:
# Underscore Dictionary:
# République I_corrected
# République II_corrected
# République III_corrected
# République IV_corrected
# République V_corrected
# République VI_corrected
# Réublique Preface_corrected
# République I_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# République II_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# République III_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# République IV_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# République V_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# République VI_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams
# Réublique Preface_corrected_underscore_bigrams.txt in tokenized/underscore_bigrams

# %%
trigram_underscore_dict = {}

for key, tokenized_words in unigrams.items():
    collocations = trigram_colloc_dict.get(key, [])
    colloc_words = []
    i = 0
    while i < len(tokenized_words) - 2:
        # If we find a trigram collocation, add and advance by three words
        trigram = (tokenized_words[i], tokenized_words[i + 1], tokenized_words[i + 2])
        if trigram in collocations:
            colloc_words.append('_'.join(trigram))
            i += 3
        else:
            colloc_words.append(tokenized_words[i])
            i += 1
    # Add the last words (if any)
    while i < len(tokenized_words):
        colloc_words.append(tokenized_words[i])
        i += 1
    trigram_underscore_dict[key] = colloc_words

print("Trigram underscore Dictionary:")
for key in trigram_underscore_dict:
    print(key)

write_dict_to_files_with_suffix(trigram_underscore_dict, trigram_underscore_folder, 'underscore_trigrams')
# Out:
# Trigram underscore Dictionary:
# République I_corrected
# République II_corrected
# République III_corrected
# République IV_corrected
# République V_corrected
# République VI_corrected
# Réublique Preface_corrected
# République I_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# République II_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# République III_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# République IV_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# République V_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# République VI_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
# Réublique Preface_corrected_underscore_trigrams.txt in tokenized/underscore_trigrams
